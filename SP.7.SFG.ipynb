# %% [markdown]
# # THIS CODE CONCATENATES WITH INVERSE VAR WEIGHTING

# %%
from astropy.table import Table, vstack, Column, MaskedColumn, pprint
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt
from astropy.convolution import convolve, Gaussian1DKernel

from astropy.io import fits
from matplotlib.backends.backend_pdf import PdfPages

import os
import requests
import sys
sys.path.append('/Users/s2537809/DESI/desispec/py')
sys.path.append('/Users/s2537809/DESI/desimodel/py')
sys.path.append('/Users/s2537809/DESI/desitarget/py')
sys.path.append('/Users/s2537809/DESI/desiutil/py')

#from desispec.io import read_spectra
# import DESI related modules - 
from desimodel.footprint import radec2pix      # For getting healpix values
import desispec.io                             # Input/Output functions related to DESI spectra
from desispec import coaddition                # Functions related to coadding the spectra


from scipy import interpolate
import astropy.units as u
path='/Users/s2537809/Documents/DESI-STACKING'#specify code directory
os.chdir(path)
import stack_code as sc
import importlib
import fnmatch
import extinction as ext
from scipy.optimize import curve_fit
from astropy.coordinates import SkyCoord
from astropy.modeling import models
from astropy.table import Table
from matplotlib import gridspec
import spectres
import time
import warnings

#pip install lmfit, extinction, sfdmap, spectres

import pandas as pd
crossmatch = Table.read('crossmatch_classifications.fits', format = 'fits' )
# Out:
# /Users/s2537809/DESI/desispec/py/desispec/qproc/qextract.py:19: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_extract(image_flux,image_var,x,hw=3) :
# /Users/s2537809/DESI/desispec/py/desispec/image_model.py:27: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_proj(image,x,sigma,flux) :
# /Users/s2537809/DESI/desispec/py/desispec/preproc.py:379: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_mean(image_flux,image_ivar,x,hw=3) :

# %% [markdown]
# ## Cell below verifies if Spectra are downloaded and downloads if they aren't
#
# Only run if unsure if spectra are downloaded, to save time!

# %%
"""
Note: The lengths for indexing are:

HERG = 184

RQAGN = 814

LERG = 1293

SFG = 6294

"""


Overall_class = 'SFG'
my_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][1000:1200]
search_column_name = 'TARGETID'
search_values = np.array(my_table[f'{search_column_name}'])



def select_data(table, column_name, search_values):
    # Get the column data as a numpy array
    column_data = table[column_name]

    SURVEY = []
    PROGRAM = []
    HEALPIX = []
    n_values = []
    Z = []
    

    for search_value in search_values:
        # Find the indices where the condition is met (value == search_value)
        indices = np.where(column_data == search_value)[0]


        if len(indices) > 0:
            # Find the corresponding Survey, program, healpix, and Z values
            SURVEY.append(table['SURVEY'][indices[0]])
            PROGRAM.append(table['PROGRAM'][indices[0]])
            HEALPIX.append(table['HEALPIX'][indices[0]])
            Z.append(table['Z'][indices[0]])
            HEALPIX_str = str(table['HEALPIX'][indices[0]])
            n_str = HEALPIX_str[:3]
            n_values.append(int(n_str))
        else:
            # Handle the case where the search value was not found
            SURVEY.append(None)
            PROGRAM.append(None)
            HEALPIX.append(None)
            n_values.append(None)
            Z.append(None)
    

    return np.array(SURVEY), np.array(PROGRAM), np.array(HEALPIX), np.array(n_values), np.array(Z), 


SURVEY = select_data(my_table, search_column_name, search_values)[0]
PROGRAM = select_data(my_table, search_column_name, search_values)[1]
HEALPIX = select_data(my_table, search_column_name, search_values)[2]
n = select_data(my_table, search_column_name, search_values)[3]
Z = select_data(my_table, search_column_name, search_values)[4]
print (SURVEY,PROGRAM,HEALPIX, n, Z)

for n, survey, program, healpix, Z, search_value in zip(n, SURVEY, PROGRAM, HEALPIX, Z, search_values):
        #download the file from the given Target ID
        target_url = f"https://data.desi.lbl.gov/public/edr/spectro/redux/fuji/healpix/{survey}/{program}/{n}/{healpix}/coadd-{survey}-{program}-{healpix}.fits"
        
        # Define the folder name and file name
        folder_name = 'DESI_Downloads'
        file_name = f"coadd-{survey}-{program}-{healpix}.fits"
        print(search_value)


        # Check if the folder exists, and create it if it doesn't
        if not os.path.exists(folder_name):
            os.makedirs(folder_name)

        # Check if the file exists in the folder
        file_path = os.path.join(folder_name, file_name)
        if os.path.exists(file_path):
            print(f"{file_name} already exists in {folder_name}. No need to download.")
        else:
            # File doesn't exist, download it
            try:
                response = requests.get(target_url)
                if response.status_code == 200:
                    with open(file_path, 'wb') as file:
                        file.write(response.content)
                    print(f"{file_name} downloaded to {folder_name}.")
                else:
                    print(f"Failed to download {file_name}. Status code: {response.status_code}")
            except Exception as e:
                print(f"An error occurred while downloading {file_name}: {str(e)}")
# Out:
# ['sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1' 'sv1'
#  'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv1' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1'
#  'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv1' 'sv1' 'sv1' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv1'
#  'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3'] ['bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright'
#  'bright' 'other' 'bright' 'bright' 'dark' 'other' 'other' 'bright'
#  'bright' 'dark' 'other' 'other' 'bright' 'bright' 'other' 'other'
#  'bright' 'other' 'dark' 'bright' 'bright' 'dark' 'bright' 'other' 'other'
#  'bright' 'other' 'other' 'other' 'bright' 'bright' 'other' 'bright'
#  'bright' 'bright' 'bright' 'other' 'other' 'other' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright'
#  'other' 'other' 'bright' 'dark' 'dark' 'bright' 'other' 'other' 'dark'
#  'other' 'bright' 'bright' 'bright' 'bright' 'bright' 'other' 'dark'
#  'dark' 'other' 'other' 'other' 'other' 'other' 'bright' 'other' 'bright'
#  'bright' 'other' 'dark' 'bright' 'bright' 'other' 'other' 'bright'
#  'other' 'other' 'bright' 'bright' 'other' 'dark' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'other' 'bright' 'bright' 'bright' 'bright'
#  'bright' 'other' 'bright' 'other' 'bright' 'bright' 'other' 'bright'
#  'bright' 'dark' 'bright' 'bright' 'bright' 'other' 'dark' 'other'
#  'bright' 'bright' 'bright' 'other' 'other' 'bright' 'other' 'other'
#  'bright' 'other' 'dark' 'bright' 'other' 'bright' 'dark' 'other' 'bright'
#  'other' 'other' 'other' 'bright' 'other' 'bright' 'other' 'bright' 'dark'
#  'bright' 'other' 'other' 'bright' 'bright' 'dark' 'bright' 'other'
#  'other' 'bright' 'bright' 'bright' 'dark' 'other' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'other' 'other' 'dark' 'bright' 'bright'
#  'bright' 'dark' 'bright' 'other' 'other' 'other' 'other' 'other' 'bright'
#  'bright' 'bright' 'dark' 'other' 'other' 'dark' 'bright' 'other' 'bright'
#  'bright' 'bright' 'dark' 'dark' 'other' 'bright' 'other' 'backup'
#  'backup'] [10152 10154 10152 11521 10154 11521 10152 10154 10154 11521 10154 11521
#  10152 11521 11521 10154 10154 10154 10152 10152 10154 10154 10154 10154
#  11521 10152 11521 10152 10152 10154 11521 10154 10154 10155 10154 10154
#  10152 10154 10154 10154 10154 11521 10154 10154 10154 10154 10154 11521
#  10154 11521 10152 10154 10154 11521 10154 11521 10154 11521 11521 10154
#  10152 11521 11521 11521 11521 10154 10152 10154 10154 11521 10154 10154
#  11521 10154 11521 10154 10154 10152 11521 10154 10154 10155 11521 11521
#  10152 11521 10154 10154 11521 10152 10154 10154 11521 11521 11521 10155
#  11521 11521 11521 10155 10154 11521 10154 11521 10154 11521 10154 11521
#  11521 11521 10154 11521 10154 10154 10154 11521 10155 10154 10152 11521
#  11521 10154 10154 10154 11521 10154 10152 11521 10154 10154 10154 11521
#  10152 10154 10154 11521 11521 11521 10154 11521 11521 10154 10155 10154
#  10154 11521 10154 10152 10152 10154 11521 11521 11521 10155 11521 11521
#  10154 10152 10155 10155 11521 11521 10154 11521 10154 10152 10155 10155
#  11521 10152 10154 10154 10154 10152 11521 10155 10152 10152 10152 10152
#  11521 11521 10152 10154 10154 11521 10152 10154 10152 11521 10154 10152
#  11521 10154 11521 11521 10154 10154 11521 10152] [101 101 101 115 101 115 101 101 101 115 101 115 101 115 115 101 101 101
#  101 101 101 101 101 101 115 101 115 101 101 101 115 101 101 101 101 101
#  101 101 101 101 101 115 101 101 101 101 101 115 101 115 101 101 101 115
#  101 115 101 115 115 101 101 115 115 115 115 101 101 101 101 115 101 101
#  115 101 115 101 101 101 115 101 101 101 115 115 101 115 101 101 115 101
#  101 101 115 115 115 101 115 115 115 101 101 115 101 115 101 115 101 115
#  115 115 101 115 101 101 101 115 101 101 101 115 115 101 101 101 115 101
#  101 115 101 101 101 115 101 101 101 115 115 115 101 115 115 101 101 101
#  101 115 101 101 101 101 115 115 115 101 115 115 101 101 101 101 115 115
#  101 115 101 101 101 101 115 101 101 101 101 101 115 101 101 101 101 101
#  115 115 101 101 101 115 101 101 101 115 101 101 115 101 115 115 101 101
#  115 101] [ 3.35145291e-01  2.47546395e-01  3.51474847e-01  2.13741842e-01
#   2.60245790e-01  2.46776309e-01  3.26101244e-01  3.50294377e-01
#   2.48664978e-01  2.30915676e-01  2.67320575e-01  2.51255934e-01
#   1.32054771e+00  4.66177402e-01  8.94670238e-01  2.64692571e-01
#   2.06842153e-01  1.18354918e+00  6.16881356e-01  9.71320367e-01
#   5.00949636e-01  1.43829866e-01  4.76371842e-01  1.18181335e+00
#   1.13551269e-01  9.56587148e-01  1.14206160e+00  4.20989635e-01
#   2.23063008e-01  2.62026642e-01  4.06392886e-01 -1.99570145e-03
#   1.61394631e+00  4.77336916e-01  3.45942222e-01  4.37611319e-01
#   1.18263070e+00  2.94771704e-01  3.26752756e-01 -1.99570145e-03
#   3.22729213e-01  2.25642234e-01  4.70261812e-01  2.60548780e-01
#   1.00551746e+00  9.03125446e-01  2.62803606e-01  4.15334710e-01
#   4.78697777e-02  3.01728664e-01  2.47619772e-01  2.12142287e-01
#   2.60254741e-01  2.51951408e-01  3.27000936e-01  2.40847110e-01
#   1.47463133e-01  8.06549617e-01  8.15919143e-01  4.65331591e-01
#   9.57477660e-01  7.52400543e-01  2.98955876e-01  4.92391271e-01
#  -1.99570145e-03  2.36904500e+00  6.47611703e-01  2.62972521e-01
#   2.65348851e-01  2.49709585e-01  2.10873257e-01  2.70182415e-01
#   5.72395385e-01  6.76710731e-01  7.10427329e-01  4.72487169e-01
#   1.25386578e+00  5.74550204e-01 -1.99570145e-03  6.12581395e-01
#   3.38195228e-01 -1.99570145e-03  2.53992626e-01  3.98017042e-01
#   9.58143966e-01  3.37176488e-01  2.75735084e-01  2.63472260e-01
#   7.59646502e-01  1.70988878e-01  2.38028642e-01  2.45220551e-01
#   6.64954428e-01  2.48519854e-01  4.06864414e-01  7.59687869e-01
#   7.37262654e-01  2.06402577e-01  3.37734549e-01  2.66866943e-01
#   2.10601248e-01  4.41680646e-01  4.52201856e-01  4.98444339e-02
#  -1.99569129e-03  2.31138140e-01  2.58271269e-01  4.40589866e-01
#   3.16568144e-01  1.07066125e-01  6.36902678e-01  3.23551450e-01
#   2.07949892e-01  1.42424417e+00  1.83040205e-01  2.28335580e-01
#   1.26313829e+00  2.36690044e-01  2.22107843e-01  2.89424617e-01
#  -1.99570145e-03  6.13595807e-01  3.46999254e-01  3.92465185e-01
#   4.06637584e-01  2.62197770e-01  2.22658176e-01  3.87577344e-01
#   8.31122973e-02  9.41927038e-01  3.19716211e-01  2.14372227e-01
#   1.01801308e+00  1.11760550e+00  4.17545529e-01  4.93845663e-01
#   3.03088749e-01  1.25986723e+00  4.30977354e-01  2.51786180e-01
#   3.33530562e-01 -1.99570145e-03  4.95964185e-01  2.65083905e-01
#   3.14700478e-01  4.04847697e-01  4.30283532e-01  2.57139736e-01
#   1.11580458e+00  1.47590864e-01  4.71829153e-01  4.28236748e-01
#   4.05566016e-01  2.63668566e-01  8.03809807e-01  3.28498005e-01
#   1.18411999e+00  5.55423332e-01  1.88907020e-01  1.88025265e-01
#   1.36714944e-01  1.36668873e+00  1.18389185e+00  3.87780029e-01
#   2.12478393e-01  3.26275299e-01  3.92941940e-01  2.60161886e-01
#   2.09195372e-01 -1.99570145e-03  5.30797823e-01  3.37288903e-01
#   2.08938025e-01  6.45889139e-02  6.52192040e-01  2.34304472e-01
#   1.18289867e+00  7.32124331e-01  3.48583331e-01  3.87177342e-01
#  -1.99570145e-03  3.03327379e-02  2.47141434e-01  9.23367520e-02
#   1.06122598e+00  3.41469365e-01  9.04649766e-01  8.86065561e-01
#   6.48397814e-02 -1.99570145e-03  3.35562472e-01  4.10595427e-02
#   1.45934177e-01  1.17756972e+00  1.14986790e+00  7.38655253e-01
#   2.43709265e-01  6.38046178e-01  4.95573579e-02  6.57485407e-02]
# 39633304823008514
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982975969
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396555936
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932938903
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468443875
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015647
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008573
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308396555958
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468443898
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008188
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468443902
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015678
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008590
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932938945
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015720
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976058
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936751
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538058
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008682
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308396556073
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633311944936784
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936786
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976100
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556087
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015757
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008714
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633329376463774
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308396556090
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633304823008722
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633315476538100
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015773
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538118
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 213624597512203
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444049
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633311944936838
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936850
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008798
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982976184
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976186
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936860
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444078
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008327
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444091
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538211
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556220
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936891
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936898
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939121
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944936897
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196401992
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008865
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633315476538259
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936944
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376463927
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976313
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402018
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976328
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015888
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939200
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976347
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556302
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402028
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376463948
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015908
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015912
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944936993
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008926
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982976389
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976403
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376463988
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444230
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944937038
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939274
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976442
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008466
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976450
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 213624597512196
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008991
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633332799015965
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538416
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538437
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939336
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633329376464089
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008514
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823009073
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932939360
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538476
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976557
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016060
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308396556500
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633311944937171
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538517
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016074
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016076
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402183
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444396
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633339577008598
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008627
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464206
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444490
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633315476538598
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402250
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976719
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464220
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976735
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008650
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976749
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939529
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008672
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464268
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944937314
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464266
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976782
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944937324
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538635
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016198
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444546
# coadd-sv3-dark-10155.fits already exists in DESI_Downloads. No need to download.
# 39633318982976791
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746553
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633329376464302
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016225
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976840
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976847
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444584
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464325
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538672
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746587
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402344
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538679
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976866
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976871
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939622
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308400746634
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746638
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538705
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016261
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016285
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939655
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538738
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464395
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016309
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127747
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939691
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633318982976981
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311949127768
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402452
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127790
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199794
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746719
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977050
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016358
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464481
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402481
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939767
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633325932939775
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402503
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538869
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199873
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633322468444756
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633322468444768
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633339577008893
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016400
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982977125
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016407
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127878
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199916
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633322468444809
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633322468444834
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633336196402570
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304827199972
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977255
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538991
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982977261
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746897
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577008995
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444890
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633308400746911
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746926
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746933
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633304827200045
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402641
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939926
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304827200056
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977346
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311949128018
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939952
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308400746994
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977418
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400747026
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577009097
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982977442
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827200127
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577009104
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949128097
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016602
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577009120
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476539133
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476539148
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 2305843021293300240
# coadd-sv3-backup-11521.fits already exists in DESI_Downloads. No need to download.
# 2305843019858848671
# coadd-sv3-backup-10152.fits already exists in DESI_Downloads. No need to download.

# %%
def inv_var_weighted_average(flux1, ivar1, flux2, ivar2):
    """
    Finds the inverse varience weighted average of two flux spectra
    
    """
    weight1 = 1 / ivar1
    weight2 = 1 / ivar2
    total_weight = weight1 + weight2
    weighted_flux1 = flux1 * (weight1 / total_weight)
    weighted_flux2 = flux2 * (weight2 / total_weight)
    weighted_avg = weighted_flux1 + weighted_flux2
    return weighted_avg

def no_overlap_f(waveb,fluxb,waver,fluxr,wavez,fluxz):
    """
    Isolates the flux and wavelength arrays of each band to non-overlapping wavelength sections
    
    """
    new_b_length = np.where(waveb<waver[0])
    b_wave = waveb[new_b_length]
    b_flux = fluxb[new_b_length]
    new_r_length = np.where((waver>waveb[-1])&(waver<wavez[0]))
    r_wave = waver[new_r_length]
    r_flux = fluxr[new_r_length]
    new_z_length = np.where(wavez>waver[-1])
    z_wave = wavez[new_z_length]
    z_flux = fluxz[new_z_length]

    return b_wave,b_flux,r_wave,r_flux,z_wave,z_flux


def overlap_av(wave1,wave2,flux1,flux2,ivar1,ivar2):
    """
    Finds the overlap of two wavelength ranges.
    Computes the inverse var weighted average flux and wavelength for th eoverlapping range 
    
    """
    overlap_idx_1 = np.where(wave1 >= wave2[0]) 
    overlap_wave = wave1[overlap_idx_1]
    overlap_flux_1 = flux1[overlap_idx_1]
    overlap_ivar_1 = ivar1[overlap_idx_1]

    overlap_idx_2 = np.where(wave2 <= wave1[-1]) 
    overlap_flux_2 = flux2[overlap_idx_2]
    overlap_ivar_2 = ivar2[overlap_idx_2]
    
    overlap_av_flux = inv_var_weighted_average(overlap_flux_1,overlap_ivar_1,overlap_flux_2,overlap_ivar_2)

    return overlap_av_flux, overlap_wave

# %%
#stacking functions

# Ignore warnings due to spec_var=0
warnings.filterwarnings("ignore", message="divide by zero encountered in true_divide")


def get_spectra(table, column_name, search_values): 
    print('Number of spectra =', len(table))
    # Get the Target IDs as a numpy array
    column_data = table[column_name]

    SURVEY, PROGRAM, HEALPIX, n_values = [], [], [], []
    Z, RA, DEC, Source_ID = [], [], [], []


    for search_value in search_values:
        # Find the indices where the condition is met (value == search_value)
        # This is only relevant if input is doen by search value and not selected table
        indices = np.where(column_data == search_value)[0]

        if len(indices) > 0:
            # Find the corresponding Survey, program, healpix, Z , RA and Dec values
            SURVEY.append(table['SURVEY'][indices[0]])
            PROGRAM.append(table['PROGRAM'][indices[0]])
            HEALPIX.append(table['HEALPIX'][indices[0]])
            Z.append(table['Z'][indices[0]])
            RA.append(table['TARGET_RA'][indices[0]]) 
            DEC.append(table['TARGET_DEC'][indices[0]])
            Source_ID.append(table['TARGETID'][indices[0]])
            HEALPIX_str = str(table['HEALPIX'][indices[0]])
            n_str = HEALPIX_str[:3]
            n_values.append(int(n_str))
        else:
            # Handle the case where the search value was not found
            SURVEY.append(None)
            PROGRAM.append(None)
            HEALPIX.append(None)
            n_values.append(None)
            Z.append(None)   
            RA.append(None)
            DEC.append(None)
            Source_ID.append(None)
            
    
    z = np.array(Z)
    RA = np.array(RA)
    DEC = np.array(DEC)
    id_spec = np.array(Source_ID)
    wave_spec, flux_spec, sigma_spec = [], [], []
    
    for index, (survey, program, healpix, search_value) in enumerate(zip(SURVEY, PROGRAM, HEALPIX, search_values)):
        
        folder_name = 'DESI_Downloads'
        file_name = f"coadd-{survey}-{program}-{healpix}.fits"
        coadd_obj = desispec.io.read_spectra(f'{folder_name}/{file_name}')
        coadd_tgts = coadd_obj.target_ids().data
        # Selecting the particular spectra of the targetid
        row = (coadd_tgts == search_value)
        coadd_spec = coadd_obj[row] 

        # Inverse Vartiance weighted average for overlap
        no_overlap = no_overlap_f(coadd_spec.wave['b'],coadd_spec.flux['b'][0],coadd_spec.wave['r'],coadd_spec.flux['r'][0],coadd_spec.wave['z'],coadd_spec.flux['z'][0])
        overlap_br= overlap_av(coadd_spec.wave['b'],coadd_spec.wave['r'],coadd_spec.flux['b'][0],coadd_spec.flux['r'][0],coadd_spec.ivar['b'][0],coadd_spec.ivar['r'][0])
        overlap_rz= overlap_av(coadd_spec.wave['r'],coadd_spec.wave['z'],coadd_spec.flux['r'][0],coadd_spec.flux['z'][0],coadd_spec.ivar['r'][0],coadd_spec.ivar['z'][0])
        

        
        # Concaternating Spectra
        flux_spectra = np.concatenate((no_overlap[1],overlap_br[0],no_overlap[3],overlap_rz[0],no_overlap[5]))
        wave_spectra = np.concatenate((no_overlap[0],overlap_br[1],no_overlap[2],overlap_rz[1],no_overlap[4]))

        # Using Desispec to get wavelengths, flux and sigma
        wave = wave_spectra
        wave = wave.flatten()
        #flux = coadd_spec.flux['r'][0]
        #flux = convolve(flux_spectra, Gaussian1DKernel(5))
        #pick if i want to convolve or not
        flux = flux_spectra
        flux = flux.flatten()
        sigma = (np.sqrt(1/coadd_spec.ivar['r']))
        sigma = sigma.flatten()
        if index % 2 == 0 and len(wave) > 0:
                wave = wave[:-1]
                flux = flux[:-1]
                sigma = sigma[:-1]
        sigma_spec.append(sigma)
        wave_spec.append(wave)
        flux_spec.append(flux)
        
    
    wave_spec = np.array(wave_spec,dtype=object)
    flux_spec = np.array(flux_spec,dtype=object)
    sigma_spec = np.array(sigma_spec,dtype=object)
    # alternatively tried wave_spec = wave_spec.tolist()

    
    
    return wave_spec, flux_spec, sigma_spec, z, RA, DEC, id_spec


def get_stack(spec, zbins=None):# can add redshift ranges i.e zbins = [[0.0,0.1],[0.1,0.2]]
    wave_spec, flux_spec, sigma_spec, z, RA, DEC, id_spec= spec
    stack = sc.stack_spectra(wave_spec,flux_spec,sigma_spec,
                               z, RA, DEC, zbins = zbins)
    return stack

# %% [markdown]
# ## Spectra Selection and Application of Stacking

# %%
"""
#presort by mass to bin by mass 

Mass_median = crossmatch['Mass_median']
mass_order_idx = np.argsort(crossmatch['Mass_median'])
sorted_mass = Mass_median[mass_order_idx]
crossmatch = crossmatch[np.array(mass_order_idx)]


Overall_class = 'LERG'
my_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][0:10]
search_column_name = 'TARGETID'
search_values = np.array(my_table[f'{search_column_name}'])

Note: The lengths for indexing are:

HERG = 184

RQAGN = 814

LERG = 1293

SFG = 6294

"""

# Select varibale to sort by
#Mass_median or Total_flux from LOFAR?

var_bin = 'Total_flux'
crossmatch = crossmatch[np.array(np.argsort(crossmatch[f'{var_bin}']))]

Overall_class = 'SFG'
my_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][1049:2098]
search_column_name = 'TARGETID'
search_values = np.array(my_table[f'{search_column_name}'])


SFG_spec=get_spectra(my_table,search_column_name,search_values) #extracts relevant spectra

SFG_stack = get_stack(SFG_spec) #stacks spectra

#stack spectra in two redshift bins (i.e 0<z<0.1 and 0.1<z<0.2) - need to alter
#SFG_stacks = get_stack(SFG_spec, zbins=[[0.0,0.5],[0.5,1.0],[1.0,4.0]])
#soemtimes the redshift is less than 0?

## try adjusting these boundarys and adding more bins instead of binning seperately
# Out:
# Number of spectra = 1049
# INFO:spectra.py:372:read_spectra: iotime 1.636 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:11:13.612305
# INFO:spectra.py:372:read_spectra: iotime 1.413 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:11:15.564529
# INFO:spectra.py:372:read_spectra: iotime 0.837 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:11:17.392170
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_31789/3924121423.py:6: RuntimeWarning: divide by zero encountered in divide
#   weight1 = 1 / ivar1
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_31789/3924121423.py:7: RuntimeWarning: divide by zero encountered in divide
#   weight2 = 1 / ivar2
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_31789/3924121423.py:9: RuntimeWarning: invalid value encountered in divide
#   weighted_flux1 = flux1 * (weight1 / total_weight)
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_31789/3924121423.py:10: RuntimeWarning: invalid value encountered in divide
#   weighted_flux2 = flux2 * (weight2 / total_weight)
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_31789/87081193.py:80: RuntimeWarning: divide by zero encountered in divide
#   sigma = (np.sqrt(1/coadd_spec.ivar['r']))
# INFO:spectra.py:372:read_spectra: iotime 1.033 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:11:19.378037
# INFO:spectra.py:372:read_spectra: iotime 1.485 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:11:21.154122
# INFO:spectra.py:372:read_spectra: iotime 1.017 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:11:22.567138
# INFO:spectra.py:372:read_spectra: iotime 0.618 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:11:23.628205
# INFO:spectra.py:372:read_spectra: iotime 0.835 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:11:24.653508
# INFO:spectra.py:372:read_spectra: iotime 2.242 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:11:27.632178
# INFO:spectra.py:372:read_spectra: iotime 0.809 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:11:30.081784
# INFO:spectra.py:372:read_spectra: iotime 0.599 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:11:31.147579
# INFO:spectra.py:372:read_spectra: iotime 2.543 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:11:33.930944
# INFO:spectra.py:372:read_spectra: iotime 1.034 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:11:36.734783
# INFO:spectra.py:372:read_spectra: iotime 0.764 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:11:38.664916
# INFO:spectra.py:372:read_spectra: iotime 2.167 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T00:11:41.046714
# INFO:spectra.py:372:read_spectra: iotime 0.128 sec to read coadd-sv1-other-10151.fits at 2024-01-08T00:11:42.761573
# INFO:spectra.py:372:read_spectra: iotime 2.265 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T00:11:45.262265
# INFO:spectra.py:372:read_spectra: iotime 2.959 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:11:50.480958
# INFO:spectra.py:372:read_spectra: iotime 3.704 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:11:56.680963
# INFO:spectra.py:372:read_spectra: iotime 2.800 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:12:02.289856
# INFO:spectra.py:372:read_spectra: iotime 1.947 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:12:05.563224
# INFO:spectra.py:372:read_spectra: iotime 2.348 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:12:09.969083
# INFO:spectra.py:372:read_spectra: iotime 1.100 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:12:14.358547
# INFO:spectra.py:372:read_spectra: iotime 0.737 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:12:15.912686
# INFO:spectra.py:372:read_spectra: iotime 2.981 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:12:19.062172
# INFO:spectra.py:372:read_spectra: iotime 3.259 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T00:12:24.060571
# INFO:spectra.py:372:read_spectra: iotime 2.819 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:12:29.893939
# INFO:spectra.py:372:read_spectra: iotime 2.880 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:12:36.329548
# INFO:spectra.py:372:read_spectra: iotime 0.637 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:12:38.568940
# INFO:spectra.py:372:read_spectra: iotime 2.855 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T00:12:41.665718
# INFO:spectra.py:372:read_spectra: iotime 1.323 sec to read coadd-sv3-dark-11524.fits at 2024-01-08T00:12:45.446246
# INFO:spectra.py:372:read_spectra: iotime 2.404 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:12:48.874622
# INFO:spectra.py:372:read_spectra: iotime 0.372 sec to read coadd-sv1-other-10158.fits at 2024-01-08T00:12:50.328767
# INFO:spectra.py:372:read_spectra: iotime 2.625 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:12:53.231533
# INFO:spectra.py:372:read_spectra: iotime 0.938 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:12:56.360279
# INFO:spectra.py:372:read_spectra: iotime 0.850 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:12:57.555471
# INFO:spectra.py:372:read_spectra: iotime 0.728 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:12:58.579759
# INFO:spectra.py:372:read_spectra: iotime 0.759 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:12:59.563835
# INFO:spectra.py:372:read_spectra: iotime 0.706 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:13:00.409855
# INFO:spectra.py:372:read_spectra: iotime 2.922 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T00:13:03.481695
# INFO:spectra.py:372:read_spectra: iotime 1.456 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:13:06.704178
# INFO:spectra.py:372:read_spectra: iotime 0.756 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:13:09.230068
# INFO:spectra.py:372:read_spectra: iotime 2.952 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:13:12.458592
# INFO:spectra.py:372:read_spectra: iotime 2.277 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T00:13:16.339681
# INFO:spectra.py:372:read_spectra: iotime 1.926 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:13:19.957490
# INFO:spectra.py:372:read_spectra: iotime 2.636 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:13:23.419543
# INFO:spectra.py:372:read_spectra: iotime 0.641 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:13:26.116060
# INFO:spectra.py:372:read_spectra: iotime 0.759 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:13:27.243985
# INFO:spectra.py:372:read_spectra: iotime 2.308 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:13:30.067462
# INFO:spectra.py:372:read_spectra: iotime 2.157 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:13:34.632195
# INFO:spectra.py:372:read_spectra: iotime 0.813 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:13:37.561735
# INFO:spectra.py:372:read_spectra: iotime 3.129 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:13:41.357674
# INFO:spectra.py:372:read_spectra: iotime 0.697 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:13:44.883333
# INFO:spectra.py:372:read_spectra: iotime 2.042 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:13:47.256830
# INFO:spectra.py:372:read_spectra: iotime 0.562 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:13:50.036713
# INFO:spectra.py:372:read_spectra: iotime 2.262 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:13:52.652592
# INFO:spectra.py:372:read_spectra: iotime 2.850 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:13:57.230705
# INFO:spectra.py:372:read_spectra: iotime 0.458 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:13:59.686135
# INFO:spectra.py:372:read_spectra: iotime 0.756 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:14:00.761035
# INFO:spectra.py:372:read_spectra: iotime 3.342 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:14:04.274617
# INFO:spectra.py:372:read_spectra: iotime 3.466 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:14:09.149890
# INFO:spectra.py:372:read_spectra: iotime 0.769 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:14:11.926327
# INFO:spectra.py:372:read_spectra: iotime 2.565 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:14:14.961439
# INFO:spectra.py:372:read_spectra: iotime 0.549 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:14:16.148809
# INFO:spectra.py:372:read_spectra: iotime 2.736 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:14:19.394344
# INFO:spectra.py:372:read_spectra: iotime 2.630 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:14:23.695804
# INFO:spectra.py:372:read_spectra: iotime 2.792 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:14:28.117396
# INFO:spectra.py:372:read_spectra: iotime 2.788 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:14:33.805301
# INFO:spectra.py:372:read_spectra: iotime 0.671 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:14:37.712186
# INFO:spectra.py:372:read_spectra: iotime 0.662 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:14:38.723554
# INFO:spectra.py:372:read_spectra: iotime 2.841 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:14:41.730422
# INFO:spectra.py:372:read_spectra: iotime 2.599 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:14:46.585285
# INFO:spectra.py:372:read_spectra: iotime 3.990 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:14:51.702519
# INFO:spectra.py:372:read_spectra: iotime 1.099 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:14:54.167345
# INFO:spectra.py:372:read_spectra: iotime 0.777 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:14:55.959141
# INFO:spectra.py:372:read_spectra: iotime 0.989 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:14:57.303975
# INFO:spectra.py:372:read_spectra: iotime 0.567 sec to read coadd-sv3-backup-10150.fits at 2024-01-08T00:14:58.268702
# INFO:spectra.py:372:read_spectra: iotime 0.634 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:14:59.043956
# INFO:spectra.py:372:read_spectra: iotime 2.384 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:15:01.566695
# INFO:spectra.py:372:read_spectra: iotime 2.823 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:15:05.150065
# INFO:spectra.py:372:read_spectra: iotime 0.610 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:15:07.839315
# INFO:spectra.py:372:read_spectra: iotime 3.285 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:15:11.411064
# INFO:spectra.py:372:read_spectra: iotime 3.086 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:15:17.548138
# INFO:spectra.py:372:read_spectra: iotime 2.924 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:15:23.854132
# INFO:spectra.py:372:read_spectra: iotime 0.878 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:15:27.372550
# INFO:spectra.py:372:read_spectra: iotime 2.014 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:15:29.745651
# INFO:spectra.py:372:read_spectra: iotime 1.057 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:15:32.296829
# INFO:spectra.py:372:read_spectra: iotime 2.618 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:15:35.373683
# INFO:spectra.py:372:read_spectra: iotime 1.035 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:15:38.854544
# INFO:spectra.py:372:read_spectra: iotime 1.217 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:15:40.739309
# INFO:spectra.py:372:read_spectra: iotime 2.389 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:15:43.416343
# INFO:spectra.py:372:read_spectra: iotime 0.697 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:15:45.078465
# INFO:spectra.py:372:read_spectra: iotime 2.628 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T00:15:47.911612
# INFO:spectra.py:372:read_spectra: iotime 1.437 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:15:52.469796
# INFO:spectra.py:372:read_spectra: iotime 0.662 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:15:54.569846
# INFO:spectra.py:372:read_spectra: iotime 2.613 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:15:57.460840
# INFO:spectra.py:372:read_spectra: iotime 0.913 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:16:01.092236
# INFO:spectra.py:372:read_spectra: iotime 1.984 sec to read coadd-sv3-dark-11520.fits at 2024-01-08T00:16:03.837702
# INFO:spectra.py:372:read_spectra: iotime 0.055 sec to read coadd-sv1-other-10146.fits at 2024-01-08T00:16:04.381769
# INFO:spectra.py:372:read_spectra: iotime 0.851 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:16:05.316030
# INFO:spectra.py:372:read_spectra: iotime 2.519 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:16:08.014344
# INFO:spectra.py:372:read_spectra: iotime 0.284 sec to read coadd-sv1-other-10157.fits at 2024-01-08T00:16:10.450872
# INFO:spectra.py:372:read_spectra: iotime 0.620 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:16:11.391827
# INFO:spectra.py:372:read_spectra: iotime 0.624 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:16:12.200213
# INFO:spectra.py:372:read_spectra: iotime 0.594 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:16:12.957816
# INFO:spectra.py:372:read_spectra: iotime 0.609 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:16:13.717411
# INFO:spectra.py:372:read_spectra: iotime 1.001 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:16:14.860775
# INFO:spectra.py:372:read_spectra: iotime 3.391 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:16:18.962566
# INFO:spectra.py:372:read_spectra: iotime 0.939 sec to read coadd-sv3-dark-10157.fits at 2024-01-08T00:16:22.768307
# INFO:spectra.py:372:read_spectra: iotime 1.773 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:16:25.396648
# INFO:spectra.py:372:read_spectra: iotime 0.667 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:16:27.837201
# INFO:spectra.py:372:read_spectra: iotime 0.232 sec to read coadd-sv1-other-10157.fits at 2024-01-08T00:16:28.315058
# INFO:spectra.py:372:read_spectra: iotime 3.199 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T00:16:31.648038
# INFO:spectra.py:372:read_spectra: iotime 1.184 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:16:34.387307
# INFO:spectra.py:372:read_spectra: iotime 0.597 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:16:35.338959
# INFO:spectra.py:372:read_spectra: iotime 0.735 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:16:36.324179
# INFO:spectra.py:372:read_spectra: iotime 0.749 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:16:37.256432
# INFO:spectra.py:372:read_spectra: iotime 0.891 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:16:38.367243
# INFO:spectra.py:372:read_spectra: iotime 0.924 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:16:40.013912
# INFO:spectra.py:372:read_spectra: iotime 0.987 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:16:41.513212
# INFO:spectra.py:372:read_spectra: iotime 0.797 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:16:42.828921
# INFO:spectra.py:372:read_spectra: iotime 3.148 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:16:46.184568
# INFO:spectra.py:372:read_spectra: iotime 3.047 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:16:51.095714
# INFO:spectra.py:372:read_spectra: iotime 2.215 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:16:54.901465
# INFO:spectra.py:372:read_spectra: iotime 0.606 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:16:57.684775
# INFO:spectra.py:372:read_spectra: iotime 3.204 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T00:17:01.290585
# INFO:spectra.py:372:read_spectra: iotime 0.689 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:17:05.513904
# INFO:spectra.py:372:read_spectra: iotime 1.914 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:17:07.790944
# INFO:spectra.py:372:read_spectra: iotime 1.505 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:17:09.742260
# INFO:spectra.py:372:read_spectra: iotime 2.908 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:17:14.324307
# INFO:spectra.py:372:read_spectra: iotime 2.121 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:17:19.752997
# INFO:spectra.py:372:read_spectra: iotime 3.622 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:17:24.030631
# INFO:spectra.py:372:read_spectra: iotime 2.280 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:17:28.101882
# INFO:spectra.py:372:read_spectra: iotime 0.721 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:17:31.656464
# INFO:spectra.py:372:read_spectra: iotime 2.298 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:17:34.332675
# INFO:spectra.py:372:read_spectra: iotime 0.768 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:17:37.390796
# INFO:spectra.py:372:read_spectra: iotime 0.863 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:17:38.995310
# INFO:spectra.py:372:read_spectra: iotime 2.750 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:17:41.968495
# INFO:spectra.py:372:read_spectra: iotime 2.167 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:17:46.220198
# INFO:spectra.py:372:read_spectra: iotime 0.657 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:17:50.391943
# INFO:spectra.py:372:read_spectra: iotime 0.716 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:17:51.420281
# INFO:spectra.py:372:read_spectra: iotime 1.487 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:17:53.089195
# INFO:spectra.py:372:read_spectra: iotime 2.175 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:17:56.541125
# INFO:spectra.py:372:read_spectra: iotime 0.690 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:17:59.769156
# INFO:spectra.py:372:read_spectra: iotime 0.873 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:18:00.929948
# INFO:spectra.py:372:read_spectra: iotime 1.142 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:18:02.434145
# INFO:spectra.py:372:read_spectra: iotime 0.835 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:18:04.044545
# INFO:spectra.py:372:read_spectra: iotime 0.775 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:18:05.043113
# INFO:spectra.py:372:read_spectra: iotime 3.133 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:18:08.730408
# INFO:spectra.py:372:read_spectra: iotime 3.605 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:18:13.666759
# INFO:spectra.py:372:read_spectra: iotime 1.546 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:18:18.078945
# INFO:spectra.py:372:read_spectra: iotime 0.606 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:18:20.628176
# INFO:spectra.py:372:read_spectra: iotime 1.900 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:18:22.748616
# INFO:spectra.py:372:read_spectra: iotime 0.856 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:18:25.948858
# INFO:spectra.py:372:read_spectra: iotime 2.191 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:18:28.633900
# INFO:spectra.py:372:read_spectra: iotime 1.025 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:18:31.945506
# INFO:spectra.py:372:read_spectra: iotime 1.340 sec to read coadd-sv3-dark-10152.fits at 2024-01-08T00:18:33.712105
# INFO:spectra.py:372:read_spectra: iotime 2.636 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:18:36.669806
# INFO:spectra.py:372:read_spectra: iotime 1.172 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:18:40.185971
# INFO:spectra.py:372:read_spectra: iotime 3.068 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:18:43.866985
# INFO:spectra.py:372:read_spectra: iotime 0.792 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:18:47.839537
# INFO:spectra.py:372:read_spectra: iotime 0.154 sec to read coadd-sv1-other-11524.fits at 2024-01-08T00:18:48.359911
# INFO:spectra.py:372:read_spectra: iotime 2.122 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:18:50.557363
# INFO:spectra.py:372:read_spectra: iotime 3.594 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:18:56.087240
# INFO:spectra.py:372:read_spectra: iotime 3.864 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:19:02.446059
# INFO:spectra.py:372:read_spectra: iotime 1.164 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:19:05.176070
# INFO:spectra.py:372:read_spectra: iotime 0.882 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:19:06.806597
# INFO:spectra.py:372:read_spectra: iotime 3.328 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:19:11.503215
# INFO:spectra.py:372:read_spectra: iotime 2.228 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T00:19:17.527734
# INFO:spectra.py:372:read_spectra: iotime 3.971 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:19:24.406270
# INFO:spectra.py:372:read_spectra: iotime 1.425 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:19:29.719879
# INFO:spectra.py:372:read_spectra: iotime 2.859 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:19:33.738129
# INFO:spectra.py:372:read_spectra: iotime 0.727 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:19:37.587928
# INFO:spectra.py:372:read_spectra: iotime 1.309 sec to read coadd-sv3-dark-10152.fits at 2024-01-08T00:19:39.879704
# INFO:spectra.py:372:read_spectra: iotime 1.884 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:19:43.119279
# INFO:spectra.py:372:read_spectra: iotime 1.833 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:19:46.386881
# INFO:spectra.py:372:read_spectra: iotime 1.556 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:19:49.225533
# INFO:spectra.py:372:read_spectra: iotime 0.818 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:19:50.650707
# INFO:spectra.py:372:read_spectra: iotime 1.442 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:19:52.419813
# INFO:spectra.py:372:read_spectra: iotime 2.843 sec to read coadd-sv3-dark-11520.fits at 2024-01-08T00:19:56.422892
# INFO:spectra.py:372:read_spectra: iotime 0.955 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:19:59.445370
# INFO:spectra.py:372:read_spectra: iotime 2.663 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:20:03.433402
# INFO:spectra.py:372:read_spectra: iotime 1.224 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:20:06.651591
# INFO:spectra.py:372:read_spectra: iotime 2.575 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:20:10.955071
# INFO:spectra.py:372:read_spectra: iotime 3.381 sec to read coadd-sv3-dark-11520.fits at 2024-01-08T00:20:17.923898
# INFO:spectra.py:372:read_spectra: iotime 3.551 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:20:24.080986
# INFO:spectra.py:372:read_spectra: iotime 3.933 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:20:30.101703
# INFO:spectra.py:372:read_spectra: iotime 0.684 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:20:34.809734
# INFO:spectra.py:372:read_spectra: iotime 0.977 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:20:37.195718
# INFO:spectra.py:372:read_spectra: iotime 1.323 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:20:39.308878
# INFO:spectra.py:372:read_spectra: iotime 3.545 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:20:43.824846
# INFO:spectra.py:372:read_spectra: iotime 2.944 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:20:49.777862
# INFO:spectra.py:372:read_spectra: iotime 4.362 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:20:56.490039
# INFO:spectra.py:372:read_spectra: iotime 3.753 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:21:05.317165
# INFO:spectra.py:372:read_spectra: iotime 3.447 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:21:12.495230
# INFO:spectra.py:372:read_spectra: iotime 0.397 sec to read coadd-sv3-bright-10151.fits at 2024-01-08T00:21:16.773281
# INFO:spectra.py:372:read_spectra: iotime 3.967 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:21:21.140600
# INFO:spectra.py:372:read_spectra: iotime 1.158 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:21:26.337096
# INFO:spectra.py:372:read_spectra: iotime 0.649 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:21:28.823895
# INFO:spectra.py:372:read_spectra: iotime 4.195 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T00:21:33.245936
# INFO:spectra.py:372:read_spectra: iotime 3.585 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:21:39.615165
# INFO:spectra.py:372:read_spectra: iotime 0.895 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:21:44.633419
# INFO:spectra.py:372:read_spectra: iotime 2.319 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:21:47.808109
# INFO:spectra.py:372:read_spectra: iotime 2.124 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:21:52.466125
# INFO:spectra.py:372:read_spectra: iotime 3.005 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:21:57.594335
# INFO:spectra.py:372:read_spectra: iotime 1.235 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:22:02.073181
# INFO:spectra.py:372:read_spectra: iotime 0.936 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:22:04.466605
# INFO:spectra.py:372:read_spectra: iotime 3.629 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:22:08.358387
# INFO:spectra.py:372:read_spectra: iotime 0.817 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:22:12.919121
# INFO:spectra.py:372:read_spectra: iotime 3.010 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:22:17.276276
# INFO:spectra.py:372:read_spectra: iotime 0.972 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:22:21.893781
# INFO:spectra.py:372:read_spectra: iotime 5.327 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:22:27.932782
# INFO:spectra.py:372:read_spectra: iotime 2.852 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:22:34.638908
# INFO:spectra.py:372:read_spectra: iotime 1.147 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:22:38.016618
# INFO:spectra.py:372:read_spectra: iotime 2.094 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:22:41.419064
# INFO:spectra.py:372:read_spectra: iotime 3.309 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:22:46.046689
# INFO:spectra.py:372:read_spectra: iotime 0.580 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:22:49.151106
# INFO:spectra.py:372:read_spectra: iotime 0.781 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:22:50.882527
# INFO:spectra.py:372:read_spectra: iotime 2.707 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:22:54.609788
# INFO:spectra.py:372:read_spectra: iotime 3.378 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:23:02.051331
# INFO:spectra.py:372:read_spectra: iotime 0.382 sec to read coadd-sv3-bright-10151.fits at 2024-01-08T00:23:06.872109
# INFO:spectra.py:372:read_spectra: iotime 2.858 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:23:09.994728
# INFO:spectra.py:372:read_spectra: iotime 1.459 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:23:13.371681
# INFO:spectra.py:372:read_spectra: iotime 0.497 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:23:15.653954
# INFO:spectra.py:372:read_spectra: iotime 0.774 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:23:16.675394
# INFO:spectra.py:372:read_spectra: iotime 3.708 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:23:21.411603
# INFO:spectra.py:372:read_spectra: iotime 0.917 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:23:23.676266
# INFO:spectra.py:372:read_spectra: iotime 2.921 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:23:27.947046
# INFO:spectra.py:372:read_spectra: iotime 3.567 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:23:34.566962
# INFO:spectra.py:372:read_spectra: iotime 3.463 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:23:41.699737
# INFO:spectra.py:372:read_spectra: iotime 1.106 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:23:47.156782
# INFO:spectra.py:372:read_spectra: iotime 1.415 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:23:50.691739
# INFO:spectra.py:372:read_spectra: iotime 2.579 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:23:53.785747
# INFO:spectra.py:372:read_spectra: iotime 1.188 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:23:58.899380
# INFO:spectra.py:372:read_spectra: iotime 1.350 sec to read coadd-sv3-dark-10152.fits at 2024-01-08T00:24:01.138222
# INFO:spectra.py:372:read_spectra: iotime 0.811 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:24:02.416976
# INFO:spectra.py:372:read_spectra: iotime 1.434 sec to read coadd-sv3-backup-10158.fits at 2024-01-08T00:24:04.379974
# INFO:spectra.py:372:read_spectra: iotime 3.008 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:24:07.803387
# INFO:spectra.py:372:read_spectra: iotime 2.648 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:24:12.860666
# INFO:spectra.py:372:read_spectra: iotime 2.491 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:24:18.245058
# INFO:spectra.py:372:read_spectra: iotime 1.494 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:24:21.396782
# INFO:spectra.py:372:read_spectra: iotime 0.842 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:24:23.565513
# INFO:spectra.py:372:read_spectra: iotime 1.854 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:24:25.663534
# INFO:spectra.py:372:read_spectra: iotime 0.708 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:24:28.446418
# INFO:spectra.py:372:read_spectra: iotime 1.247 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:24:29.964768
# INFO:spectra.py:372:read_spectra: iotime 0.605 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:24:31.364088
# INFO:spectra.py:372:read_spectra: iotime 3.593 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:24:35.416708
# INFO:spectra.py:372:read_spectra: iotime 5.361 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T00:24:43.649047
# INFO:spectra.py:372:read_spectra: iotime 4.015 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:24:51.221824
# INFO:spectra.py:372:read_spectra: iotime 4.551 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:25:00.326944
# INFO:spectra.py:372:read_spectra: iotime 2.274 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:25:07.360444
# INFO:spectra.py:372:read_spectra: iotime 0.835 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:25:11.865171
# INFO:spectra.py:372:read_spectra: iotime 1.394 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:25:13.658566
# INFO:spectra.py:372:read_spectra: iotime 0.527 sec to read coadd-sv3-backup-11520.fits at 2024-01-08T00:25:15.047312
# INFO:spectra.py:372:read_spectra: iotime 1.530 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:25:16.812985
# INFO:spectra.py:372:read_spectra: iotime 0.919 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:25:18.524959
# INFO:spectra.py:372:read_spectra: iotime 0.495 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:25:20.441854
# INFO:spectra.py:372:read_spectra: iotime 0.733 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:25:21.362674
# INFO:spectra.py:372:read_spectra: iotime 3.521 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:25:25.154982
# INFO:spectra.py:372:read_spectra: iotime 0.716 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:25:29.180083
# INFO:spectra.py:372:read_spectra: iotime 0.637 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:25:30.341400
# INFO:spectra.py:372:read_spectra: iotime 1.653 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:25:32.191272
# INFO:spectra.py:372:read_spectra: iotime 1.270 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:25:34.597047
# INFO:spectra.py:372:read_spectra: iotime 0.735 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:25:36.799204
# INFO:spectra.py:372:read_spectra: iotime 2.625 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:25:39.670781
# INFO:spectra.py:372:read_spectra: iotime 0.682 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:25:43.373612
# INFO:spectra.py:372:read_spectra: iotime 0.656 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:25:44.634463
# INFO:spectra.py:372:read_spectra: iotime 0.870 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:25:45.671457
# INFO:spectra.py:372:read_spectra: iotime 0.803 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:25:46.682014
# INFO:spectra.py:372:read_spectra: iotime 0.911 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:25:47.949566
# INFO:spectra.py:372:read_spectra: iotime 3.375 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:25:51.674829
# INFO:spectra.py:372:read_spectra: iotime 0.934 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:25:56.022944
# INFO:spectra.py:372:read_spectra: iotime 0.926 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:25:58.860727
# INFO:spectra.py:372:read_spectra: iotime 0.917 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:26:00.086465
# INFO:spectra.py:372:read_spectra: iotime 1.061 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:26:01.386316
# INFO:spectra.py:372:read_spectra: iotime 0.930 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:26:02.952183
# INFO:spectra.py:372:read_spectra: iotime 4.080 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:26:08.218768
# INFO:spectra.py:372:read_spectra: iotime 1.407 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:26:12.688184
# INFO:spectra.py:372:read_spectra: iotime 0.773 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:26:14.398151
# INFO:spectra.py:372:read_spectra: iotime 4.258 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:26:19.743138
# INFO:spectra.py:372:read_spectra: iotime 2.741 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:26:25.567788
# INFO:spectra.py:372:read_spectra: iotime 0.761 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:26:30.152898
# INFO:spectra.py:372:read_spectra: iotime 0.894 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:26:32.101641
# INFO:spectra.py:372:read_spectra: iotime 4.676 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:26:37.010408
# INFO:spectra.py:372:read_spectra: iotime 1.305 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:26:40.994878
# INFO:spectra.py:372:read_spectra: iotime 1.463 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:26:44.035097
# INFO:spectra.py:372:read_spectra: iotime 3.761 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:26:48.589589
# INFO:spectra.py:372:read_spectra: iotime 4.369 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:26:55.901810
# INFO:spectra.py:372:read_spectra: iotime 2.747 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:27:02.588245
# INFO:spectra.py:372:read_spectra: iotime 2.454 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:27:07.538555
# INFO:spectra.py:372:read_spectra: iotime 3.502 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:27:13.809508
# INFO:spectra.py:372:read_spectra: iotime 0.775 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:27:16.837797
# INFO:spectra.py:372:read_spectra: iotime 2.384 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:27:19.994051
# INFO:spectra.py:372:read_spectra: iotime 3.772 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:27:25.090046
# INFO:spectra.py:372:read_spectra: iotime 4.523 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:27:34.877463
# INFO:spectra.py:372:read_spectra: iotime 3.426 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:27:41.181113
# INFO:spectra.py:372:read_spectra: iotime 0.809 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:27:45.479940
# INFO:spectra.py:372:read_spectra: iotime 2.231 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:27:49.389541
# INFO:spectra.py:372:read_spectra: iotime 4.834 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:27:56.950800
# INFO:spectra.py:372:read_spectra: iotime 1.545 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:28:02.636467
# INFO:spectra.py:372:read_spectra: iotime 0.827 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:28:05.042453
# INFO:spectra.py:372:read_spectra: iotime 1.262 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:28:07.501426
# INFO:spectra.py:372:read_spectra: iotime 1.822 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:28:10.809935
# INFO:spectra.py:372:read_spectra: iotime 4.188 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T00:28:15.940337
# INFO:spectra.py:372:read_spectra: iotime 3.712 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T00:28:23.041499
# INFO:spectra.py:372:read_spectra: iotime 0.904 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:28:28.394156
# INFO:spectra.py:372:read_spectra: iotime 0.790 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:28:29.702575
# INFO:spectra.py:372:read_spectra: iotime 3.074 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:28:33.001923
# INFO:spectra.py:372:read_spectra: iotime 3.750 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T00:28:39.979043
# INFO:spectra.py:372:read_spectra: iotime 3.912 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:28:46.092841
# INFO:spectra.py:372:read_spectra: iotime 0.626 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:28:50.286392
# INFO:spectra.py:372:read_spectra: iotime 2.997 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:28:53.784605
# INFO:spectra.py:372:read_spectra: iotime 3.586 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:28:59.894662
# INFO:spectra.py:372:read_spectra: iotime 3.987 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:29:07.498204
# INFO:spectra.py:372:read_spectra: iotime 2.456 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:29:12.594854
# INFO:spectra.py:372:read_spectra: iotime 1.113 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:29:18.431819
# INFO:spectra.py:372:read_spectra: iotime 0.692 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:29:20.659175
# INFO:spectra.py:372:read_spectra: iotime 3.449 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:29:24.360281
# INFO:spectra.py:372:read_spectra: iotime 3.959 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:29:31.513475
# INFO:spectra.py:372:read_spectra: iotime 0.616 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:29:34.618916
# INFO:spectra.py:372:read_spectra: iotime 0.701 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:29:35.614933
# INFO:spectra.py:372:read_spectra: iotime 3.337 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:29:39.116893
# INFO:spectra.py:372:read_spectra: iotime 4.306 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:29:46.914503
# INFO:spectra.py:372:read_spectra: iotime 3.662 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:29:54.023020
# INFO:spectra.py:372:read_spectra: iotime 4.051 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:30:03.150332
# INFO:spectra.py:372:read_spectra: iotime 2.863 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:30:10.256808
# INFO:spectra.py:372:read_spectra: iotime 3.653 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:30:17.323020
# INFO:spectra.py:372:read_spectra: iotime 0.863 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:30:23.671226
# INFO:spectra.py:372:read_spectra: iotime 2.638 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:30:27.216545
# INFO:spectra.py:372:read_spectra: iotime 3.044 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:30:32.990359
# INFO:spectra.py:372:read_spectra: iotime 4.462 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:30:41.561225
# INFO:spectra.py:372:read_spectra: iotime 3.824 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:30:50.288707
# INFO:spectra.py:372:read_spectra: iotime 3.764 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:30:57.164757
# INFO:spectra.py:372:read_spectra: iotime 0.391 sec to read coadd-sv3-dark-10151.fits at 2024-01-08T00:31:01.919133
# INFO:spectra.py:372:read_spectra: iotime 2.667 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:31:04.909338
# INFO:spectra.py:372:read_spectra: iotime 2.696 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:31:12.131377
# INFO:spectra.py:372:read_spectra: iotime 3.562 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:31:19.219761
# INFO:spectra.py:372:read_spectra: iotime 3.680 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:31:25.753717
# INFO:spectra.py:372:read_spectra: iotime 0.657 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:31:29.992970
# INFO:spectra.py:372:read_spectra: iotime 0.612 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:31:30.912056
# INFO:spectra.py:372:read_spectra: iotime 2.701 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:31:33.770699
# INFO:spectra.py:372:read_spectra: iotime 3.582 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:31:40.543001
# INFO:spectra.py:372:read_spectra: iotime 0.842 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:31:44.515297
# INFO:spectra.py:372:read_spectra: iotime 1.786 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:31:46.763943
# INFO:spectra.py:372:read_spectra: iotime 2.566 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:31:51.755809
# INFO:spectra.py:372:read_spectra: iotime 2.322 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:31:56.793492
# INFO:spectra.py:372:read_spectra: iotime 0.936 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:32:00.691601
# INFO:spectra.py:372:read_spectra: iotime 2.614 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T00:32:04.911096
# INFO:spectra.py:372:read_spectra: iotime 1.194 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:32:09.463323
# INFO:spectra.py:372:read_spectra: iotime 3.189 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:32:13.818120
# INFO:spectra.py:372:read_spectra: iotime 1.246 sec to read coadd-sv3-dark-11524.fits at 2024-01-08T00:32:17.971265
# INFO:spectra.py:372:read_spectra: iotime 0.817 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:32:20.943126
# INFO:spectra.py:372:read_spectra: iotime 3.291 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:32:24.519882
# INFO:spectra.py:372:read_spectra: iotime 0.771 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:32:28.141002
# INFO:spectra.py:372:read_spectra: iotime 0.909 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:32:29.383142
# INFO:spectra.py:372:read_spectra: iotime 2.760 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:32:33.152252
# INFO:spectra.py:372:read_spectra: iotime 3.879 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T00:32:39.426891
# INFO:spectra.py:372:read_spectra: iotime 0.660 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:32:43.624815
# INFO:spectra.py:372:read_spectra: iotime 4.129 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:32:48.148715
# INFO:spectra.py:372:read_spectra: iotime 4.245 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:32:54.543901
# INFO:spectra.py:372:read_spectra: iotime 3.840 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:33:01.522938
# INFO:spectra.py:372:read_spectra: iotime 0.878 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:33:07.140760
# INFO:spectra.py:372:read_spectra: iotime 2.283 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:33:11.593319
# INFO:spectra.py:372:read_spectra: iotime 0.358 sec to read coadd-sv3-bright-10151.fits at 2024-01-08T00:33:14.872099
# INFO:spectra.py:372:read_spectra: iotime 0.915 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:33:15.999149
# INFO:spectra.py:372:read_spectra: iotime 0.814 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:33:17.050162
# INFO:spectra.py:372:read_spectra: iotime 3.757 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T00:33:21.065420
# INFO:spectra.py:372:read_spectra: iotime 2.851 sec to read coadd-sv3-dark-11520.fits at 2024-01-08T00:33:26.590238
# INFO:spectra.py:372:read_spectra: iotime 0.972 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:33:30.664304
# INFO:spectra.py:372:read_spectra: iotime 0.695 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:33:32.544159
# INFO:spectra.py:372:read_spectra: iotime 0.848 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:33:33.598815
# INFO:spectra.py:372:read_spectra: iotime 2.197 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:33:36.761618
# INFO:spectra.py:372:read_spectra: iotime 3.186 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:33:41.530537
# INFO:spectra.py:372:read_spectra: iotime 1.383 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:33:46.290184
# INFO:spectra.py:372:read_spectra: iotime 0.177 sec to read coadd-sv1-other-11524.fits at 2024-01-08T00:33:47.770950
# INFO:spectra.py:372:read_spectra: iotime 2.467 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:33:50.329227
# INFO:spectra.py:372:read_spectra: iotime 3.096 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:33:56.532137
# INFO:spectra.py:372:read_spectra: iotime 3.459 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:34:05.244700
# INFO:spectra.py:372:read_spectra: iotime 3.239 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:34:12.251217
# INFO:spectra.py:372:read_spectra: iotime 1.159 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:34:18.059245
# INFO:spectra.py:372:read_spectra: iotime 1.975 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:34:22.243001
# INFO:spectra.py:372:read_spectra: iotime 3.676 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:34:28.191860
# INFO:spectra.py:372:read_spectra: iotime 3.361 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:34:35.293278
# INFO:spectra.py:372:read_spectra: iotime 0.966 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:34:38.686976
# INFO:spectra.py:372:read_spectra: iotime 3.361 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:34:42.402805
# INFO:spectra.py:372:read_spectra: iotime 0.685 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:34:46.378396
# INFO:spectra.py:372:read_spectra: iotime 3.451 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:34:50.150588
# INFO:spectra.py:372:read_spectra: iotime 2.574 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:34:56.798821
# INFO:spectra.py:372:read_spectra: iotime 0.137 sec to read coadd-sv1-other-10151.fits at 2024-01-08T00:35:00.438749
# INFO:spectra.py:372:read_spectra: iotime 2.746 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:35:03.457480
# INFO:spectra.py:372:read_spectra: iotime 4.525 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:35:11.338082
# INFO:spectra.py:372:read_spectra: iotime 1.930 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:35:16.567138
# INFO:spectra.py:372:read_spectra: iotime 0.674 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:35:18.000802
# INFO:spectra.py:372:read_spectra: iotime 0.956 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:35:19.187795
# INFO:spectra.py:372:read_spectra: iotime 4.184 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:35:23.598099
# INFO:spectra.py:372:read_spectra: iotime 1.297 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:35:28.163962
# INFO:spectra.py:372:read_spectra: iotime 1.183 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:35:31.445720
# INFO:spectra.py:372:read_spectra: iotime 2.429 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:35:35.189753
# INFO:spectra.py:372:read_spectra: iotime 0.701 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:35:39.147697
# INFO:spectra.py:372:read_spectra: iotime 0.617 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:35:40.116938
# INFO:spectra.py:372:read_spectra: iotime 3.562 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:35:43.861187
# INFO:spectra.py:372:read_spectra: iotime 1.485 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:35:49.502241
# INFO:spectra.py:372:read_spectra: iotime 1.380 sec to read coadd-sv3-dark-10152.fits at 2024-01-08T00:35:53.084251
# INFO:spectra.py:372:read_spectra: iotime 0.975 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:35:55.757890
# INFO:spectra.py:372:read_spectra: iotime 0.822 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:35:57.701275
# ...
# INFO:spectra.py:372:read_spectra: iotime 2.511 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T01:13:58.688196
# INFO:spectra.py:372:read_spectra: iotime 1.060 sec to read coadd-sv1-other-10153.fits at 2024-01-08T01:14:02.323570
# INFO:spectra.py:372:read_spectra: iotime 2.577 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T01:14:05.307396
# INFO:spectra.py:372:read_spectra: iotime 0.513 sec to read coadd-sv1-other-10152.fits at 2024-01-08T01:14:07.582687
# INFO:spectra.py:372:read_spectra: iotime 0.864 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T01:14:08.863058
# INFO:spectra.py:372:read_spectra: iotime 0.731 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:14:09.809812
# INFO:spectra.py:372:read_spectra: iotime 2.487 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T01:14:12.479176
# INFO:spectra.py:372:read_spectra: iotime 0.402 sec to read coadd-sv3-bright-10151.fits at 2024-01-08T01:14:15.218426
# INFO:spectra.py:372:read_spectra: iotime 3.104 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T01:14:18.610189
# INFO:spectra.py:372:read_spectra: iotime 2.363 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T01:14:23.382976
# INFO:spectra.py:372:read_spectra: iotime 1.966 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T01:14:27.674519
# INFO:spectra.py:372:read_spectra: iotime 2.761 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:14:31.061935
# INFO:spectra.py:372:read_spectra: iotime 0.800 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:14:34.550000
# INFO:spectra.py:372:read_spectra: iotime 3.047 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T01:14:37.924869
# INFO:spectra.py:372:read_spectra: iotime 0.664 sec to read coadd-sv1-other-11520.fits at 2024-01-08T01:14:39.840968
# INFO:spectra.py:372:read_spectra: iotime 1.757 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T01:14:41.821181
# INFO:spectra.py:372:read_spectra: iotime 3.614 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T01:14:45.922798
# INFO:spectra.py:372:read_spectra: iotime 2.540 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T01:14:51.247063
# INFO:spectra.py:372:read_spectra: iotime 1.995 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T01:14:56.203467
# INFO:spectra.py:372:read_spectra: iotime 2.052 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T01:14:59.416629
# INFO:spectra.py:372:read_spectra: iotime 1.712 sec to read coadd-sv3-dark-10152.fits at 2024-01-08T01:15:03.606273
# INFO:spectra.py:372:read_spectra: iotime 2.206 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:15:06.395423
# INFO:spectra.py:372:read_spectra: iotime 2.508 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:15:09.637236
# INFO:spectra.py:372:read_spectra: iotime 2.548 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:15:13.161193
# INFO:spectra.py:372:read_spectra: iotime 0.756 sec to read coadd-sv1-other-10150.fits at 2024-01-08T01:15:16.657614
# INFO:spectra.py:372:read_spectra: iotime 0.839 sec to read coadd-sv1-other-10156.fits at 2024-01-08T01:15:17.837845
# INFO:spectra.py:372:read_spectra: iotime 0.769 sec to read coadd-sv1-other-10154.fits at 2024-01-08T01:15:18.816633
# INFO:spectra.py:372:read_spectra: iotime 3.018 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:15:21.999753
# INFO:spectra.py:372:read_spectra: iotime 2.396 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:15:26.695836
# INFO:spectra.py:372:read_spectra: iotime 0.954 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T01:15:29.675374
# INFO:spectra.py:372:read_spectra: iotime 1.496 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:15:31.512318
# INFO:spectra.py:372:read_spectra: iotime 0.695 sec to read coadd-sv1-other-10155.fits at 2024-01-08T01:15:33.703421
# INFO:spectra.py:372:read_spectra: iotime 2.263 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:15:36.235075
# INFO:spectra.py:372:read_spectra: iotime 0.773 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:15:38.818299
# INFO:spectra.py:372:read_spectra: iotime 2.288 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:15:41.531077
# INFO:spectra.py:372:read_spectra: iotime 0.845 sec to read coadd-sv1-other-10152.fits at 2024-01-08T01:15:43.220537
# INFO:spectra.py:372:read_spectra: iotime 0.450 sec to read coadd-sv1-other-10152.fits at 2024-01-08T01:15:43.986515
# INFO:spectra.py:372:read_spectra: iotime 2.057 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T01:15:46.197814
# INFO:spectra.py:372:read_spectra: iotime 0.882 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T01:15:49.745662
# INFO:spectra.py:372:read_spectra: iotime 2.553 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T01:15:52.619032
# INFO:spectra.py:372:read_spectra: iotime 0.823 sec to read coadd-sv1-other-11520.fits at 2024-01-08T01:15:54.939620
# INFO:spectra.py:372:read_spectra: iotime 1.886 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T01:15:57.240836
# INFO:spectra.py:372:read_spectra: iotime 1.730 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:15:59.532624
# INFO:spectra.py:372:read_spectra: iotime 0.729 sec to read coadd-sv1-other-10154.fits at 2024-01-08T01:16:02.171831
# INFO:spectra.py:372:read_spectra: iotime 0.603 sec to read coadd-sv1-other-11520.fits at 2024-01-08T01:16:03.022275
# INFO:spectra.py:372:read_spectra: iotime 2.620 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T01:16:05.862824
# INFO:spectra.py:372:read_spectra: iotime 2.690 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T01:16:09.429610
# INFO:spectra.py:372:read_spectra: iotime 2.625 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:16:14.809256
# INFO:spectra.py:372:read_spectra: iotime 0.813 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:16:17.088588
# INFO:spectra.py:372:read_spectra: iotime 2.764 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:16:20.210544
# INFO:spectra.py:372:read_spectra: iotime 0.871 sec to read coadd-sv1-other-10147.fits at 2024-01-08T01:16:23.133582
# INFO:spectra.py:372:read_spectra: iotime 2.591 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:16:26.270042
# INFO:spectra.py:372:read_spectra: iotime 0.742 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:16:28.579189
# INFO:spectra.py:372:read_spectra: iotime 2.222 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:16:31.075494
# INFO:spectra.py:372:read_spectra: iotime 0.636 sec to read coadd-sv1-other-10155.fits at 2024-01-08T01:16:32.875145
# INFO:spectra.py:372:read_spectra: iotime 2.466 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:16:35.734288
# INFO:spectra.py:372:read_spectra: iotime 0.780 sec to read coadd-sv1-other-10154.fits at 2024-01-08T01:16:37.370028
# INFO:spectra.py:372:read_spectra: iotime 0.844 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T01:16:38.672206
# INFO:spectra.py:372:read_spectra: iotime 0.990 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T01:16:40.144489
# INFO:spectra.py:372:read_spectra: iotime 0.852 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:16:41.562572
# INFO:spectra.py:372:read_spectra: iotime 1.101 sec to read coadd-sv1-other-10156.fits at 2024-01-08T01:16:42.978829
# INFO:spectra.py:372:read_spectra: iotime 0.645 sec to read coadd-sv1-other-10154.fits at 2024-01-08T01:16:43.960390
# INFO:spectra.py:372:read_spectra: iotime 0.815 sec to read coadd-sv1-other-10153.fits at 2024-01-08T01:16:44.939700
# INFO:spectra.py:372:read_spectra: iotime 2.982 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:16:48.103088
# INFO:spectra.py:372:read_spectra: iotime 1.166 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T01:16:51.421040
# INFO:spectra.py:372:read_spectra: iotime 0.758 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:16:53.222544
# INFO:spectra.py:372:read_spectra: iotime 1.907 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T01:16:55.328784
# INFO:spectra.py:372:read_spectra: iotime 0.891 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:16:57.831154
# INFO:spectra.py:372:read_spectra: iotime 1.834 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T01:17:00.278177
# INFO:spectra.py:372:read_spectra: iotime 0.893 sec to read coadd-sv1-other-10150.fits at 2024-01-08T01:17:01.762181
# INFO:spectra.py:372:read_spectra: iotime 2.310 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T01:17:04.662192
# INFO:spectra.py:372:read_spectra: iotime 0.701 sec to read coadd-sv1-other-10154.fits at 2024-01-08T01:17:06.282029
# INFO:spectra.py:372:read_spectra: iotime 0.854 sec to read coadd-sv1-other-10153.fits at 2024-01-08T01:17:07.329202
# INFO:spectra.py:372:read_spectra: iotime 2.923 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:17:10.468067
# INFO:spectra.py:372:read_spectra: iotime 2.039 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T01:17:14.913119
# INFO:spectra.py:372:read_spectra: iotime 0.764 sec to read coadd-sv1-other-11521.fits at 2024-01-08T01:17:18.407139
# INFO:spectra.py:372:read_spectra: iotime 2.261 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:17:20.972256
# INFO:spectra.py:372:read_spectra: iotime 0.824 sec to read coadd-sv1-other-10155.fits at 2024-01-08T01:17:22.332451
# INFO:spectra.py:372:read_spectra: iotime 1.797 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:17:24.655653
# INFO:spectra.py:372:read_spectra: iotime 1.062 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T01:17:26.258649
# INFO:spectra.py:372:read_spectra: iotime 2.573 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:17:29.360536
# INFO:spectra.py:372:read_spectra: iotime 1.170 sec to read coadd-sv1-other-10156.fits at 2024-01-08T01:17:32.280709
# INFO:spectra.py:372:read_spectra: iotime 1.520 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:17:34.788227
# INFO:spectra.py:372:read_spectra: iotime 0.848 sec to read coadd-sv1-other-10156.fits at 2024-01-08T01:17:36.286304
# INFO:spectra.py:372:read_spectra: iotime 0.767 sec to read coadd-sv1-other-10154.fits at 2024-01-08T01:17:37.879349
# INFO:spectra.py:372:read_spectra: iotime 2.626 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T01:17:40.713174
# INFO:spectra.py:372:read_spectra: iotime 0.790 sec to read coadd-sv1-other-10156.fits at 2024-01-08T01:17:44.261874
# INFO:spectra.py:372:read_spectra: iotime 2.007 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T01:17:46.682283
# INFO:spectra.py:372:read_spectra: iotime 2.796 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:17:50.143445
# INFO:spectra.py:372:read_spectra: iotime 2.321 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T01:17:53.809944
# INFO:spectra.py:372:read_spectra: iotime 0.857 sec to read coadd-sv1-other-10153.fits at 2024-01-08T01:17:57.456285
# INFO:spectra.py:372:read_spectra: iotime 2.782 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T01:18:00.592639
# INFO:spectra.py:372:read_spectra: iotime 0.809 sec to read coadd-sv1-other-10155.fits at 2024-01-08T01:18:03.665667
# INFO:spectra.py:372:read_spectra: iotime 2.303 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T01:18:06.564735
# INFO:spectra.py:372:read_spectra: iotime 2.124 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:18:09.509009
# INFO:spectra.py:372:read_spectra: iotime 1.273 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T01:18:12.607045
# INFO:spectra.py:372:read_spectra: iotime 1.036 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T01:18:14.242181
# INFO:spectra.py:372:read_spectra: iotime 2.475 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:18:17.689887
# INFO:spectra.py:372:read_spectra: iotime 0.666 sec to read coadd-sv1-other-10155.fits at 2024-01-08T01:18:19.116797
# INFO:spectra.py:372:read_spectra: iotime 2.110 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T01:18:21.481721
# INFO:spectra.py:372:read_spectra: iotime 3.236 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:18:25.283216
# INFO:spectra.py:372:read_spectra: iotime 0.687 sec to read coadd-sv1-other-10154.fits at 2024-01-08T01:18:28.460004
# INFO:spectra.py:372:read_spectra: iotime 2.264 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:18:31.005312
# INFO:spectra.py:372:read_spectra: iotime 2.227 sec to read coadd-sv3-dark-11520.fits at 2024-01-08T01:18:35.367678
# INFO:spectra.py:372:read_spectra: iotime 1.440 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:18:38.950753
# INFO:spectra.py:372:read_spectra: iotime 2.717 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:18:42.779925
# INFO:spectra.py:372:read_spectra: iotime 0.723 sec to read coadd-sv1-other-10147.fits at 2024-01-08T01:18:45.635354
# INFO:spectra.py:372:read_spectra: iotime 1.477 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T01:18:47.415377
# INFO:spectra.py:372:read_spectra: iotime 3.535 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T01:18:51.294274
# INFO:spectra.py:372:read_spectra: iotime 3.455 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T01:18:57.417547
# INFO:spectra.py:372:read_spectra: iotime 2.222 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T01:19:02.863718
# INFO:spectra.py:372:read_spectra: iotime 2.225 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T01:19:07.113967
# INFO:spectra.py:372:read_spectra: iotime 2.562 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:19:11.915841
# INFO:spectra.py:372:read_spectra: iotime 2.985 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T01:19:16.439283
# INFO:spectra.py:372:read_spectra: iotime 1.993 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T01:19:19.974795
# INFO:spectra.py:372:read_spectra: iotime 2.951 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:19:24.870834
# INFO:spectra.py:372:read_spectra: iotime 2.598 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T01:19:30.494614
# INFO:spectra.py:372:read_spectra: iotime 2.644 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T01:19:36.023841
# INFO:spectra.py:372:read_spectra: iotime 2.789 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T01:19:41.285342
# flux_spec: [array([-11.28937244,  -0.4070347 ,  -6.82197905, ...,   0.83747911,
#           0.57543331,   0.4972958 ])
#  array([ 1.81746352, -0.78946561, -0.07341799, ...,  0.29147047,
#          0.18163522,  0.14387371])
#  array([0., 0., 0., ..., 0., 0., 0.]) ...
#  array([ 2.46674347, -6.36587811,  3.60687423, ...,  2.10618496,
#          2.37307835,  3.43578625])
#  array([ 2.83378649, -4.82915545, -4.53505945, ...,  0.62093663,
#          0.79899746,  1.06793046])
#  array([ 3.44056249, -2.06579065, -2.5075953 , ...,  4.85956955,
#          4.4025383 ,  3.32670712])                              ]
# zbin: [(-0.0019957014509158224, 2.137936031868901)]
# 1
# Number of spectra to stack =  1049
# -0.0019957014509158224 2.137936031868901
# flux= [array([-11.28937244,  -0.4070347 ,  -6.82197905, ...,   0.83747911,
#           0.57543331,   0.4972958 ])
#  array([ 1.81746352, -0.78946561, -0.07341799, ...,  0.29147047,
#          0.18163522,  0.14387371])
#  array([0., 0., 0., ..., 0., 0., 0.]) ...
#  array([ 2.46674347, -6.36587811,  3.60687423, ...,  2.10618496,
#          2.37307835,  3.43578625])
#  array([ 2.83378649, -4.82915545, -4.53505945, ...,  0.62093663,
#          0.79899746,  1.06793046])
#  array([ 3.44056249, -2.06579065, -2.5075953 , ...,  4.85956955,
#          4.4025383 ,  3.32670712])                              ]
# Spectra corrected for foreground extinction.
# flux_new: [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ...  0.  0. nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Fnorm: [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# /Users/s2537809/Documents/DESI-STACKING/stack_code.py:248: RuntimeWarning: invalid value encountered in divide
#   Fnorm = flux_new / np.median(flux_new[:, norm_range], axis=1, keepdims=True)
# Stack[0]: [nan nan nan ... nan nan nan]
# Stack[1]: [nan nan nan ... nan nan nan]
# Stack[2]: [ 1.  1.  1. ... 85. 85. 43.]

# %% [markdown]
# ## Plot Stacked Spectra

# %%
plt.figure(figsize=(20,6))
plt.plot(SFG_stack['zbin=0']['wln'],SFG_stack['zbin=0']['flux'], color='purple', alpha=0.5, label = f'DESI {Overall_class} Stacked Spectra Low SFR 1')
plt.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
plt.ylim(-5,12)
plt.legend()

# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-plots-low_sfr_1.pdf'
with PdfPages(pdf_filename) as pdf:
        fig, ax = plt.subplots(figsize=(12, 8))
        ax.plot(SFG_stack['zbin=0']['wln'],SFG_stack['zbin=0']['flux'], color='purple', alpha=0.5,label = f'DESI {Overall_class} Stacked Spectra Low SFR 1')
        ax.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
        ax.set_xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
        ax.legend()

     # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# All the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')
# Out:
# All plots saved in DESI-SFG-stacked-plots-low_sfr_1.pdf
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]

# %%
#not sure if boundarys are consistent to do this



wavelength = SFG_stack['zbin=0']['wln']
flux = SFG_stack['zbin=0']['flux']

plt.figure(figsize=(20, 6))
plt.plot(wavelength[wavelength <= 5800], flux[wavelength <= 5800], color='blue', alpha=0.5)
plt.plot(wavelength[(wavelength > 5760) & (wavelength <= 7620)], flux[(wavelength > 5760) & (wavelength <= 7620)], color='green', alpha=0.5)
plt.plot(wavelength[wavelength > 7520], flux[wavelength > 7520], color='red', alpha=0.5)
plt.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
plt.xlim(1000,9900)
plt.show()

# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-plots-practice.pdf'
with PdfPages(pdf_filename) as pdf:
        fig, ax = plt.subplots(figsize=(20, 6))
        ax.plot(wavelength[wavelength <= 5800], flux[wavelength <= 5800], color='blue', alpha=0.5)
        ax.plot(wavelength[(wavelength > 5760) & (wavelength <= 7620)], flux[(wavelength > 5760) & (wavelength <= 7620)], color='green', alpha=0.5)
        ax.plot(wavelength[wavelength > 7520], flux[wavelength > 7520], color='red', alpha=0.5)
        ax.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
        ax.set_xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
        ax.set_xlim(3500,9900)

     # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# All the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')


### it appears that the problem is with the second half of the rqagn then ?? 
## it is the specifc values and not the size of the range ???
# Out:
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# All plots saved in DESI-SFG-stacked-plots-practice.pdf

# %%
"""

The lack of simulated correction might be having an impact ?
Need to use different redshift bins - why does DESI have negative redshifts?
Why is there such a difference between the bins?

"""


plt.figure(figsize=(20,6))
plt.plot(SFG_stacks['zbin=0']['wln'],SFG_stacks['zbin=0']['flux'], label='0.0<z<0.5', color='yellow', alpha=0.5)
plt.plot(SFG_stacks['zbin=1']['wln'],SFG_stacks['zbin=1']['flux'], label='0.5<z<1.0', color='red', alpha=0.5)
plt.plot(SFG_stacks['zbin=2']['wln'],SFG_stacks['zbin=2']['flux'], label='1.0<z<4.0', color='green', alpha=0.5)
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
plt.legend()


# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-zbin-plots-practice.pdf'
with PdfPages(pdf_filename) as pdf:
        fig, ax = plt.subplots(figsize=(12, 8))
        ax.plot(SFG_stacks['zbin=0']['wln'],SFG_stacks['zbin=0']['flux'], label='0.0<z<0.5', color='yellow', alpha=0.5)
        ax.plot(SFG_stacks['zbin=1']['wln'],SFG_stacks['zbin=1']['flux'], label='0.5<z<1.0', color='red', alpha=0.5)
        ax.plot(SFG_stacks['zbin=2']['wln'],SFG_stacks['zbin=2']['flux'], label='1.0<z<4.0', color='green', alpha=0.5)
        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
        ax.set_xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
        ax.legend()
     # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# After the loop, all the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')
# Out:
# All plots saved in DESI-SFG-stacked-zbin-plots-practice.pdf
