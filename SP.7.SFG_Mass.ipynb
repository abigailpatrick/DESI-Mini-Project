# %% [markdown]
# # THIS CODE CONCATENATES WITH INVERSE VAR WEIGHTING

# %%
from astropy.table import Table, vstack, Column, MaskedColumn, pprint
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt
from astropy.convolution import convolve, Gaussian1DKernel

from astropy.io import fits
from matplotlib.backends.backend_pdf import PdfPages

import os
import requests
import sys
sys.path.append('/Users/s2537809/DESI/desispec/py')
sys.path.append('/Users/s2537809/DESI/desimodel/py')
sys.path.append('/Users/s2537809/DESI/desitarget/py')
sys.path.append('/Users/s2537809/DESI/desiutil/py')

#from desispec.io import read_spectra
# import DESI related modules - 
from desimodel.footprint import radec2pix      # For getting healpix values
import desispec.io                             # Input/Output functions related to DESI spectra
from desispec import coaddition                # Functions related to coadding the spectra


from scipy import interpolate
import astropy.units as u
path='/Users/s2537809/Documents/DESI-STACKING'#specify code directory
os.chdir(path)
import stack_code as sc
import importlib
import fnmatch
import extinction as ext
from scipy.optimize import curve_fit
from astropy.coordinates import SkyCoord
from astropy.modeling import models
from astropy.table import Table
from matplotlib import gridspec
import spectres
import time
import warnings

#pip install lmfit, extinction, sfdmap, spectres

import pandas as pd
crossmatch = Table.read('crossmatch_classifications.fits', format = 'fits' )
# Out:
# /Users/s2537809/DESI/desispec/py/desispec/qproc/qextract.py:19: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_extract(image_flux,image_var,x,hw=3) :
# /Users/s2537809/DESI/desispec/py/desispec/image_model.py:27: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_proj(image,x,sigma,flux) :
# /Users/s2537809/DESI/desispec/py/desispec/preproc.py:379: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_mean(image_flux,image_ivar,x,hw=3) :

# %% [markdown]
# ## Cell below verifies if Spectra are downloaded and downloads if they aren't
#
# Only run if unsure if spectra are downloaded, to save time!

# %%
"""
Note: The lengths for indexing are:

HERG = 184

RQAGN = 814

LERG = 1293

SFG = 6294

"""


Overall_class = 'SFG'
my_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][1000:1200]
search_column_name = 'TARGETID'
search_values = np.array(my_table[f'{search_column_name}'])



def select_data(table, column_name, search_values):
    # Get the column data as a numpy array
    column_data = table[column_name]

    SURVEY = []
    PROGRAM = []
    HEALPIX = []
    n_values = []
    Z = []
    

    for search_value in search_values:
        # Find the indices where the condition is met (value == search_value)
        indices = np.where(column_data == search_value)[0]


        if len(indices) > 0:
            # Find the corresponding Survey, program, healpix, and Z values
            SURVEY.append(table['SURVEY'][indices[0]])
            PROGRAM.append(table['PROGRAM'][indices[0]])
            HEALPIX.append(table['HEALPIX'][indices[0]])
            Z.append(table['Z'][indices[0]])
            HEALPIX_str = str(table['HEALPIX'][indices[0]])
            n_str = HEALPIX_str[:3]
            n_values.append(int(n_str))
        else:
            # Handle the case where the search value was not found
            SURVEY.append(None)
            PROGRAM.append(None)
            HEALPIX.append(None)
            n_values.append(None)
            Z.append(None)
    

    return np.array(SURVEY), np.array(PROGRAM), np.array(HEALPIX), np.array(n_values), np.array(Z), 


SURVEY = select_data(my_table, search_column_name, search_values)[0]
PROGRAM = select_data(my_table, search_column_name, search_values)[1]
HEALPIX = select_data(my_table, search_column_name, search_values)[2]
n = select_data(my_table, search_column_name, search_values)[3]
Z = select_data(my_table, search_column_name, search_values)[4]
print (SURVEY,PROGRAM,HEALPIX, n, Z)

for n, survey, program, healpix, Z, search_value in zip(n, SURVEY, PROGRAM, HEALPIX, Z, search_values):
        #download the file from the given Target ID
        target_url = f"https://data.desi.lbl.gov/public/edr/spectro/redux/fuji/healpix/{survey}/{program}/{n}/{healpix}/coadd-{survey}-{program}-{healpix}.fits"
        
        # Define the folder name and file name
        folder_name = 'DESI_Downloads'
        file_name = f"coadd-{survey}-{program}-{healpix}.fits"
        print(search_value)


        # Check if the folder exists, and create it if it doesn't
        if not os.path.exists(folder_name):
            os.makedirs(folder_name)

        # Check if the file exists in the folder
        file_path = os.path.join(folder_name, file_name)
        if os.path.exists(file_path):
            print(f"{file_name} already exists in {folder_name}. No need to download.")
        else:
            # File doesn't exist, download it
            try:
                response = requests.get(target_url)
                if response.status_code == 200:
                    with open(file_path, 'wb') as file:
                        file.write(response.content)
                    print(f"{file_name} downloaded to {folder_name}.")
                else:
                    print(f"Failed to download {file_name}. Status code: {response.status_code}")
            except Exception as e:
                print(f"An error occurred while downloading {file_name}: {str(e)}")
# Out:
# ['sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1' 'sv1'
#  'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv1' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1'
#  'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv1' 'sv1' 'sv1' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv1'
#  'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3'] ['bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright'
#  'bright' 'other' 'bright' 'bright' 'dark' 'other' 'other' 'bright'
#  'bright' 'dark' 'other' 'other' 'bright' 'bright' 'other' 'other'
#  'bright' 'other' 'dark' 'bright' 'bright' 'dark' 'bright' 'other' 'other'
#  'bright' 'other' 'other' 'other' 'bright' 'bright' 'other' 'bright'
#  'bright' 'bright' 'bright' 'other' 'other' 'other' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright'
#  'other' 'other' 'bright' 'dark' 'dark' 'bright' 'other' 'other' 'dark'
#  'other' 'bright' 'bright' 'bright' 'bright' 'bright' 'other' 'dark'
#  'dark' 'other' 'other' 'other' 'other' 'other' 'bright' 'other' 'bright'
#  'bright' 'other' 'dark' 'bright' 'bright' 'other' 'other' 'bright'
#  'other' 'other' 'bright' 'bright' 'other' 'dark' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'other' 'bright' 'bright' 'bright' 'bright'
#  'bright' 'other' 'bright' 'other' 'bright' 'bright' 'other' 'bright'
#  'bright' 'dark' 'bright' 'bright' 'bright' 'other' 'dark' 'other'
#  'bright' 'bright' 'bright' 'other' 'other' 'bright' 'other' 'other'
#  'bright' 'other' 'dark' 'bright' 'other' 'bright' 'dark' 'other' 'bright'
#  'other' 'other' 'other' 'bright' 'other' 'bright' 'other' 'bright' 'dark'
#  'bright' 'other' 'other' 'bright' 'bright' 'dark' 'bright' 'other'
#  'other' 'bright' 'bright' 'bright' 'dark' 'other' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'other' 'other' 'dark' 'bright' 'bright'
#  'bright' 'dark' 'bright' 'other' 'other' 'other' 'other' 'other' 'bright'
#  'bright' 'bright' 'dark' 'other' 'other' 'dark' 'bright' 'other' 'bright'
#  'bright' 'bright' 'dark' 'dark' 'other' 'bright' 'other' 'backup'
#  'backup'] [10152 10154 10152 11521 10154 11521 10152 10154 10154 11521 10154 11521
#  10152 11521 11521 10154 10154 10154 10152 10152 10154 10154 10154 10154
#  11521 10152 11521 10152 10152 10154 11521 10154 10154 10155 10154 10154
#  10152 10154 10154 10154 10154 11521 10154 10154 10154 10154 10154 11521
#  10154 11521 10152 10154 10154 11521 10154 11521 10154 11521 11521 10154
#  10152 11521 11521 11521 11521 10154 10152 10154 10154 11521 10154 10154
#  11521 10154 11521 10154 10154 10152 11521 10154 10154 10155 11521 11521
#  10152 11521 10154 10154 11521 10152 10154 10154 11521 11521 11521 10155
#  11521 11521 11521 10155 10154 11521 10154 11521 10154 11521 10154 11521
#  11521 11521 10154 11521 10154 10154 10154 11521 10155 10154 10152 11521
#  11521 10154 10154 10154 11521 10154 10152 11521 10154 10154 10154 11521
#  10152 10154 10154 11521 11521 11521 10154 11521 11521 10154 10155 10154
#  10154 11521 10154 10152 10152 10154 11521 11521 11521 10155 11521 11521
#  10154 10152 10155 10155 11521 11521 10154 11521 10154 10152 10155 10155
#  11521 10152 10154 10154 10154 10152 11521 10155 10152 10152 10152 10152
#  11521 11521 10152 10154 10154 11521 10152 10154 10152 11521 10154 10152
#  11521 10154 11521 11521 10154 10154 11521 10152] [101 101 101 115 101 115 101 101 101 115 101 115 101 115 115 101 101 101
#  101 101 101 101 101 101 115 101 115 101 101 101 115 101 101 101 101 101
#  101 101 101 101 101 115 101 101 101 101 101 115 101 115 101 101 101 115
#  101 115 101 115 115 101 101 115 115 115 115 101 101 101 101 115 101 101
#  115 101 115 101 101 101 115 101 101 101 115 115 101 115 101 101 115 101
#  101 101 115 115 115 101 115 115 115 101 101 115 101 115 101 115 101 115
#  115 115 101 115 101 101 101 115 101 101 101 115 115 101 101 101 115 101
#  101 115 101 101 101 115 101 101 101 115 115 115 101 115 115 101 101 101
#  101 115 101 101 101 101 115 115 115 101 115 115 101 101 101 101 115 115
#  101 115 101 101 101 101 115 101 101 101 101 101 115 101 101 101 101 101
#  115 115 101 101 101 115 101 101 101 115 101 101 115 101 115 115 101 101
#  115 101] [ 3.35145291e-01  2.47546395e-01  3.51474847e-01  2.13741842e-01
#   2.60245790e-01  2.46776309e-01  3.26101244e-01  3.50294377e-01
#   2.48664978e-01  2.30915676e-01  2.67320575e-01  2.51255934e-01
#   1.32054771e+00  4.66177402e-01  8.94670238e-01  2.64692571e-01
#   2.06842153e-01  1.18354918e+00  6.16881356e-01  9.71320367e-01
#   5.00949636e-01  1.43829866e-01  4.76371842e-01  1.18181335e+00
#   1.13551269e-01  9.56587148e-01  1.14206160e+00  4.20989635e-01
#   2.23063008e-01  2.62026642e-01  4.06392886e-01 -1.99570145e-03
#   1.61394631e+00  4.77336916e-01  3.45942222e-01  4.37611319e-01
#   1.18263070e+00  2.94771704e-01  3.26752756e-01 -1.99570145e-03
#   3.22729213e-01  2.25642234e-01  4.70261812e-01  2.60548780e-01
#   1.00551746e+00  9.03125446e-01  2.62803606e-01  4.15334710e-01
#   4.78697777e-02  3.01728664e-01  2.47619772e-01  2.12142287e-01
#   2.60254741e-01  2.51951408e-01  3.27000936e-01  2.40847110e-01
#   1.47463133e-01  8.06549617e-01  8.15919143e-01  4.65331591e-01
#   9.57477660e-01  7.52400543e-01  2.98955876e-01  4.92391271e-01
#  -1.99570145e-03  2.36904500e+00  6.47611703e-01  2.62972521e-01
#   2.65348851e-01  2.49709585e-01  2.10873257e-01  2.70182415e-01
#   5.72395385e-01  6.76710731e-01  7.10427329e-01  4.72487169e-01
#   1.25386578e+00  5.74550204e-01 -1.99570145e-03  6.12581395e-01
#   3.38195228e-01 -1.99570145e-03  2.53992626e-01  3.98017042e-01
#   9.58143966e-01  3.37176488e-01  2.75735084e-01  2.63472260e-01
#   7.59646502e-01  1.70988878e-01  2.38028642e-01  2.45220551e-01
#   6.64954428e-01  2.48519854e-01  4.06864414e-01  7.59687869e-01
#   7.37262654e-01  2.06402577e-01  3.37734549e-01  2.66866943e-01
#   2.10601248e-01  4.41680646e-01  4.52201856e-01  4.98444339e-02
#  -1.99569129e-03  2.31138140e-01  2.58271269e-01  4.40589866e-01
#   3.16568144e-01  1.07066125e-01  6.36902678e-01  3.23551450e-01
#   2.07949892e-01  1.42424417e+00  1.83040205e-01  2.28335580e-01
#   1.26313829e+00  2.36690044e-01  2.22107843e-01  2.89424617e-01
#  -1.99570145e-03  6.13595807e-01  3.46999254e-01  3.92465185e-01
#   4.06637584e-01  2.62197770e-01  2.22658176e-01  3.87577344e-01
#   8.31122973e-02  9.41927038e-01  3.19716211e-01  2.14372227e-01
#   1.01801308e+00  1.11760550e+00  4.17545529e-01  4.93845663e-01
#   3.03088749e-01  1.25986723e+00  4.30977354e-01  2.51786180e-01
#   3.33530562e-01 -1.99570145e-03  4.95964185e-01  2.65083905e-01
#   3.14700478e-01  4.04847697e-01  4.30283532e-01  2.57139736e-01
#   1.11580458e+00  1.47590864e-01  4.71829153e-01  4.28236748e-01
#   4.05566016e-01  2.63668566e-01  8.03809807e-01  3.28498005e-01
#   1.18411999e+00  5.55423332e-01  1.88907020e-01  1.88025265e-01
#   1.36714944e-01  1.36668873e+00  1.18389185e+00  3.87780029e-01
#   2.12478393e-01  3.26275299e-01  3.92941940e-01  2.60161886e-01
#   2.09195372e-01 -1.99570145e-03  5.30797823e-01  3.37288903e-01
#   2.08938025e-01  6.45889139e-02  6.52192040e-01  2.34304472e-01
#   1.18289867e+00  7.32124331e-01  3.48583331e-01  3.87177342e-01
#  -1.99570145e-03  3.03327379e-02  2.47141434e-01  9.23367520e-02
#   1.06122598e+00  3.41469365e-01  9.04649766e-01  8.86065561e-01
#   6.48397814e-02 -1.99570145e-03  3.35562472e-01  4.10595427e-02
#   1.45934177e-01  1.17756972e+00  1.14986790e+00  7.38655253e-01
#   2.43709265e-01  6.38046178e-01  4.95573579e-02  6.57485407e-02]
# 39633304823008514
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982975969
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396555936
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932938903
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468443875
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015647
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008573
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308396555958
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468443898
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008188
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468443902
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015678
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008590
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932938945
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015720
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976058
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936751
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538058
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008682
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308396556073
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633311944936784
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936786
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976100
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556087
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015757
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008714
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633329376463774
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308396556090
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633304823008722
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633315476538100
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015773
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538118
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 213624597512203
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444049
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633311944936838
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936850
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008798
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982976184
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976186
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936860
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444078
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008327
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444091
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538211
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556220
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936891
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936898
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939121
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944936897
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196401992
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008865
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633315476538259
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936944
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376463927
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976313
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402018
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976328
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015888
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939200
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976347
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556302
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402028
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376463948
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015908
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015912
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944936993
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008926
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982976389
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976403
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376463988
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444230
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944937038
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939274
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976442
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008466
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976450
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 213624597512196
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008991
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633332799015965
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538416
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538437
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939336
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633329376464089
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008514
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823009073
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932939360
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538476
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976557
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016060
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308396556500
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633311944937171
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538517
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016074
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016076
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402183
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444396
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633339577008598
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008627
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464206
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444490
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633315476538598
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402250
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976719
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464220
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976735
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008650
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976749
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939529
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008672
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464268
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944937314
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464266
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976782
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944937324
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538635
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016198
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444546
# coadd-sv3-dark-10155.fits already exists in DESI_Downloads. No need to download.
# 39633318982976791
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746553
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633329376464302
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016225
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976840
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976847
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444584
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464325
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538672
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746587
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402344
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538679
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976866
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976871
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939622
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308400746634
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746638
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538705
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016261
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016285
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939655
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538738
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464395
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016309
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127747
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939691
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633318982976981
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311949127768
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402452
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127790
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199794
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746719
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977050
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016358
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464481
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402481
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939767
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633325932939775
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402503
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538869
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199873
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633322468444756
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633322468444768
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633339577008893
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016400
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982977125
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016407
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127878
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199916
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633322468444809
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633322468444834
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633336196402570
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304827199972
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977255
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538991
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982977261
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746897
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577008995
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444890
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633308400746911
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746926
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746933
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633304827200045
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402641
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939926
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304827200056
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977346
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311949128018
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939952
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308400746994
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977418
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400747026
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577009097
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982977442
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827200127
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577009104
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949128097
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016602
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577009120
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476539133
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476539148
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 2305843021293300240
# coadd-sv3-backup-11521.fits already exists in DESI_Downloads. No need to download.
# 2305843019858848671
# coadd-sv3-backup-10152.fits already exists in DESI_Downloads. No need to download.

# %% [markdown]
# # Wavelength Overlap Regions Weighted Average

# %%
def inv_var_weighted_average(flux1, ivar1, flux2, ivar2):
    """
    Finds the inverse varience weighted average of two flux spectra
    
    """
    weight1 = 1 / ivar1
    weight2 = 1 / ivar2
    total_weight = weight1 + weight2
    weighted_flux1 = flux1 * (weight1 / total_weight)
    weighted_flux2 = flux2 * (weight2 / total_weight)
    weighted_avg = weighted_flux1 + weighted_flux2
    return weighted_avg

def no_overlap_f(waveb,fluxb,waver,fluxr,wavez,fluxz):
    """
    Isolates the flux and wavelength arrays of each band to non-overlapping wavelength sections
    
    """
    new_b_length = np.where(waveb<waver[0])
    b_wave = waveb[new_b_length]
    b_flux = fluxb[new_b_length]
    new_r_length = np.where((waver>waveb[-1])&(waver<wavez[0]))
    r_wave = waver[new_r_length]
    r_flux = fluxr[new_r_length]
    new_z_length = np.where(wavez>waver[-1])
    z_wave = wavez[new_z_length]
    z_flux = fluxz[new_z_length]

    return b_wave,b_flux,r_wave,r_flux,z_wave,z_flux


def overlap_av(wave1,wave2,flux1,flux2,ivar1,ivar2):
    """
    Finds the overlap of two wavelength ranges.
    Computes the inverse var weighted average flux and wavelength for th eoverlapping range 
    
    """
    overlap_idx_1 = np.where(wave1 >= wave2[0]) 
    overlap_wave = wave1[overlap_idx_1]
    overlap_flux_1 = flux1[overlap_idx_1]
    overlap_ivar_1 = ivar1[overlap_idx_1]

    overlap_idx_2 = np.where(wave2 <= wave1[-1]) 
    overlap_flux_2 = flux2[overlap_idx_2]
    overlap_ivar_2 = ivar2[overlap_idx_2]
    
    overlap_av_flux = inv_var_weighted_average(overlap_flux_1,overlap_ivar_1,overlap_flux_2,overlap_ivar_2)

    return overlap_av_flux, overlap_wave

# %% [markdown]
# # Stacking Functions

# %%
#stacking functions

# Ignore warnings due to spec_var=0
warnings.filterwarnings("ignore", message="divide by zero encountered in true_divide")


def get_spectra(table, column_name, search_values): 
    print('Number of spectra =', len(table))
    # Get the Target IDs as a numpy array
    column_data = table[column_name]

    SURVEY, PROGRAM, HEALPIX, n_values = [], [], [], []
    Z, RA, DEC, Source_ID = [], [], [], []


    for search_value in search_values:
        # Find the indices where the condition is met (value == search_value)
        # This is only relevant if input is doen by search value and not selected table
        indices = np.where(column_data == search_value)[0]

        if len(indices) > 0:
            # Find the corresponding Survey, program, healpix, Z , RA and Dec values
            SURVEY.append(table['SURVEY'][indices[0]])
            PROGRAM.append(table['PROGRAM'][indices[0]])
            HEALPIX.append(table['HEALPIX'][indices[0]])
            Z.append(table['Z'][indices[0]])
            RA.append(table['TARGET_RA'][indices[0]]) 
            DEC.append(table['TARGET_DEC'][indices[0]])
            Source_ID.append(table['TARGETID'][indices[0]])
            HEALPIX_str = str(table['HEALPIX'][indices[0]])
            n_str = HEALPIX_str[:3]
            n_values.append(int(n_str))
        else:
            # Handle the case where the search value was not found
            SURVEY.append(None)
            PROGRAM.append(None)
            HEALPIX.append(None)
            n_values.append(None)
            Z.append(None)   
            RA.append(None)
            DEC.append(None)
            Source_ID.append(None)
            
    
    z = np.array(Z)
    RA = np.array(RA)
    DEC = np.array(DEC)
    id_spec = np.array(Source_ID)
    wave_spec, flux_spec, sigma_spec = [], [], []
    
    for index, (survey, program, healpix, search_value) in enumerate(zip(SURVEY, PROGRAM, HEALPIX, search_values)):
        
        folder_name = 'DESI_Downloads'
        file_name = f"coadd-{survey}-{program}-{healpix}.fits"
        coadd_obj = desispec.io.read_spectra(f'{folder_name}/{file_name}')
        coadd_tgts = coadd_obj.target_ids().data
        # Selecting the particular spectra of the targetid
        row = (coadd_tgts == search_value)
        coadd_spec = coadd_obj[row] 

        # Inverse Vartiance weighted average for overlap
        no_overlap = no_overlap_f(coadd_spec.wave['b'],coadd_spec.flux['b'][0],coadd_spec.wave['r'],coadd_spec.flux['r'][0],coadd_spec.wave['z'],coadd_spec.flux['z'][0])
        overlap_br= overlap_av(coadd_spec.wave['b'],coadd_spec.wave['r'],coadd_spec.flux['b'][0],coadd_spec.flux['r'][0],coadd_spec.ivar['b'][0],coadd_spec.ivar['r'][0])
        overlap_rz= overlap_av(coadd_spec.wave['r'],coadd_spec.wave['z'],coadd_spec.flux['r'][0],coadd_spec.flux['z'][0],coadd_spec.ivar['r'][0],coadd_spec.ivar['z'][0])
        
        
        # Concaternating Spectra
        flux_spectra = np.concatenate((no_overlap[1],overlap_br[0],no_overlap[3],overlap_rz[0],no_overlap[5]))
        wave_spectra = np.concatenate((no_overlap[0],overlap_br[1],no_overlap[2],overlap_rz[1],no_overlap[4]))

        # Using Desispec to get wavelengths, flux and sigma
        wave = wave_spectra
        wave = wave.flatten()
        #flux = coadd_spec.flux['r'][0]
        #flux = convolve(flux_spectra, Gaussian1DKernel(5))
        #pick if i want to convolve or not
        flux = flux_spectra
        flux = flux.flatten()
        sigma = (np.sqrt(1/coadd_spec.ivar['r']))
        sigma = sigma.flatten()
        if index % 2 == 0 and len(wave) > 0:
                wave = wave[:-1]
                flux = flux[:-1]
                sigma = sigma[:-1]
        sigma_spec.append(sigma)
        wave_spec.append(wave)
        flux_spec.append(flux)
        
    
    wave_spec = np.array(wave_spec,dtype=object)
    flux_spec = np.array(flux_spec,dtype=object)
    sigma_spec = np.array(sigma_spec,dtype=object)
    # alternatively tried wave_spec = wave_spec.tolist()

    
    
    return wave_spec, flux_spec, sigma_spec, z, RA, DEC, id_spec


def get_stack(spec, zbins=None):# can add redshift ranges i.e zbins = [[0.0,0.1],[0.1,0.2]]
    wave_spec, flux_spec, sigma_spec, z, RA, DEC, id_spec= spec
    stack = sc.stack_spectra(wave_spec,flux_spec,sigma_spec,
                               z, RA, DEC, zbins = zbins)
    return stack

# %% [markdown]
# ## Spectra Selection and Application of Stacking

# %%
# Bin the data by flux (proxy for SFR?) or mass 


var_bin = 'Mass_cons'
crossmatch = crossmatch[np.array(np.argsort(crossmatch[f'{var_bin}']))]


Overall_class = 'SFG'
total_objects = 400
bins = 4
table_size = total_objects // bins

# Create a list to store the tables
tables = []

# Loop to create each table
for i in range(bins):
    start_index = i * table_size
    end_index = (i + 1) * table_size if i < bins - 1 else total_objects
    
    # Create a table for the current segment
    current_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][start_index:end_index]
    
    # Append the table to the list
    tables.append(current_table)

# There are tables 0 to 5
#print(tables[1])

import csv


spec_outputs = []

# Perform operations for each table
for i, table in enumerate(tables):
    search_column_name = 'TARGETID'
    search_values = np.array(table[f'{search_column_name}'])
    
    # Extract relevant spectra
    spec_tuple = get_spectra(table, search_column_name, search_values)
    spec_dict = {
        'wave_spec': spec_tuple[0],
        'flux_spec': spec_tuple[1],
        'sigma_spec': spec_tuple[2],
        'z': spec_tuple[3],
        'RA': spec_tuple[4],
        'DEC': spec_tuple[5],
        'id_spec': spec_tuple[6]
    }
    spec_outputs.append(spec_dict)


csv_filename = 'spec_outputs.csv'

with open(csv_filename, 'w', newline='') as csvfile:
    fieldnames = ['wave_spec', 'flux_spec', 'sigma_spec', 'z', 'RA', 'DEC', 'id_spec']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write header
    writer.writeheader()

    # Write data
    for spec in spec_outputs:
        for i in range(len(spec['wave_spec'])):
            writer.writerow({
                'wave_spec': spec['wave_spec'][i],
                'flux_spec': spec['flux_spec'][i],
                'sigma_spec': spec['sigma_spec'][i],
                'z': spec['z'][i],
                'RA': spec['RA'][i],
                'DEC': spec['DEC'][i],
                'id_spec': spec['id_spec'][i]})
# Out:
# Number of spectra = 100
# INFO:spectra.py:372:read_spectra: iotime 2.274 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:24:35.766168
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/3482820004.py:79: RuntimeWarning: divide by zero encountered in divide
#   sigma = (np.sqrt(1/coadd_spec.ivar['r']))
# INFO:spectra.py:372:read_spectra: iotime 1.639 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:24:38.136112
# INFO:spectra.py:372:read_spectra: iotime 2.045 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:24:40.799406
# INFO:spectra.py:372:read_spectra: iotime 2.341 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:24:44.369842
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/3924121423.py:7: RuntimeWarning: divide by zero encountered in divide
#   weight2 = 1 / ivar2
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/3924121423.py:10: RuntimeWarning: invalid value encountered in divide
#   weighted_flux2 = flux2 * (weight2 / total_weight)
# INFO:spectra.py:372:read_spectra: iotime 1.873 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:24:47.793173
# INFO:spectra.py:372:read_spectra: iotime 1.951 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:24:50.436045
# INFO:spectra.py:372:read_spectra: iotime 1.701 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:24:52.661844
# INFO:spectra.py:372:read_spectra: iotime 0.472 sec to read coadd-sv3-backup-11520.fits at 2024-01-18T15:24:54.155822
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/3924121423.py:6: RuntimeWarning: divide by zero encountered in divide
#   weight1 = 1 / ivar1
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/3924121423.py:9: RuntimeWarning: invalid value encountered in divide
#   weighted_flux1 = flux1 * (weight1 / total_weight)
# INFO:spectra.py:372:read_spectra: iotime 2.325 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:24:56.633012
# INFO:spectra.py:372:read_spectra: iotime 0.147 sec to read coadd-sv1-other-11524.fits at 2024-01-18T15:24:57.385469
# INFO:spectra.py:372:read_spectra: iotime 1.789 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:24:59.288938
# INFO:spectra.py:372:read_spectra: iotime 1.976 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:25:01.661435
# INFO:spectra.py:372:read_spectra: iotime 0.163 sec to read coadd-sv3-bright-11522.fits at 2024-01-18T15:25:03.373930
# INFO:spectra.py:372:read_spectra: iotime 0.575 sec to read coadd-sv1-other-10147.fits at 2024-01-18T15:25:04.087139
# INFO:spectra.py:372:read_spectra: iotime 0.839 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:25:05.040276
# INFO:spectra.py:372:read_spectra: iotime 2.197 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:25:07.422910
# INFO:spectra.py:372:read_spectra: iotime 0.932 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:25:09.429519
# INFO:spectra.py:372:read_spectra: iotime 2.211 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:25:12.097832
# INFO:spectra.py:372:read_spectra: iotime 0.326 sec to read coadd-sv1-other-10158.fits at 2024-01-18T15:25:13.310831
# INFO:spectra.py:372:read_spectra: iotime 2.090 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:25:15.646711
# INFO:spectra.py:372:read_spectra: iotime 0.880 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:25:17.038476
# INFO:spectra.py:372:read_spectra: iotime 1.481 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:25:18.913928
# INFO:spectra.py:372:read_spectra: iotime 1.706 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:25:20.993488
# INFO:spectra.py:372:read_spectra: iotime 2.328 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:25:24.796237
# INFO:spectra.py:372:read_spectra: iotime 1.973 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:25:28.336885
# INFO:spectra.py:372:read_spectra: iotime 1.940 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:25:31.143005
# INFO:spectra.py:372:read_spectra: iotime 1.984 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:25:33.659342
# INFO:spectra.py:372:read_spectra: iotime 2.512 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:25:37.453194
# INFO:spectra.py:372:read_spectra: iotime 2.298 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:25:41.214591
# INFO:spectra.py:372:read_spectra: iotime 0.886 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:25:43.456151
# INFO:spectra.py:372:read_spectra: iotime 2.084 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:25:45.846132
# INFO:spectra.py:372:read_spectra: iotime 0.780 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:25:47.115951
# INFO:spectra.py:372:read_spectra: iotime 1.905 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:25:49.258487
# INFO:spectra.py:372:read_spectra: iotime 2.622 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:25:52.408897
# INFO:spectra.py:372:read_spectra: iotime 0.051 sec to read coadd-sv1-other-10146.fits at 2024-01-18T15:25:53.923725
# INFO:spectra.py:372:read_spectra: iotime 2.005 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:25:56.038476
# INFO:spectra.py:372:read_spectra: iotime 1.191 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:25:57.667428
# INFO:spectra.py:372:read_spectra: iotime 0.738 sec to read coadd-sv1-other-11521.fits at 2024-01-18T15:25:58.747070
# INFO:spectra.py:372:read_spectra: iotime 2.329 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:26:01.267304
# INFO:spectra.py:372:read_spectra: iotime 2.503 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:26:04.737512
# INFO:spectra.py:372:read_spectra: iotime 1.963 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:26:08.416763
# INFO:spectra.py:372:read_spectra: iotime 1.749 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:26:11.487053
# INFO:spectra.py:372:read_spectra: iotime 0.461 sec to read coadd-sv1-other-10152.fits at 2024-01-18T15:26:12.566823
# INFO:spectra.py:372:read_spectra: iotime 1.939 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:26:14.648321
# INFO:spectra.py:372:read_spectra: iotime 0.648 sec to read coadd-sv1-other-10155.fits at 2024-01-18T15:26:15.694110
# INFO:spectra.py:372:read_spectra: iotime 2.367 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:26:18.255865
# INFO:spectra.py:372:read_spectra: iotime 1.224 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:26:20.656368
# INFO:spectra.py:372:read_spectra: iotime 2.182 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:26:23.374211
# INFO:spectra.py:372:read_spectra: iotime 0.887 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:26:25.348692
# INFO:spectra.py:372:read_spectra: iotime 1.955 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:26:27.714583
# INFO:spectra.py:372:read_spectra: iotime 2.159 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:26:30.468444
# INFO:spectra.py:372:read_spectra: iotime 1.836 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:26:33.884699
# INFO:spectra.py:372:read_spectra: iotime 2.598 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:26:37.250116
# INFO:spectra.py:372:read_spectra: iotime 2.189 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:26:40.985450
# INFO:spectra.py:372:read_spectra: iotime 2.345 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:26:44.604313
# INFO:spectra.py:372:read_spectra: iotime 1.942 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:26:47.829209
# INFO:spectra.py:372:read_spectra: iotime 1.936 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:26:50.971401
# INFO:spectra.py:372:read_spectra: iotime 0.582 sec to read coadd-sv3-backup-10153.fits at 2024-01-18T15:26:52.501988
# INFO:spectra.py:372:read_spectra: iotime 1.837 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:26:54.530275
# INFO:spectra.py:372:read_spectra: iotime 2.301 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:26:57.272750
# INFO:spectra.py:372:read_spectra: iotime 2.196 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:27:01.264597
# INFO:spectra.py:372:read_spectra: iotime 1.874 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:27:04.410369
# INFO:spectra.py:372:read_spectra: iotime 2.186 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:27:07.444966
# INFO:spectra.py:372:read_spectra: iotime 2.265 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:27:11.182032
# INFO:spectra.py:372:read_spectra: iotime 1.976 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:27:14.475639
# INFO:spectra.py:372:read_spectra: iotime 2.086 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:27:17.322709
# INFO:spectra.py:372:read_spectra: iotime 0.753 sec to read coadd-sv1-other-11521.fits at 2024-01-18T15:27:19.437294
# INFO:spectra.py:372:read_spectra: iotime 1.982 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:27:21.693443
# INFO:spectra.py:372:read_spectra: iotime 1.501 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:27:23.658898
# INFO:spectra.py:372:read_spectra: iotime 2.375 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:27:27.378802
# INFO:spectra.py:372:read_spectra: iotime 2.373 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:27:31.247434
# INFO:spectra.py:372:read_spectra: iotime 0.315 sec to read coadd-sv3-bright-10151.fits at 2024-01-18T15:27:33.067001
# INFO:spectra.py:372:read_spectra: iotime 2.283 sec to read coadd-sv3-dark-10150.fits at 2024-01-18T15:27:35.539643
# INFO:spectra.py:372:read_spectra: iotime 2.683 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:27:38.687891
# INFO:spectra.py:372:read_spectra: iotime 2.022 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:27:42.572818
# INFO:spectra.py:372:read_spectra: iotime 0.748 sec to read coadd-sv1-other-10150.fits at 2024-01-18T15:27:44.555862
# INFO:spectra.py:372:read_spectra: iotime 1.767 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:27:46.584243
# INFO:spectra.py:372:read_spectra: iotime 0.955 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:27:47.929620
# INFO:spectra.py:372:read_spectra: iotime 1.165 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:27:49.307197
# INFO:spectra.py:372:read_spectra: iotime 2.165 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:27:51.733964
# INFO:spectra.py:372:read_spectra: iotime 0.817 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:27:54.192873
# INFO:spectra.py:372:read_spectra: iotime 2.347 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:27:56.797500
# INFO:spectra.py:372:read_spectra: iotime 2.901 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:28:00.420220
# INFO:spectra.py:372:read_spectra: iotime 0.625 sec to read coadd-sv1-other-11520.fits at 2024-01-18T15:28:02.605310
# INFO:spectra.py:372:read_spectra: iotime 2.200 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:28:05.012443
# INFO:spectra.py:372:read_spectra: iotime 1.866 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:28:07.386382
# INFO:spectra.py:372:read_spectra: iotime 1.702 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:28:10.764611
# INFO:spectra.py:372:read_spectra: iotime 1.964 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:28:13.254862
# INFO:spectra.py:372:read_spectra: iotime 2.502 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:28:17.036631
# INFO:spectra.py:372:read_spectra: iotime 2.251 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:28:20.806544
# INFO:spectra.py:372:read_spectra: iotime 1.704 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:28:23.764868
# INFO:spectra.py:372:read_spectra: iotime 2.142 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:28:26.402418
# INFO:spectra.py:372:read_spectra: iotime 2.341 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:28:30.248847
# INFO:spectra.py:372:read_spectra: iotime 2.026 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:28:33.711140
# INFO:spectra.py:372:read_spectra: iotime 2.427 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:28:36.967050
# INFO:spectra.py:372:read_spectra: iotime 2.164 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:28:40.529050
# INFO:spectra.py:372:read_spectra: iotime 2.031 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:28:43.665905
# INFO:spectra.py:372:read_spectra: iotime 1.966 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:28:46.709239
# INFO:spectra.py:372:read_spectra: iotime 0.699 sec to read coadd-sv1-other-10154.fits at 2024-01-18T15:28:48.632005
# INFO:spectra.py:372:read_spectra: iotime 1.883 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:28:50.760196
# Number of spectra = 100
# INFO:spectra.py:372:read_spectra: iotime 1.993 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:28:53.294332
# INFO:spectra.py:372:read_spectra: iotime 1.803 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:28:55.540470
# INFO:spectra.py:372:read_spectra: iotime 1.986 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:28:59.043152
# INFO:spectra.py:372:read_spectra: iotime 2.576 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:29:02.354055
# INFO:spectra.py:372:read_spectra: iotime 2.225 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:29:06.335108
# INFO:spectra.py:372:read_spectra: iotime 2.204 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:29:09.673041
# INFO:spectra.py:372:read_spectra: iotime 2.120 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:29:12.567926
# INFO:spectra.py:372:read_spectra: iotime 2.224 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:29:16.096305
# INFO:spectra.py:372:read_spectra: iotime 2.198 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:29:19.802717
# INFO:spectra.py:372:read_spectra: iotime 2.170 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:29:23.016076
# INFO:spectra.py:372:read_spectra: iotime 1.724 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:29:25.893822
# INFO:spectra.py:372:read_spectra: iotime 0.643 sec to read coadd-sv1-other-10155.fits at 2024-01-18T15:29:27.481482
# INFO:spectra.py:372:read_spectra: iotime 2.241 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:29:30.036706
# INFO:spectra.py:372:read_spectra: iotime 2.648 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:29:33.344313
# INFO:spectra.py:372:read_spectra: iotime 2.348 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:29:37.218838
# INFO:spectra.py:372:read_spectra: iotime 2.029 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:29:40.613153
# INFO:spectra.py:372:read_spectra: iotime 1.959 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:29:43.267008
# INFO:spectra.py:372:read_spectra: iotime 0.862 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:29:45.092330
# INFO:spectra.py:372:read_spectra: iotime 1.694 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:29:47.033456
# INFO:spectra.py:372:read_spectra: iotime 2.755 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:29:50.323430
# INFO:spectra.py:372:read_spectra: iotime 0.457 sec to read coadd-sv1-other-10152.fits at 2024-01-18T15:29:52.496322
# INFO:spectra.py:372:read_spectra: iotime 1.801 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:29:54.506824
# INFO:spectra.py:372:read_spectra: iotime 1.469 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:29:56.351328
# INFO:spectra.py:372:read_spectra: iotime 0.870 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:29:57.699900
# INFO:spectra.py:372:read_spectra: iotime 2.217 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:30:00.130577
# INFO:spectra.py:372:read_spectra: iotime 2.527 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:30:03.571174
# INFO:spectra.py:372:read_spectra: iotime 1.805 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:30:07.175998
# INFO:spectra.py:372:read_spectra: iotime 2.295 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:30:10.112212
# INFO:spectra.py:372:read_spectra: iotime 1.705 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:30:13.387982
# INFO:spectra.py:372:read_spectra: iotime 1.715 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:30:15.699920
# INFO:spectra.py:372:read_spectra: iotime 1.979 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:30:18.123345
# INFO:spectra.py:372:read_spectra: iotime 0.734 sec to read coadd-sv1-other-10150.fits at 2024-01-18T15:30:20.092998
# INFO:spectra.py:372:read_spectra: iotime 1.970 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:30:22.326056
# INFO:spectra.py:372:read_spectra: iotime 0.662 sec to read coadd-sv1-other-10155.fits at 2024-01-18T15:30:23.480936
# INFO:spectra.py:372:read_spectra: iotime 2.153 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:30:25.829560
# INFO:spectra.py:372:read_spectra: iotime 2.833 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:30:29.354976
# INFO:spectra.py:372:read_spectra: iotime 1.184 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:30:32.224995
# INFO:spectra.py:372:read_spectra: iotime 1.706 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:30:34.303488
# INFO:spectra.py:372:read_spectra: iotime 0.508 sec to read coadd-sv1-other-10152.fits at 2024-01-18T15:30:35.199384
# INFO:spectra.py:372:read_spectra: iotime 1.102 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:30:36.479976
# INFO:spectra.py:372:read_spectra: iotime 0.829 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:30:37.537183
# INFO:spectra.py:372:read_spectra: iotime 2.332 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:30:40.077982
# INFO:spectra.py:372:read_spectra: iotime 0.801 sec to read coadd-sv1-other-11521.fits at 2024-01-18T15:30:42.058589
# INFO:spectra.py:372:read_spectra: iotime 0.824 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:30:43.194398
# INFO:spectra.py:372:read_spectra: iotime 2.149 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:30:45.655602
# INFO:spectra.py:372:read_spectra: iotime 2.259 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:30:48.696313
# INFO:spectra.py:372:read_spectra: iotime 0.827 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:30:51.012424
# INFO:spectra.py:372:read_spectra: iotime 2.229 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:30:53.509338
# INFO:spectra.py:372:read_spectra: iotime 1.951 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:30:56.363735
# INFO:spectra.py:372:read_spectra: iotime 1.787 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:30:59.379416
# INFO:spectra.py:372:read_spectra: iotime 2.210 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:31:02.235046
# INFO:spectra.py:372:read_spectra: iotime 1.614 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:31:05.229730
# INFO:spectra.py:372:read_spectra: iotime 2.384 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:31:08.296580
# INFO:spectra.py:372:read_spectra: iotime 1.603 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:31:11.412007
# INFO:spectra.py:372:read_spectra: iotime 2.108 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:31:14.316932
# INFO:spectra.py:372:read_spectra: iotime 1.983 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:31:17.356923
# INFO:spectra.py:372:read_spectra: iotime 1.675 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:31:20.010306
# INFO:spectra.py:372:read_spectra: iotime 1.187 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:31:21.675731
# INFO:spectra.py:372:read_spectra: iotime 1.371 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:31:23.355157
# INFO:spectra.py:372:read_spectra: iotime 2.083 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:31:25.905536
# INFO:spectra.py:372:read_spectra: iotime 2.353 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:31:29.917222
# INFO:spectra.py:372:read_spectra: iotime 2.212 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:31:33.642351
# INFO:spectra.py:372:read_spectra: iotime 1.894 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:31:36.811965
# INFO:spectra.py:372:read_spectra: iotime 2.392 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:31:39.945205
# INFO:spectra.py:372:read_spectra: iotime 2.166 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:31:43.876243
# INFO:spectra.py:372:read_spectra: iotime 0.851 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:31:46.121950
# INFO:spectra.py:372:read_spectra: iotime 2.450 sec to read coadd-sv3-dark-11521.fits at 2024-01-18T15:31:48.859710
# INFO:spectra.py:372:read_spectra: iotime 3.071 sec to read coadd-sv3-dark-10155.fits at 2024-01-18T15:31:52.569313
# INFO:spectra.py:372:read_spectra: iotime 1.710 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:31:56.031029
# INFO:spectra.py:372:read_spectra: iotime 1.806 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:31:58.665666
# INFO:spectra.py:372:read_spectra: iotime 1.972 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:32:01.084950
# INFO:spectra.py:372:read_spectra: iotime 2.161 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:32:04.238599
# INFO:spectra.py:372:read_spectra: iotime 2.401 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:32:07.914831
# INFO:spectra.py:372:read_spectra: iotime 0.766 sec to read coadd-sv1-other-11521.fits at 2024-01-18T15:32:10.147812
# INFO:spectra.py:372:read_spectra: iotime 2.244 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:32:12.679461
# INFO:spectra.py:372:read_spectra: iotime 2.409 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:32:15.748030
# INFO:spectra.py:372:read_spectra: iotime 2.354 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:32:19.529537
# INFO:spectra.py:372:read_spectra: iotime 1.798 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:32:22.812573
# INFO:spectra.py:372:read_spectra: iotime 1.711 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:32:25.168704
# INFO:spectra.py:372:read_spectra: iotime 2.276 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:32:28.066444
# INFO:spectra.py:372:read_spectra: iotime 1.669 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:32:31.059921
# INFO:spectra.py:372:read_spectra: iotime 2.132 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:32:33.867184
# INFO:spectra.py:372:read_spectra: iotime 2.012 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:32:37.354024
# INFO:spectra.py:372:read_spectra: iotime 1.719 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:32:39.855130
# INFO:spectra.py:372:read_spectra: iotime 1.970 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:32:42.423561
# INFO:spectra.py:372:read_spectra: iotime 2.001 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:32:45.238660
# INFO:spectra.py:372:read_spectra: iotime 2.005 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:32:48.930509
# INFO:spectra.py:372:read_spectra: iotime 2.180 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:32:51.855043
# INFO:spectra.py:372:read_spectra: iotime 1.471 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:32:54.379338
# INFO:spectra.py:372:read_spectra: iotime 1.714 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:32:56.602373
# INFO:spectra.py:372:read_spectra: iotime 1.614 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:32:58.904344
# INFO:spectra.py:372:read_spectra: iotime 1.401 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:33:00.809992
# INFO:spectra.py:372:read_spectra: iotime 1.608 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:33:02.792368
# INFO:spectra.py:372:read_spectra: iotime 1.798 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:33:05.131770
# INFO:spectra.py:372:read_spectra: iotime 1.183 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:33:06.815239
# INFO:spectra.py:372:read_spectra: iotime 2.170 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:33:09.313016
# INFO:spectra.py:372:read_spectra: iotime 2.205 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:33:12.739424
# INFO:spectra.py:372:read_spectra: iotime 1.982 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:33:16.281630
# INFO:spectra.py:372:read_spectra: iotime 2.359 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:33:19.569583
# INFO:spectra.py:372:read_spectra: iotime 1.472 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:33:22.619014
# Number of spectra = 100
# INFO:spectra.py:372:read_spectra: iotime 0.459 sec to read coadd-sv1-other-10152.fits at 2024-01-18T15:33:23.732047
# INFO:spectra.py:372:read_spectra: iotime 1.806 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:33:25.633190
# INFO:spectra.py:372:read_spectra: iotime 1.425 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:33:27.465940
# INFO:spectra.py:372:read_spectra: iotime 1.714 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:33:30.119940
# INFO:spectra.py:372:read_spectra: iotime 1.715 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:33:32.327083
# INFO:spectra.py:372:read_spectra: iotime 2.741 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:33:35.825604
# INFO:spectra.py:372:read_spectra: iotime 2.113 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:33:39.621646
# INFO:spectra.py:372:read_spectra: iotime 0.760 sec to read coadd-sv1-other-10150.fits at 2024-01-18T15:33:41.655751
# INFO:spectra.py:372:read_spectra: iotime 2.381 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:33:44.303742
# INFO:spectra.py:372:read_spectra: iotime 2.398 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:33:47.563140
# INFO:spectra.py:372:read_spectra: iotime 2.251 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:33:51.212847
# INFO:spectra.py:372:read_spectra: iotime 2.301 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:33:54.622847
# INFO:spectra.py:372:read_spectra: iotime 1.925 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:33:57.827932
# INFO:spectra.py:372:read_spectra: iotime 1.953 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:34:00.578023
# INFO:spectra.py:372:read_spectra: iotime 0.699 sec to read coadd-sv1-other-10154.fits at 2024-01-18T15:34:02.130132
# INFO:spectra.py:372:read_spectra: iotime 2.231 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:34:04.576937
# INFO:spectra.py:372:read_spectra: iotime 2.569 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:34:07.771749
# INFO:spectra.py:372:read_spectra: iotime 0.586 sec to read coadd-sv1-other-10147.fits at 2024-01-18T15:34:09.863034
# INFO:spectra.py:372:read_spectra: iotime 2.016 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:34:12.106453
# INFO:spectra.py:372:read_spectra: iotime 2.017 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:34:14.574110
# INFO:spectra.py:372:read_spectra: iotime 1.865 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:34:17.482694
# INFO:spectra.py:372:read_spectra: iotime 2.162 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:34:20.509723
# INFO:spectra.py:372:read_spectra: iotime 2.415 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:34:24.025507
# INFO:spectra.py:372:read_spectra: iotime 1.465 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:34:27.187440
# INFO:spectra.py:372:read_spectra: iotime 2.058 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:34:29.680670
# INFO:spectra.py:372:read_spectra: iotime 2.399 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:34:32.957801
# INFO:spectra.py:372:read_spectra: iotime 0.841 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:34:35.308470
# INFO:spectra.py:372:read_spectra: iotime 0.734 sec to read coadd-sv3-bright-10157.fits at 2024-01-18T15:34:36.323509
# INFO:spectra.py:372:read_spectra: iotime 1.968 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:34:38.469097
# INFO:spectra.py:372:read_spectra: iotime 0.692 sec to read coadd-sv3-bright-10157.fits at 2024-01-18T15:34:39.678919
# INFO:spectra.py:372:read_spectra: iotime 1.804 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:34:41.726105
# INFO:spectra.py:372:read_spectra: iotime 2.716 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:34:45.029144
# INFO:spectra.py:372:read_spectra: iotime 1.730 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:34:48.186824
# INFO:spectra.py:372:read_spectra: iotime 1.580 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:34:50.433569
# INFO:spectra.py:372:read_spectra: iotime 2.361 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:34:53.205688
# INFO:spectra.py:372:read_spectra: iotime 1.968 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:34:56.453330
# INFO:spectra.py:372:read_spectra: iotime 1.612 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:34:59.431165
# INFO:spectra.py:372:read_spectra: iotime 2.264 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:35:02.177660
# INFO:spectra.py:372:read_spectra: iotime 0.860 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:35:04.191190
# INFO:spectra.py:372:read_spectra: iotime 0.824 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:35:05.287176
# INFO:spectra.py:372:read_spectra: iotime 1.192 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:35:06.673992
# INFO:spectra.py:372:read_spectra: iotime 2.253 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:35:09.198178
# INFO:spectra.py:372:read_spectra: iotime 2.539 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:35:13.237294
# INFO:spectra.py:372:read_spectra: iotime 0.640 sec to read coadd-sv1-other-11520.fits at 2024-01-18T15:35:15.648788
# INFO:spectra.py:372:read_spectra: iotime 2.238 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:35:18.163375
# INFO:spectra.py:372:read_spectra: iotime 2.264 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:35:20.934461
# INFO:spectra.py:372:read_spectra: iotime 2.152 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:35:25.323253
# INFO:spectra.py:372:read_spectra: iotime 2.259 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:35:28.926502
# INFO:spectra.py:372:read_spectra: iotime 2.119 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:35:32.280445
# INFO:spectra.py:372:read_spectra: iotime 0.324 sec to read coadd-sv1-other-10158.fits at 2024-01-18T15:35:33.396421
# INFO:spectra.py:372:read_spectra: iotime 0.863 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:35:34.404934
# INFO:spectra.py:372:read_spectra: iotime 1.521 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:35:36.126625
# INFO:spectra.py:372:read_spectra: iotime 0.828 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:35:37.316863
# INFO:spectra.py:372:read_spectra: iotime 2.061 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:35:39.569919
# INFO:spectra.py:372:read_spectra: iotime 2.326 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:35:43.129053
# INFO:spectra.py:372:read_spectra: iotime 0.795 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:35:45.585960
# INFO:spectra.py:372:read_spectra: iotime 1.801 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:35:47.671723
# INFO:spectra.py:372:read_spectra: iotime 2.242 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:35:50.314803
# INFO:spectra.py:372:read_spectra: iotime 2.018 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:35:54.310319
# INFO:spectra.py:372:read_spectra: iotime 2.126 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:35:57.600284
# INFO:spectra.py:372:read_spectra: iotime 2.331 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:36:00.649619
# INFO:spectra.py:372:read_spectra: iotime 2.376 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:36:04.825141
# INFO:spectra.py:372:read_spectra: iotime 1.479 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:36:07.682552
# INFO:spectra.py:372:read_spectra: iotime 2.501 sec to read coadd-sv3-dark-10158.fits at 2024-01-18T15:36:10.606432
# INFO:spectra.py:372:read_spectra: iotime 2.293 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:36:14.255575
# INFO:spectra.py:372:read_spectra: iotime 1.409 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:36:17.204644
# INFO:spectra.py:372:read_spectra: iotime 2.177 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:36:19.796357
# INFO:spectra.py:372:read_spectra: iotime 0.864 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:36:21.450477
# INFO:spectra.py:372:read_spectra: iotime 0.622 sec to read coadd-sv1-other-11520.fits at 2024-01-18T15:36:22.408823
# INFO:spectra.py:372:read_spectra: iotime 2.602 sec to read coadd-sv3-dark-10158.fits at 2024-01-18T15:36:25.155149
# INFO:spectra.py:372:read_spectra: iotime 2.385 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:36:28.880157
# INFO:spectra.py:372:read_spectra: iotime 1.465 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:36:31.931556
# INFO:spectra.py:372:read_spectra: iotime 0.596 sec to read coadd-sv3-backup-11521.fits at 2024-01-18T15:36:32.934053
# INFO:spectra.py:372:read_spectra: iotime 1.993 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:36:35.098290
# INFO:spectra.py:372:read_spectra: iotime 2.689 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:36:38.220142
# INFO:spectra.py:372:read_spectra: iotime 0.824 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:36:40.617084
# INFO:spectra.py:372:read_spectra: iotime 2.366 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:36:43.262098
# INFO:spectra.py:372:read_spectra: iotime 2.674 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:36:46.643547
# INFO:spectra.py:372:read_spectra: iotime 2.010 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:36:50.275296
# INFO:spectra.py:372:read_spectra: iotime 1.200 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:36:52.209884
# INFO:spectra.py:372:read_spectra: iotime 2.206 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:36:54.730400
# INFO:spectra.py:372:read_spectra: iotime 2.621 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:36:58.002336
# INFO:spectra.py:372:read_spectra: iotime 2.354 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:37:01.805430
# INFO:spectra.py:372:read_spectra: iotime 2.175 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:37:05.686949
# INFO:spectra.py:372:read_spectra: iotime 1.198 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:37:08.034117
# INFO:spectra.py:372:read_spectra: iotime 2.045 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:37:10.443120
# INFO:spectra.py:372:read_spectra: iotime 2.943 sec to read coadd-sv3-dark-10155.fits at 2024-01-18T15:37:13.901930
# INFO:spectra.py:372:read_spectra: iotime 1.822 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:37:17.438995
# INFO:spectra.py:372:read_spectra: iotime 2.354 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:37:20.753896
# INFO:spectra.py:372:read_spectra: iotime 2.469 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:37:24.373036
# INFO:spectra.py:372:read_spectra: iotime 0.755 sec to read coadd-sv1-other-10150.fits at 2024-01-18T15:37:26.623981
# INFO:spectra.py:372:read_spectra: iotime 1.583 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:37:28.470566
# INFO:spectra.py:372:read_spectra: iotime 2.078 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:37:30.867355
# INFO:spectra.py:372:read_spectra: iotime 3.007 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:37:34.707831
# INFO:spectra.py:372:read_spectra: iotime 2.187 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:37:38.781929
# INFO:spectra.py:372:read_spectra: iotime 2.269 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:37:42.346775
# INFO:spectra.py:372:read_spectra: iotime 2.096 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:37:45.810401
# INFO:spectra.py:372:read_spectra: iotime 0.847 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:37:47.602373
# INFO:spectra.py:372:read_spectra: iotime 1.945 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:37:49.798069
# INFO:spectra.py:372:read_spectra: iotime 2.128 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:37:52.490617
# Number of spectra = 100
# INFO:spectra.py:372:read_spectra: iotime 1.473 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:37:55.661392
# INFO:spectra.py:372:read_spectra: iotime 1.178 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:37:57.124667
# INFO:spectra.py:372:read_spectra: iotime 1.979 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:37:59.404577
# INFO:spectra.py:372:read_spectra: iotime 2.344 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:38:02.798050
# INFO:spectra.py:372:read_spectra: iotime 0.460 sec to read coadd-sv1-other-10152.fits at 2024-01-18T15:38:04.806542
# INFO:spectra.py:372:read_spectra: iotime 2.256 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:38:07.347904
# INFO:spectra.py:372:read_spectra: iotime 2.923 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:38:10.742782
# INFO:spectra.py:372:read_spectra: iotime 0.829 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:38:13.339217
# INFO:spectra.py:372:read_spectra: iotime 2.130 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:38:15.769389
# INFO:spectra.py:372:read_spectra: iotime 2.690 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:38:19.019365
# INFO:spectra.py:372:read_spectra: iotime 0.456 sec to read coadd-sv1-other-10152.fits at 2024-01-18T15:38:21.384594
# INFO:spectra.py:372:read_spectra: iotime 0.679 sec to read coadd-sv1-other-10154.fits at 2024-01-18T15:38:22.270259
# INFO:spectra.py:372:read_spectra: iotime 0.854 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:38:23.277068
# INFO:spectra.py:372:read_spectra: iotime 2.003 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:38:25.487796
# INFO:spectra.py:372:read_spectra: iotime 2.393 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:38:28.634032
# INFO:spectra.py:372:read_spectra: iotime 1.892 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:38:31.901342
# INFO:spectra.py:372:read_spectra: iotime 0.704 sec to read coadd-sv1-other-10154.fits at 2024-01-18T15:38:33.266418
# INFO:spectra.py:372:read_spectra: iotime 1.479 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:38:34.945471
# INFO:spectra.py:372:read_spectra: iotime 1.859 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:38:37.149228
# INFO:spectra.py:372:read_spectra: iotime 2.956 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:38:40.698022
# INFO:spectra.py:372:read_spectra: iotime 1.706 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:38:44.075523
# INFO:spectra.py:372:read_spectra: iotime 0.750 sec to read coadd-sv1-other-10150.fits at 2024-01-18T15:38:45.521964
# INFO:spectra.py:372:read_spectra: iotime 0.841 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:38:46.566587
# INFO:spectra.py:372:read_spectra: iotime 2.240 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:38:49.026270
# INFO:spectra.py:372:read_spectra: iotime 2.613 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:38:52.643617
# INFO:spectra.py:372:read_spectra: iotime 2.139 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:38:56.370898
# INFO:spectra.py:372:read_spectra: iotime 0.847 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:38:58.574834
# INFO:spectra.py:372:read_spectra: iotime 2.008 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:39:00.871796
# INFO:spectra.py:372:read_spectra: iotime 0.841 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:39:02.152446
# INFO:spectra.py:372:read_spectra: iotime 2.004 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:39:04.363125
# INFO:spectra.py:372:read_spectra: iotime 2.732 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:39:07.679624
# INFO:spectra.py:372:read_spectra: iotime 2.392 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:39:11.440163
# INFO:spectra.py:372:read_spectra: iotime 0.841 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:39:13.662102
# INFO:spectra.py:372:read_spectra: iotime 2.252 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:39:16.215807
# INFO:spectra.py:372:read_spectra: iotime 0.895 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:39:17.828846
# INFO:spectra.py:372:read_spectra: iotime 2.250 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:39:20.356769
# INFO:spectra.py:372:read_spectra: iotime 2.447 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:39:23.536008
# INFO:spectra.py:372:read_spectra: iotime 0.644 sec to read coadd-sv1-other-10155.fits at 2024-01-18T15:39:25.898015
# INFO:spectra.py:372:read_spectra: iotime 1.462 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:39:27.577139
# INFO:spectra.py:372:read_spectra: iotime 1.658 sec to read coadd-sv3-dark-10147.fits at 2024-01-18T15:39:29.558032
# INFO:spectra.py:372:read_spectra: iotime 2.507 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:39:32.884883
# INFO:spectra.py:372:read_spectra: iotime 1.217 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:39:35.496579
# INFO:spectra.py:372:read_spectra: iotime 2.138 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:39:37.990712
# INFO:spectra.py:372:read_spectra: iotime 2.430 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:39:41.584918
# INFO:spectra.py:372:read_spectra: iotime 2.032 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:39:45.264433
# INFO:spectra.py:372:read_spectra: iotime 2.003 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:39:48.503423
# INFO:spectra.py:372:read_spectra: iotime 2.154 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:39:51.597569
# INFO:spectra.py:372:read_spectra: iotime 2.171 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:39:55.275577
# INFO:spectra.py:372:read_spectra: iotime 1.977 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:39:58.294572
# INFO:spectra.py:372:read_spectra: iotime 0.847 sec to read coadd-sv1-other-10156.fits at 2024-01-18T15:39:59.966681
# INFO:spectra.py:372:read_spectra: iotime 1.847 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:40:02.069034
# INFO:spectra.py:372:read_spectra: iotime 2.097 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:40:04.612567
# INFO:spectra.py:372:read_spectra: iotime 1.177 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:40:07.536965
# INFO:spectra.py:372:read_spectra: iotime 2.105 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:40:10.004225
# INFO:spectra.py:372:read_spectra: iotime 0.964 sec to read coadd-sv1-other-10153.fits at 2024-01-18T15:40:11.546200
# INFO:spectra.py:372:read_spectra: iotime 1.991 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:40:14.042743
# INFO:spectra.py:372:read_spectra: iotime 0.806 sec to read coadd-sv1-other-10150.fits at 2024-01-18T15:40:15.333522
# INFO:spectra.py:372:read_spectra: iotime 2.220 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:40:17.807013
# INFO:spectra.py:372:read_spectra: iotime 1.978 sec to read coadd-sv3-bright-11520.fits at 2024-01-18T15:40:20.614586
# INFO:spectra.py:372:read_spectra: iotime 1.452 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:40:23.250423
# INFO:spectra.py:372:read_spectra: iotime 1.930 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:40:25.695031
# INFO:spectra.py:372:read_spectra: iotime 1.803 sec to read coadd-sv3-bright-10154.fits at 2024-01-18T15:40:28.732389
# INFO:spectra.py:372:read_spectra: iotime 0.315 sec to read coadd-sv3-bright-10151.fits at 2024-01-18T15:40:30.000507
# INFO:spectra.py:372:read_spectra: iotime 1.955 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:40:32.121279
# INFO:spectra.py:372:read_spectra: iotime 2.612 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:40:35.139094
# INFO:spectra.py:372:read_spectra: iotime 1.987 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:40:38.719869
# INFO:spectra.py:372:read_spectra: iotime 2.344 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:40:42.308911
# INFO:spectra.py:372:read_spectra: iotime 1.469 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:40:44.972041
# INFO:spectra.py:372:read_spectra: iotime 2.144 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:40:47.559920
# INFO:spectra.py:372:read_spectra: iotime 2.456 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:40:50.944600
# INFO:spectra.py:372:read_spectra: iotime 0.316 sec to read coadd-sv3-bright-10151.fits at 2024-01-18T15:40:52.651287
# INFO:spectra.py:372:read_spectra: iotime 2.230 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:40:55.044189
# INFO:spectra.py:372:read_spectra: iotime 2.175 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:40:57.661835
# INFO:spectra.py:372:read_spectra: iotime 2.109 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:41:01.360262
# INFO:spectra.py:372:read_spectra: iotime 1.862 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:41:04.109320
# INFO:spectra.py:372:read_spectra: iotime 2.186 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:41:06.908727
# INFO:spectra.py:372:read_spectra: iotime 1.965 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:41:10.513616
# INFO:spectra.py:372:read_spectra: iotime 2.359 sec to read coadd-sv3-bright-10156.fits at 2024-01-18T15:41:13.684802
# INFO:spectra.py:372:read_spectra: iotime 0.143 sec to read coadd-sv1-other-11524.fits at 2024-01-18T15:41:15.276743
# INFO:spectra.py:372:read_spectra: iotime 2.224 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:41:17.800051
# INFO:spectra.py:372:read_spectra: iotime 1.324 sec to read coadd-sv3-bright-10152.fits at 2024-01-18T15:41:19.558934
# INFO:spectra.py:372:read_spectra: iotime 1.471 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:41:21.638972
# INFO:spectra.py:372:read_spectra: iotime 2.181 sec to read coadd-sv3-bright-11521.fits at 2024-01-18T15:41:24.195653
# INFO:spectra.py:372:read_spectra: iotime 2.887 sec to read coadd-sv3-dark-10158.fits at 2024-01-18T15:41:28.371790
# INFO:spectra.py:372:read_spectra: iotime 2.126 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:41:32.441765
# INFO:spectra.py:372:read_spectra: iotime 0.872 sec to read coadd-sv3-bright-11524.fits at 2024-01-18T15:41:34.424264
# INFO:spectra.py:372:read_spectra: iotime 1.964 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:41:36.652332
# INFO:spectra.py:372:read_spectra: iotime 0.639 sec to read coadd-sv1-other-11520.fits at 2024-01-18T15:41:37.725440
# INFO:spectra.py:372:read_spectra: iotime 1.464 sec to read coadd-sv3-bright-10147.fits at 2024-01-18T15:41:39.381342
# INFO:spectra.py:372:read_spectra: iotime 1.983 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:41:41.686918
# INFO:spectra.py:372:read_spectra: iotime 0.597 sec to read coadd-sv1-other-11520.fits at 2024-01-18T15:41:43.998885
# INFO:spectra.py:372:read_spectra: iotime 0.741 sec to read coadd-sv1-other-11521.fits at 2024-01-18T15:41:44.956056
# INFO:spectra.py:372:read_spectra: iotime 2.115 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:41:47.255278
# INFO:spectra.py:372:read_spectra: iotime 0.738 sec to read coadd-sv1-other-11521.fits at 2024-01-18T15:41:48.557868
# INFO:spectra.py:372:read_spectra: iotime 2.000 sec to read coadd-sv3-bright-10153.fits at 2024-01-18T15:41:50.919335
# INFO:spectra.py:372:read_spectra: iotime 2.927 sec to read coadd-sv3-bright-10158.fits at 2024-01-18T15:41:54.359348
# INFO:spectra.py:372:read_spectra: iotime 0.235 sec to read coadd-sv1-other-10157.fits at 2024-01-18T15:41:56.299055
# INFO:spectra.py:372:read_spectra: iotime 2.004 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:41:58.478016
# INFO:spectra.py:372:read_spectra: iotime 2.004 sec to read coadd-sv3-bright-10150.fits at 2024-01-18T15:42:00.880577
# INFO:spectra.py:372:read_spectra: iotime 1.863 sec to read coadd-sv3-bright-10155.fits at 2024-01-18T15:42:04.423881

# %%
csv_filename = 'spec_outputs.csv'

spec_outputs = []

with open(csv_filename, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    
    # Read data
    current_spec = {'wave_spec': [], 'flux_spec': [], 'sigma_spec': [], 'z': [], 'RA': [], 'DEC': [], 'id_spec': []}
    current_id = None
    
    for row in reader:
        if current_id is None or current_id != row['id_spec']:
            # Start a new spectrum
            current_spec = {'wave_spec': [], 'flux_spec': [], 'sigma_spec': [], 'z': [], 'RA': [], 'DEC': [], 'id_spec': row['id_spec']}
            current_id = row['id_spec']
        
        # Convert the string representation of the array back to a NumPy array
        current_spec['wave_spec'].append(np.fromstring(row['wave_spec'], sep=' '))
        current_spec['flux_spec'].append(np.fromstring(row['flux_spec'], sep=' '))
        current_spec['sigma_spec'].append(np.fromstring(row['sigma_spec'], sep=' '))
        current_spec['z'].append(float(row['z']))
        current_spec['RA'].append(float(row['RA']))
        current_spec['DEC'].append(float(row['DEC']))
    
    # Add the last spectrum
    spec_outputs.append(current_spec)



stacks_outputs = []





# Perform operations for each spectrum in spec_outputs
for i, spec in enumerate(spec_outputs):
    # Convert 'z' values to float
    spec['z'] = np.array(spec['z'], dtype=float)

    # Stack spectra
    stacks = get_stack(spec, zbins=[[-0.5, 0.75], [0.75, 4.5]])

    # Append the stack output to the list
    stacks_outputs.append(stacks)
# Out:
# flux_spec: flux_spec
# zbin: [[-0.5, 0.75], [0.75, 4.5]]
# 2
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/2020705510.py:19: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   current_spec['wave_spec'].append(np.fromstring(row['wave_spec'], sep=' '))
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/2020705510.py:20: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   current_spec['flux_spec'].append(np.fromstring(row['flux_spec'], sep=' '))
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_43588/2020705510.py:21: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   current_spec['sigma_spec'].append(np.fromstring(row['sigma_spec'], sep=' '))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb Cell 11 line 4
#      <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=39'>40</a> spec['z'] = np.array(spec['z'], dtype=float)
#      <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=41'>42</a> # Stack spectra
# ---> <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=42'>43</a> stacks = get_stack(spec, zbins=[[-0.5, 0.75], [0.75, 4.5]])
#      <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=44'>45</a> # Append the stack output to the list
#      <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=45'>46</a> stacks_outputs.append(stacks)
#
# /Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=99'>100</a> def get_stack(spec, zbins=None):# can add redshift ranges i.e zbins = [[0.0,0.1],[0.1,0.2]]
#     <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=100'>101</a>     wave_spec, flux_spec, sigma_spec, z, RA, DEC, id_spec= spec
# --> <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=101'>102</a>     stack = sc.stack_spectra(wave_spec,flux_spec,sigma_spec,
#     <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=102'>103</a>                                z, RA, DEC, zbins = zbins)
#     <a href='vscode-notebook-cell:/Users/s2537809/DESI-Mini-Project/SP.7.SFG_Mass.ipynb#X13sZmlsZQ%3D%3D?line=103'>104</a>     return stack
#
# File ~/Documents/DESI-STACKING/stack_code.py:609, in stack_spectra(wave_spec, flux_spec, sigma_spec, z, RA, DEC, zbins, sampling, line_list_dir, dustmap_dir, filter_curve_dir)
#     606 print (len(zbins))
#     607 for i in range(len(zbins)):
#     608         #select indexes of spectra within the redshift bin and print the total selected
# --> 609         idx.append(np.where((z >= zbins[i][0]) & (z <= zbins[i][1]))[0])
#     610         print('Number of spectra to stack = ', len(idx[i]))
#     611         print(zbins[i][0], zbins[i][1])#abby
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
"""

b: 3600.0 5800.0000000005 r: 5760.0 7620.000000000423 z: 7520.0


Note: The lengths for indexing are:

HERG = 184

RQAGN = 814

LERG = 1293

SFG = 6294

"""

# Select varibale to sort by
#Mass_median or Total_flux from LOFAR?

Overall_class = 'SFG'
my_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][0:100]
search_column_name = 'TARGETID'
search_values = np.array(my_table[f'{search_column_name}'])


SFG_spec=get_spectra(my_table,search_column_name,search_values) #extracts relevant spectra

SFG_stack = get_stack(SFG_spec) #stacks spectra
# Out:
# Number of spectra = 100
# INFO:spectra.py:372:read_spectra: iotime 1.624 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:04:53.889729
# INFO:spectra.py:372:read_spectra: iotime 1.009 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:05:00.230894
# INFO:spectra.py:372:read_spectra: iotime 6.587 sec to read coadd-sv3-bright-10156.fits at 2024-01-07T14:05:08.136089
# INFO:spectra.py:372:read_spectra: iotime 6.086 sec to read coadd-sv3-dark-11521.fits at 2024-01-07T14:05:19.253633
# INFO:spectra.py:372:read_spectra: iotime 4.318 sec to read coadd-sv3-bright-10155.fits at 2024-01-07T14:05:28.643283
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_32472/3924121423.py:6: RuntimeWarning: divide by zero encountered in divide
#   weight1 = 1 / ivar1
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_32472/3924121423.py:9: RuntimeWarning: invalid value encountered in divide
#   weighted_flux1 = flux1 * (weight1 / total_weight)
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_32472/87081193.py:80: RuntimeWarning: divide by zero encountered in divide
#   sigma = (np.sqrt(1/coadd_spec.ivar['r']))
# INFO:spectra.py:372:read_spectra: iotime 1.715 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:05:33.897122
# INFO:spectra.py:372:read_spectra: iotime 4.450 sec to read coadd-sv3-bright-10153.fits at 2024-01-07T14:05:40.361766
# INFO:spectra.py:372:read_spectra: iotime 0.285 sec to read coadd-sv1-other-11524.fits at 2024-01-07T14:05:47.092063
# INFO:spectra.py:372:read_spectra: iotime 0.917 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:05:48.584982
# INFO:spectra.py:372:read_spectra: iotime 1.837 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:05:50.828470
# INFO:spectra.py:372:read_spectra: iotime 1.149 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:05:53.360223
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_32472/3924121423.py:7: RuntimeWarning: divide by zero encountered in divide
#   weight2 = 1 / ivar2
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_32472/3924121423.py:10: RuntimeWarning: invalid value encountered in divide
#   weighted_flux2 = flux2 * (weight2 / total_weight)
# INFO:spectra.py:372:read_spectra: iotime 3.509 sec to read coadd-sv3-bright-10153.fits at 2024-01-07T14:05:58.519682
# INFO:spectra.py:372:read_spectra: iotime 1.628 sec to read coadd-sv1-other-10154.fits at 2024-01-07T14:06:05.014738
# INFO:spectra.py:372:read_spectra: iotime 4.736 sec to read coadd-sv3-bright-10155.fits at 2024-01-07T14:06:12.480386
# INFO:spectra.py:372:read_spectra: iotime 5.099 sec to read coadd-sv3-dark-11521.fits at 2024-01-07T14:06:22.542257
# INFO:spectra.py:372:read_spectra: iotime 4.815 sec to read coadd-sv3-dark-10155.fits at 2024-01-07T14:06:33.252279
# INFO:spectra.py:372:read_spectra: iotime 1.524 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:06:40.943471
# INFO:spectra.py:372:read_spectra: iotime 3.894 sec to read coadd-sv3-bright-10155.fits at 2024-01-07T14:06:47.270902
# INFO:spectra.py:372:read_spectra: iotime 1.421 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:06:52.897075
# INFO:spectra.py:372:read_spectra: iotime 4.656 sec to read coadd-sv3-dark-10154.fits at 2024-01-07T14:07:00.004219
# INFO:spectra.py:372:read_spectra: iotime 4.801 sec to read coadd-sv3-dark-10155.fits at 2024-01-07T14:07:09.100638
# INFO:spectra.py:372:read_spectra: iotime 6.121 sec to read coadd-sv3-bright-10153.fits at 2024-01-07T14:07:20.012711
# INFO:spectra.py:372:read_spectra: iotime 3.040 sec to read coadd-sv3-bright-10147.fits at 2024-01-07T14:07:27.868879
# INFO:spectra.py:372:read_spectra: iotime 2.254 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:07:34.088753
# INFO:spectra.py:372:read_spectra: iotime 1.729 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:07:37.962803
# INFO:spectra.py:372:read_spectra: iotime 1.861 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:07:41.099649
# INFO:spectra.py:372:read_spectra: iotime 2.375 sec to read coadd-sv3-bright-10152.fits at 2024-01-07T14:07:45.559594
# INFO:spectra.py:372:read_spectra: iotime 1.815 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:07:50.118402
# INFO:spectra.py:372:read_spectra: iotime 4.867 sec to read coadd-sv3-dark-10153.fits at 2024-01-07T14:07:56.987496
# INFO:spectra.py:372:read_spectra: iotime 5.972 sec to read coadd-sv3-dark-10155.fits at 2024-01-07T14:08:08.258727
# INFO:spectra.py:372:read_spectra: iotime 1.583 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:08:14.692581
# INFO:spectra.py:372:read_spectra: iotime 1.773 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:08:19.243626
# INFO:spectra.py:372:read_spectra: iotime 1.689 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:08:22.910452
# INFO:spectra.py:372:read_spectra: iotime 1.513 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:08:25.731854
# INFO:spectra.py:372:read_spectra: iotime 4.932 sec to read coadd-sv3-dark-11520.fits at 2024-01-07T14:08:31.530686
# INFO:spectra.py:372:read_spectra: iotime 1.588 sec to read coadd-sv1-other-10154.fits at 2024-01-07T14:08:36.210038
# INFO:spectra.py:372:read_spectra: iotime 1.218 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:08:39.394489
# INFO:spectra.py:372:read_spectra: iotime 1.098 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:08:43.751050
# INFO:spectra.py:372:read_spectra: iotime 1.771 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:08:47.198878
# INFO:spectra.py:372:read_spectra: iotime 1.825 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:08:50.720058
# INFO:spectra.py:372:read_spectra: iotime 2.699 sec to read coadd-sv3-dark-11524.fits at 2024-01-07T14:08:55.838776
# INFO:spectra.py:372:read_spectra: iotime 2.015 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:08:59.215723
# INFO:spectra.py:372:read_spectra: iotime 1.651 sec to read coadd-sv1-other-11520.fits at 2024-01-07T14:09:03.275473
# INFO:spectra.py:372:read_spectra: iotime 5.883 sec to read coadd-sv3-dark-10156.fits at 2024-01-07T14:09:10.764214
# INFO:spectra.py:372:read_spectra: iotime 1.612 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:09:18.108662
# INFO:spectra.py:372:read_spectra: iotime 1.858 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:09:20.987672
# INFO:spectra.py:372:read_spectra: iotime 4.559 sec to read coadd-sv3-bright-10156.fits at 2024-01-07T14:09:27.419549
# INFO:spectra.py:372:read_spectra: iotime 2.861 sec to read coadd-sv3-bright-10147.fits at 2024-01-07T14:09:37.086862
# INFO:spectra.py:372:read_spectra: iotime 1.330 sec to read coadd-sv1-other-10152.fits at 2024-01-07T14:09:41.395477
# INFO:spectra.py:372:read_spectra: iotime 3.079 sec to read coadd-sv3-bright-11520.fits at 2024-01-07T14:09:45.929771
# INFO:spectra.py:372:read_spectra: iotime 1.355 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:09:51.302067
# INFO:spectra.py:372:read_spectra: iotime 2.120 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:09:54.092429
# INFO:spectra.py:372:read_spectra: iotime 5.426 sec to read coadd-sv3-dark-10155.fits at 2024-01-07T14:10:01.589842
# INFO:spectra.py:372:read_spectra: iotime 4.683 sec to read coadd-sv3-dark-10155.fits at 2024-01-07T14:10:12.937830
# INFO:spectra.py:372:read_spectra: iotime 3.207 sec to read coadd-sv3-bright-10153.fits at 2024-01-07T14:10:22.922977
# INFO:spectra.py:372:read_spectra: iotime 2.027 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:10:30.787318
# INFO:spectra.py:372:read_spectra: iotime 1.330 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:10:34.198879
# INFO:spectra.py:372:read_spectra: iotime 1.187 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:10:37.362614
# INFO:spectra.py:372:read_spectra: iotime 4.229 sec to read coadd-sv3-bright-10155.fits at 2024-01-07T14:10:42.874619
# INFO:spectra.py:372:read_spectra: iotime 4.822 sec to read coadd-sv3-bright-10156.fits at 2024-01-07T14:10:50.900994
# INFO:spectra.py:372:read_spectra: iotime 6.587 sec to read coadd-sv3-dark-10156.fits at 2024-01-07T14:11:05.444874
# INFO:spectra.py:372:read_spectra: iotime 1.287 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:11:12.644087
# INFO:spectra.py:372:read_spectra: iotime 1.481 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:11:15.416651
# INFO:spectra.py:372:read_spectra: iotime 1.981 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:11:18.440717
# INFO:spectra.py:372:read_spectra: iotime 1.120 sec to read coadd-sv1-other-10147.fits at 2024-01-07T14:11:21.544459
# INFO:spectra.py:372:read_spectra: iotime 1.085 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:11:22.983727
# INFO:spectra.py:372:read_spectra: iotime 1.432 sec to read coadd-sv1-other-10154.fits at 2024-01-07T14:11:26.275689
# INFO:spectra.py:372:read_spectra: iotime 1.372 sec to read coadd-sv1-other-10152.fits at 2024-01-07T14:11:28.427560
# INFO:spectra.py:372:read_spectra: iotime 3.954 sec to read coadd-sv3-bright-10154.fits at 2024-01-07T14:11:33.260487
# INFO:spectra.py:372:read_spectra: iotime 2.266 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:11:38.450541
# INFO:spectra.py:372:read_spectra: iotime 3.998 sec to read coadd-sv3-dark-11520.fits at 2024-01-07T14:11:46.995300
# INFO:spectra.py:372:read_spectra: iotime 1.611 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:11:52.950666
# INFO:spectra.py:372:read_spectra: iotime 1.173 sec to read coadd-sv1-other-10153.fits at 2024-01-07T14:11:56.080023
# INFO:spectra.py:372:read_spectra: iotime 1.525 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:12:00.419410
# INFO:spectra.py:372:read_spectra: iotime 1.502 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:12:04.226352
# INFO:spectra.py:372:read_spectra: iotime 1.232 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:12:07.536445
# INFO:spectra.py:372:read_spectra: iotime 0.371 sec to read coadd-sv1-other-11524.fits at 2024-01-07T14:12:09.982030
# INFO:spectra.py:372:read_spectra: iotime 1.122 sec to read coadd-sv1-other-10147.fits at 2024-01-07T14:12:11.448228
# INFO:spectra.py:372:read_spectra: iotime 2.590 sec to read coadd-sv3-bright-10152.fits at 2024-01-07T14:12:14.608632
# INFO:spectra.py:372:read_spectra: iotime 7.083 sec to read coadd-sv3-bright-10155.fits at 2024-01-07T14:12:23.840075
# INFO:spectra.py:372:read_spectra: iotime 1.612 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:12:32.496790
# INFO:spectra.py:372:read_spectra: iotime 1.702 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:12:36.376226
# INFO:spectra.py:372:read_spectra: iotime 4.236 sec to read coadd-sv3-bright-10155.fits at 2024-01-07T14:12:42.676326
# INFO:spectra.py:372:read_spectra: iotime 5.063 sec to read coadd-sv3-bright-10156.fits at 2024-01-07T14:12:51.824634
# INFO:spectra.py:372:read_spectra: iotime 1.541 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:12:59.546086
# INFO:spectra.py:372:read_spectra: iotime 1.598 sec to read coadd-sv1-other-10154.fits at 2024-01-07T14:13:01.882010
# INFO:spectra.py:372:read_spectra: iotime 1.317 sec to read coadd-sv1-other-10156.fits at 2024-01-07T14:13:05.112458
# INFO:spectra.py:372:read_spectra: iotime 1.492 sec to read coadd-sv1-other-11521.fits at 2024-01-07T14:13:08.180305
# INFO:spectra.py:372:read_spectra: iotime 1.558 sec to read coadd-sv1-other-11520.fits at 2024-01-07T14:13:13.397766
# INFO:spectra.py:372:read_spectra: iotime 3.505 sec to read coadd-sv3-bright-10154.fits at 2024-01-07T14:13:18.396086
# INFO:spectra.py:372:read_spectra: iotime 4.091 sec to read coadd-sv3-bright-10153.fits at 2024-01-07T14:13:26.541878
# INFO:spectra.py:372:read_spectra: iotime 1.440 sec to read coadd-sv1-other-10154.fits at 2024-01-07T14:13:33.175154
# INFO:spectra.py:372:read_spectra: iotime 3.413 sec to read coadd-sv3-bright-10153.fits at 2024-01-07T14:13:38.779433
# INFO:spectra.py:372:read_spectra: iotime 1.431 sec to read coadd-sv1-other-10155.fits at 2024-01-07T14:13:45.566409
# INFO:spectra.py:372:read_spectra: iotime 4.045 sec to read coadd-sv3-bright-10153.fits at 2024-01-07T14:13:51.015225
# INFO:spectra.py:372:read_spectra: iotime 5.744 sec to read coadd-sv3-dark-10156.fits at 2024-01-07T14:14:03.419263
# INFO:spectra.py:372:read_spectra: iotime 1.351 sec to read coadd-sv1-other-10150.fits at 2024-01-07T14:14:10.484299
# INFO:spectra.py:372:read_spectra: iotime 5.046 sec to read coadd-sv3-bright-10155.fits at 2024-01-07T14:14:17.788654
# INFO:spectra.py:372:read_spectra: iotime 3.463 sec to read coadd-sv3-bright-10158.fits at 2024-01-07T14:14:24.574409
# INFO:spectra.py:372:read_spectra: iotime 4.011 sec to read coadd-sv3-dark-10155.fits at 2024-01-07T14:14:33.500996
# flux_spec: [array([ 2.43335533,  0.61084831, -0.00866813, ...,  0.29354069,
#          0.34384754,  0.19168034])
#  array([-2.61322188,  0.40202418,  0.14521654, ...,  0.73069286,
#          0.67717338,  0.5820666 ])
#  array([ 8.25803185, -0.63503659, -2.17693448, ...,  0.02029419,
#          0.89067668,  1.07738185])
#  array([ 3.49341774, -2.55140233,  5.27219915, ...,  0.4224588 ,
#          0.59005213,  0.3979224 ])
#  array([17.2240181 , -5.5401988 ,  3.13099027, ...,  0.68661183,
#          2.4439919 ,  1.64336753])
#  array([-2.67049313, -1.78588569, -0.97204661, ...,  0.43655947,
#          0.33257112,  0.27583003])
#  array([-5.3562398 , -0.85808539, -3.31513643, ...,  0.66653901,
#          0.86061138,  0.45655468])
#  array([-0.1835826 , -0.06340963, -1.17598259, ...,  0.59148622,
#          0.31962723,  0.51524097])
#  array([-1.7699827 , -0.21748479, -0.49100274, ..., -0.04319405,
#          0.13237534, -0.02157807])
#  array([ 1.08820438,  0.84468454, -1.65799153, ..., -0.04145974,
#         -0.02944034, -0.14010237])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([35.03156662, 18.33257866,  3.52934194, ...,  1.29746652,
#          1.55542111,  1.51094425])
#  array([-0.09930845,  2.52775884,  0.29756221, ...,  0.34432679,
#          0.43362045,  0.54729748])
#  array([ 4.50915575, -0.13178301, 10.42954731, ...,  0.83803362,
#          0.59246272,  1.14987612])
#  array([ 2.4446826 ,  0.85755545, -5.11320257, ...,  0.67770416,
#          0.12108986,  0.62818408])
#  array([ 1.36432445,  2.46810222, -1.3625201 , ...,  0.014704  ,
#          0.49602863,  0.33987641])
#  array([1.30293775, 1.27237892, 1.64726043, ..., 0.52616113, 0.63279527,
#         0.44778204])
#  array([-6.97344589, -6.64028692, -1.92179   , ...,  1.69562185,
#          1.33262157,  1.1589371 ])
#  array([-3.38126111, -4.41534758,  6.12031889, ...,  0.82749939,
#          0.9081884 ,  0.51743805])
#  array([ 0.32355747, -4.11781406, -0.53252286, ...,  0.61443102,
#         -0.08164035,  0.44938862])
#  array([-1.44917762,  6.25815535,  0.91891116, ...,  0.15854482,
#          0.6450491 ,  0.09632397])
#  array([-8.82855129,  9.23059082, 12.98437786, ...,  0.11794742,
#          0.98117059,  1.06085122])
#  array([ 16.11919594,  -3.72200918, -21.60967064, ...,   2.055305  ,
#           1.33347571,   1.28202653])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-1.14977741, -0.4115338 , -1.24567068, ...,  0.33589107,
#          0.32319731,  0.72169936])
#  array([ 1.09631431, -1.84932435,  3.18433642, ...,  0.15354715,
#          0.21866764,  0.35109907])
#  array([-13.61173534,  -6.59351444,  11.59921646, ...,   0.82716715,
#           1.40629971,   2.25831151])
#  array([-1.80716181,  0.57476532, -1.41917741, ...,  0.13047048,
#          0.0268589 ,  0.03872349])
#  array([ 1.31012678, -5.51878786,  6.54017401, ...,  0.50136697,
#          0.05850342, -0.01109523])
#  array([0.41424564, 1.55608165, 9.72974968, ..., 0.55918914, 0.67385405,
#         1.0014987 ])
#  array([-0.27088654,  0.37320241, -0.21967079, ...,  0.33519131,
#          0.37864575,  0.34381545])
#  array([-1.293383  , -1.34332657, -0.54642791, ...,  0.17894925,
#          0.16687945,  0.15304317])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.53023732,  0.54391438,  1.48746467, ...,  0.50419903,
#          0.59006739,  0.68563789])
#  array([5.34092009e-01, 1.55834055e+00, 5.78825760e+00, ...,
#         3.71053815e-04, 3.73959780e-01, 7.61037618e-02])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.89740586,  0.18834504, -2.45918918, ...,  0.83031535,
#          0.82980931,  0.47207767])
#  array([-1.42278409, -1.91399515,  1.26808727, ...,  0.42740899,
#          0.56347036,  0.35379833])
#  array([-0.29903576,  0.20901462,  1.27053452, ...,  0.16789083,
#          0.05455012,  0.37612727])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 3.37150478, -0.66677815,  0.95671505, ..., -0.0690365 ,
#         -0.20918871,  0.35251996])
#  array([1.86081886, 3.72216129, 2.17366767, ..., 0.24891406, 0.48962069,
#         0.36371177])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 1.45752585, -3.07918239, -0.44577214, ...,  0.43567517,
#          0.24499591,  0.03346617])
#  array([ 0.70522398, -1.6086061 ,  2.25770974, ...,  0.60400933,
#          0.61149222,  0.56129116])
#  array([-0.11404669,  0.86938804,  1.03633642, ...,  0.34432027,
#          0.0826054 ,  0.61384237])
#  array([1.52659321, 9.5658474 , 4.84952927, ..., 1.35588431, 1.75015903,
#         1.46689928])
#  array([ 0.42735103, -2.51420665, -0.92307734, ...,  3.80270529,
#          4.66472054,  4.01909542])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-8.53496456, -1.15570176, -9.48403263, ...,  1.37163341,
#          1.12615526,  1.43622589])
#  array([-3.05254865,  6.08074093,  1.60339093, ...,  2.09816122,
#          2.02739906,  2.00018573])
#  array([ 0.09811218,  0.39330584, -0.90382034, ...,  0.28603056,
#          0.1596984 ,  0.20124002])
#  array([-0.654037  ,  3.41126919,  3.85125971, ..., -0.42086607,
#          0.50714195,  0.0728449 ])
#  array([ 8.83228111,  3.02257156, -6.32337093, ...,  0.23587321,
#          0.38556758,  0.34613532])
#  array([ 0.72347093,  6.75539446, -7.89611912, ...,  0.83318818,
#          0.84354478,  0.87371254])
#  array([-0.30273259, -0.08071886, -0.14397518, ...,  0.6386112 ,
#          0.5519281 ,  0.38495159])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 3.46641231, -0.44875482, -2.77039671, ...,  0.41747782,
#          0.21562356,  0.30377123])
#  array([ 5.39796734,  8.02091312, -0.08266701, ...,  1.18800199,
#          1.68989182,  1.75596344])
#  array([-4.63974142,  1.5634135 , 22.11089706, ...,  2.35667157,
#          1.33000255,  1.07498705])
#  array([-2.8289578 ,  0.56318319,  4.25358534, ...,  0.40374723,
#          0.09977778,  0.50862002])
#  array([0.35074192, 1.55554914, 2.17167163, ..., 0.79877597, 0.95176476,
#         0.77491808])
#  array([0., 0., 0., ..., 0., 0., 0.]) array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 1.49448907, -1.92768216,  0.74485034, ...,  0.21176043,
#          0.07165458,  0.04723065])
#  array([ 0.25126591, -0.50810134,  2.63278317, ...,  0.35930511,
#          0.35213801,  0.20928322])
#  array([-0.22750835,  0.67042309,  1.32121623, ...,  0.80794036,
#          0.85428339,  1.00968611])
#  array([ 0.71362185, -1.98051441,  0.03037509, ...,  0.29886106,
#          0.82238567,  0.40631816])
#  array([ 4.59078026,  1.5527643 ,  7.8351593 , ...,  0.83513403,
#         -0.15948543,  1.63268638])
#  array([-0.63186413,  0.36941326, -0.47689089, ...,  0.5746519 ,
#          0.47351232,  0.43388057])
#  array([ 3.18096089,  2.021173  ,  7.54029369, ...,  0.4272919 ,
#         -0.53597015,  0.05211856])
#  array([-4.10408545,  0.62168717,  0.03590477, ...,  0.41019037,
#          0.11867607,  0.38754746])
#  array([-2.03452754, -2.20161629, -0.80589879, ...,  1.70447838,
#          1.59183419,  1.23059678])
#  array([-0.08541783,  0.89683884, -0.12032247, ...,  0.16516538,
#          0.15253781,  0.01410545])
#  array([-0.48026857,  0.32577544,  0.41043442, ...,  0.57110375,
#          0.6840322 ,  0.67655432])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.44821671, -0.11781817, -0.50617707, ...,  0.18889758,
#          0.20770699,  0.04971944])
#  array([-2.11353922, -0.94700789, -0.29054123, ...,  0.15219608,
#          0.37305281,  0.07574645])
#  array([ 4.36850309, -5.49960661, -7.4643445 , ...,  3.12713456,
#          2.53469324,  1.99226713])
#  array([5.9955945 , 6.14461899, 4.53962374, ..., 0.53117251, 1.54488289,
#         0.98573196])
#  array([ 2.16103458, -4.62367868,  3.15827107, ...,  0.58589262,
#          0.53254741,  0.68982917])
#  array([3.66620588, 1.65175283, 1.4610765 , ..., 1.13855803, 1.15246582,
#         1.10242844])
#  array([ -6.48855686,   6.55683994, -17.74205208, ...,   1.94674015,
#           0.95980769,   0.04076623])
#  array([ 6.44553375, -3.95871305, 17.75914192, ...,  2.11110711,
#          3.0096488 , -0.2359322 ])
#  array([ 0.05329644, -0.18935776, -0.67217475, ...,  0.2109461 ,
#          0.25497434,  0.16020481])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.78909159, -2.98857212,  2.88861609, ...,  0.44034126,
#          0.42274261,  0.64192843])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 1.26974833,  0.01979811, -0.21890698, ...,  0.16055577,
#          0.36291733,  0.187215  ])
#  array([20.47024536,  0.99534041,  1.55215204, ...,  1.05578721,
#          1.08685863,  1.54925549])
#  array([9.29258537, 3.48307371, 1.17842686, ..., 1.14548087, 0.31588975,
#         0.55137724])
#  array([ 3.75611758, -0.45879561,  0.35199967, ...,  0.2008276 ,
#          0.55509853,  0.09741364])
#  array([ 3.56037402,  7.06734228, 18.71957016, ...,  1.70650971,
#          0.50039202,  1.3434974 ])
#  array([0.89579827, 0.05648043, 1.19237852, ..., 1.23531616, 1.1683656 ,
#         1.02863228])
#  array([ 2.50665617, -9.18691635,  5.81084776, ...,  1.19549859,
#          0.95826757,  1.06103337])
#  array([ 3.69142246,  3.14136434, -0.67478549, ...,  0.65898901,
#         -0.14019713,  0.1641515 ])
#  array([-0.94413161, -0.64856601, -1.47153997, ...,  0.18624498,
#          0.1821114 ,  0.1025013 ])
#  array([ 4.49402761, -4.23536396,  0.11550981, ..., -0.20593309,
#          0.64143074,  0.81575501])
#  array([8.89458847, 5.09631062, 9.82631779, ..., 1.98560297, 1.13694322,
#         0.24218088])
#  array([ 2.69002938,  2.68658686, -9.72270298, ..., -0.20951428,
#         -0.12697269,  0.18742549])                              ]
# zbin: [(-0.0019957014509158224, 1.5366456924678233)]
# 1
# Number of spectra to stack =  100
# -0.0019957014509158224 1.5366456924678233
# flux= [array([ 2.43335533,  0.61084831, -0.00866813, ...,  0.29354069,
#          0.34384754,  0.19168034])
#  array([-2.61322188,  0.40202418,  0.14521654, ...,  0.73069286,
#          0.67717338,  0.5820666 ])
#  array([ 8.25803185, -0.63503659, -2.17693448, ...,  0.02029419,
#          0.89067668,  1.07738185])
#  array([ 3.49341774, -2.55140233,  5.27219915, ...,  0.4224588 ,
#          0.59005213,  0.3979224 ])
#  array([17.2240181 , -5.5401988 ,  3.13099027, ...,  0.68661183,
#          2.4439919 ,  1.64336753])
#  array([-2.67049313, -1.78588569, -0.97204661, ...,  0.43655947,
#          0.33257112,  0.27583003])
#  array([-5.3562398 , -0.85808539, -3.31513643, ...,  0.66653901,
#          0.86061138,  0.45655468])
#  array([-0.1835826 , -0.06340963, -1.17598259, ...,  0.59148622,
#          0.31962723,  0.51524097])
#  array([-1.7699827 , -0.21748479, -0.49100274, ..., -0.04319405,
#          0.13237534, -0.02157807])
#  array([ 1.08820438,  0.84468454, -1.65799153, ..., -0.04145974,
#         -0.02944034, -0.14010237])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([35.03156662, 18.33257866,  3.52934194, ...,  1.29746652,
#          1.55542111,  1.51094425])
#  array([-0.09930845,  2.52775884,  0.29756221, ...,  0.34432679,
#          0.43362045,  0.54729748])
#  array([ 4.50915575, -0.13178301, 10.42954731, ...,  0.83803362,
#          0.59246272,  1.14987612])
#  array([ 2.4446826 ,  0.85755545, -5.11320257, ...,  0.67770416,
#          0.12108986,  0.62818408])
#  array([ 1.36432445,  2.46810222, -1.3625201 , ...,  0.014704  ,
#          0.49602863,  0.33987641])
#  array([1.30293775, 1.27237892, 1.64726043, ..., 0.52616113, 0.63279527,
#         0.44778204])
#  array([-6.97344589, -6.64028692, -1.92179   , ...,  1.69562185,
#          1.33262157,  1.1589371 ])
#  array([-3.38126111, -4.41534758,  6.12031889, ...,  0.82749939,
#          0.9081884 ,  0.51743805])
#  array([ 0.32355747, -4.11781406, -0.53252286, ...,  0.61443102,
#         -0.08164035,  0.44938862])
#  array([-1.44917762,  6.25815535,  0.91891116, ...,  0.15854482,
#          0.6450491 ,  0.09632397])
#  array([-8.82855129,  9.23059082, 12.98437786, ...,  0.11794742,
#          0.98117059,  1.06085122])
#  array([ 16.11919594,  -3.72200918, -21.60967064, ...,   2.055305  ,
#           1.33347571,   1.28202653])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-1.14977741, -0.4115338 , -1.24567068, ...,  0.33589107,
#          0.32319731,  0.72169936])
#  array([ 1.09631431, -1.84932435,  3.18433642, ...,  0.15354715,
#          0.21866764,  0.35109907])
#  array([-13.61173534,  -6.59351444,  11.59921646, ...,   0.82716715,
#           1.40629971,   2.25831151])
#  array([-1.80716181,  0.57476532, -1.41917741, ...,  0.13047048,
#          0.0268589 ,  0.03872349])
#  array([ 1.31012678, -5.51878786,  6.54017401, ...,  0.50136697,
#          0.05850342, -0.01109523])
#  array([0.41424564, 1.55608165, 9.72974968, ..., 0.55918914, 0.67385405,
#         1.0014987 ])
#  array([-0.27088654,  0.37320241, -0.21967079, ...,  0.33519131,
#          0.37864575,  0.34381545])
#  array([-1.293383  , -1.34332657, -0.54642791, ...,  0.17894925,
#          0.16687945,  0.15304317])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.53023732,  0.54391438,  1.48746467, ...,  0.50419903,
#          0.59006739,  0.68563789])
#  array([5.34092009e-01, 1.55834055e+00, 5.78825760e+00, ...,
#         3.71053815e-04, 3.73959780e-01, 7.61037618e-02])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.89740586,  0.18834504, -2.45918918, ...,  0.83031535,
#          0.82980931,  0.47207767])
#  array([-1.42278409, -1.91399515,  1.26808727, ...,  0.42740899,
#          0.56347036,  0.35379833])
#  array([-0.29903576,  0.20901462,  1.27053452, ...,  0.16789083,
#          0.05455012,  0.37612727])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 3.37150478, -0.66677815,  0.95671505, ..., -0.0690365 ,
#         -0.20918871,  0.35251996])
#  array([1.86081886, 3.72216129, 2.17366767, ..., 0.24891406, 0.48962069,
#         0.36371177])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 1.45752585, -3.07918239, -0.44577214, ...,  0.43567517,
#          0.24499591,  0.03346617])
#  array([ 0.70522398, -1.6086061 ,  2.25770974, ...,  0.60400933,
#          0.61149222,  0.56129116])
#  array([-0.11404669,  0.86938804,  1.03633642, ...,  0.34432027,
#          0.0826054 ,  0.61384237])
#  array([1.52659321, 9.5658474 , 4.84952927, ..., 1.35588431, 1.75015903,
#         1.46689928])
#  array([ 0.42735103, -2.51420665, -0.92307734, ...,  3.80270529,
#          4.66472054,  4.01909542])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-8.53496456, -1.15570176, -9.48403263, ...,  1.37163341,
#          1.12615526,  1.43622589])
#  array([-3.05254865,  6.08074093,  1.60339093, ...,  2.09816122,
#          2.02739906,  2.00018573])
#  array([ 0.09811218,  0.39330584, -0.90382034, ...,  0.28603056,
#          0.1596984 ,  0.20124002])
#  array([-0.654037  ,  3.41126919,  3.85125971, ..., -0.42086607,
#          0.50714195,  0.0728449 ])
#  array([ 8.83228111,  3.02257156, -6.32337093, ...,  0.23587321,
#          0.38556758,  0.34613532])
#  array([ 0.72347093,  6.75539446, -7.89611912, ...,  0.83318818,
#          0.84354478,  0.87371254])
#  array([-0.30273259, -0.08071886, -0.14397518, ...,  0.6386112 ,
#          0.5519281 ,  0.38495159])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 3.46641231, -0.44875482, -2.77039671, ...,  0.41747782,
#          0.21562356,  0.30377123])
#  array([ 5.39796734,  8.02091312, -0.08266701, ...,  1.18800199,
#          1.68989182,  1.75596344])
#  array([-4.63974142,  1.5634135 , 22.11089706, ...,  2.35667157,
#          1.33000255,  1.07498705])
#  array([-2.8289578 ,  0.56318319,  4.25358534, ...,  0.40374723,
#          0.09977778,  0.50862002])
#  array([0.35074192, 1.55554914, 2.17167163, ..., 0.79877597, 0.95176476,
#         0.77491808])
#  array([0., 0., 0., ..., 0., 0., 0.]) array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 1.49448907, -1.92768216,  0.74485034, ...,  0.21176043,
#          0.07165458,  0.04723065])
#  array([ 0.25126591, -0.50810134,  2.63278317, ...,  0.35930511,
#          0.35213801,  0.20928322])
#  array([-0.22750835,  0.67042309,  1.32121623, ...,  0.80794036,
#          0.85428339,  1.00968611])
#  array([ 0.71362185, -1.98051441,  0.03037509, ...,  0.29886106,
#          0.82238567,  0.40631816])
#  array([ 4.59078026,  1.5527643 ,  7.8351593 , ...,  0.83513403,
#         -0.15948543,  1.63268638])
#  array([-0.63186413,  0.36941326, -0.47689089, ...,  0.5746519 ,
#          0.47351232,  0.43388057])
#  array([ 3.18096089,  2.021173  ,  7.54029369, ...,  0.4272919 ,
#         -0.53597015,  0.05211856])
#  array([-4.10408545,  0.62168717,  0.03590477, ...,  0.41019037,
#          0.11867607,  0.38754746])
#  array([-2.03452754, -2.20161629, -0.80589879, ...,  1.70447838,
#          1.59183419,  1.23059678])
#  array([-0.08541783,  0.89683884, -0.12032247, ...,  0.16516538,
#          0.15253781,  0.01410545])
#  array([-0.48026857,  0.32577544,  0.41043442, ...,  0.57110375,
#          0.6840322 ,  0.67655432])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.44821671, -0.11781817, -0.50617707, ...,  0.18889758,
#          0.20770699,  0.04971944])
#  array([-2.11353922, -0.94700789, -0.29054123, ...,  0.15219608,
#          0.37305281,  0.07574645])
#  array([ 4.36850309, -5.49960661, -7.4643445 , ...,  3.12713456,
#          2.53469324,  1.99226713])
#  array([5.9955945 , 6.14461899, 4.53962374, ..., 0.53117251, 1.54488289,
#         0.98573196])
#  array([ 2.16103458, -4.62367868,  3.15827107, ...,  0.58589262,
#          0.53254741,  0.68982917])
#  array([3.66620588, 1.65175283, 1.4610765 , ..., 1.13855803, 1.15246582,
#         1.10242844])
#  array([ -6.48855686,   6.55683994, -17.74205208, ...,   1.94674015,
#           0.95980769,   0.04076623])
#  array([ 6.44553375, -3.95871305, 17.75914192, ...,  2.11110711,
#          3.0096488 , -0.2359322 ])
#  array([ 0.05329644, -0.18935776, -0.67217475, ...,  0.2109461 ,
#          0.25497434,  0.16020481])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.78909159, -2.98857212,  2.88861609, ...,  0.44034126,
#          0.42274261,  0.64192843])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([ 1.26974833,  0.01979811, -0.21890698, ...,  0.16055577,
#          0.36291733,  0.187215  ])
#  array([20.47024536,  0.99534041,  1.55215204, ...,  1.05578721,
#          1.08685863,  1.54925549])
#  array([9.29258537, 3.48307371, 1.17842686, ..., 1.14548087, 0.31588975,
#         0.55137724])
#  array([ 3.75611758, -0.45879561,  0.35199967, ...,  0.2008276 ,
#          0.55509853,  0.09741364])
#  array([ 3.56037402,  7.06734228, 18.71957016, ...,  1.70650971,
#          0.50039202,  1.3434974 ])
#  array([0.89579827, 0.05648043, 1.19237852, ..., 1.23531616, 1.1683656 ,
#         1.02863228])
#  array([ 2.50665617, -9.18691635,  5.81084776, ...,  1.19549859,
#          0.95826757,  1.06103337])
#  array([ 3.69142246,  3.14136434, -0.67478549, ...,  0.65898901,
#         -0.14019713,  0.1641515 ])
#  array([-0.94413161, -0.64856601, -1.47153997, ...,  0.18624498,
#          0.1821114 ,  0.1025013 ])
#  array([ 4.49402761, -4.23536396,  0.11550981, ..., -0.20593309,
#          0.64143074,  0.81575501])
#  array([8.89458847, 5.09631062, 9.82631779, ..., 1.98560297, 1.13694322,
#         0.24218088])
#  array([ 2.69002938,  2.68658686, -9.72270298, ..., -0.20951428,
#         -0.12697269,  0.18742549])                              ]
# Spectra corrected for foreground extinction.
# flux_new: [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Fnorm: [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# /Users/s2537809/Documents/DESI-STACKING/stack_code.py:248: RuntimeWarning: invalid value encountered in divide
#   Fnorm = flux_new / np.median(flux_new[:, norm_range], axis=1, keepdims=True)
# Stack[0]: [3.39054635 4.76134839 9.14861984 ...        nan        nan        nan]
# Stack[1]: [3.39054635 4.76134839 9.14861984 ...        nan        nan        nan]
# Stack[2]: [ 1.  1.  1. ... 13. 13.  7.]

# %%
#stack spectra in two redshift bins (i.e 0<z<0.1 and 0.1<z<0.2) - need to alter
#SFG_stacks = get_stack(SFG_spec, zbins=[[0.0,0.5],[0.5,1.0],[1.0,4.0]])
#soemtimes the redshift is less than 0?

## try adjusting these boundarys and adding more bins instead of binning seperately

# %% [markdown]
# ## Plot Stacked Spectra

# %%
print('Min:',SFG_stack['zbin=0']['wln'][0])
print('Max:',SFG_stack['zbin=0']['wln'][-1])
# Out:
# Min: 1117.5
# Max: 9843.5

# %%
plt.figure(figsize=(20,6))
plt.plot(stack_outputs[2]['zbin=0']['wln'],stack_outputs[2]['zbin=0']['flux'], color='purple', alpha=0.5, label = f'DESI {Overall_class} Stacked Spectra')
plt.plot(stack_outputs[2]['zbin=0']['wln'],convolve(stack_outputs[2]['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
plt.legend()
# Out:
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(20, 36), sharey=True)

# Define the labels for the legend
labels = ['SFG Low SFR Bin 1', 'SFG Low SFR Bin 2', 'SFG Mid SFR Bin 1', 'SFG Mid SFR Bin 2', 'SFG High SFR Bin 1', 'SFG High SFR Bin 2']

# Loop over each stack output and plot in a separate subplot
for i, (stack_output, label) in enumerate(zip(stack_outputs, labels)):
    ax = axes[i]  # Select the current subplot
    
    # Plot the stacked spectra
    ax.plot(stack_output['zbin=0']['wln'], stack_output['zbin=0']['flux'], color='purple', alpha=0.5,
            label=f'DESI {label} Stacked Spectra')
    
    # Plot the convolved spectra
    ax.plot(stack_output['zbin=0']['wln'], convolve(stack_output['zbin=0']['flux'], Gaussian1DKernel(5)),
            color='black', alpha=1)
    
    ax.set_ylabel('$F_{\lambda}$ [$10^{-17} \, \mathrm{erg\ s^{-1}\ cm^{-2}\ \AA^{-1}}$]')
    ax.set_xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
    ax.set_ylim(-5, 10)
    ax.set_xlim(1800, 10000)
    ax.legend()

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]

# %%
# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-plots-Mass.pdf'
with PdfPages(pdf_filename) as pdf:
    # Create a figure with three subplots
    fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(20, 36), sharey=True)

    # Define the labels for the legend
    labels = ['Low SFR Bin 1', 'Low SFR Bin 2', 'Mid SFR Bin 1', 'Mid SFR Bin 2', 'High SFR Bin 1', 'High SFR Bin 2']

    # Loop over each stack output and plot in a separate subplot
    for i, (stack_output, label) in enumerate(zip(stack_outputs, labels)):
        ax = axes[i]  # Select the current subplot

        # Plot the stacked spectra
        ax.plot(stack_output['zbin=0']['wln'], stack_output['zbin=0']['flux'], color='purple', alpha=0.5,
                label=f'DESI SFG {label} Stacked Spectra Mass')

        # Plot the convolved spectra
        ax.plot(stack_output['zbin=0']['wln'], convolve(stack_output['zbin=0']['flux'], Gaussian1DKernel(5)),
                color='black', alpha=1)

        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} \, \mathrm{erg\ s^{-1}\ cm^{-2}\ \AA^{-1}}$]')
        ax.set_xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
        ax.set_ylim(-5, 10)
        ax.set_xlim(1000, 10000)
        ax.legend()

        # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# All the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')
# Out:
# All plots saved in DESI-SFG-stacked-plots-Mass.pdf

# %%
plt.figure(figsize=(20,6))
plt.plot(SFG_stack['zbin=0']['wln'],SFG_stack['zbin=0']['flux'], color='purple', alpha=0.5, label = f'DESI {Overall_class} Stacked Spectra')
plt.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
plt.legend()

# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-plots-practice.pdf'
with PdfPages(pdf_filename) as pdf:
        fig, ax = plt.subplots(figsize=(12, 8))
        ax.plot(SFG_stack['zbin=0']['wln'],SFG_stack['zbin=0']['flux'], color='purple', alpha=0.5,label = f'DESI {Overall_class} Stacked Spectra')
        ax.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
        ax.set_xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
        ax.legend()

     # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# All the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')
# Out:
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]
# All plots saved in DESI-SFG-stacked-plots-practice.pdf

# %%
# Would need to adjust the wavelength ranges to the rest-fram wavelength ranges to do this



wavelength = SFG_stack['zbin=0']['wln']
flux = SFG_stack['zbin=0']['flux']

plt.figure(figsize=(20, 6))
plt.plot(wavelength[wavelength <= 5800], flux[wavelength <= 5800], color='blue', alpha=0.5)
plt.plot(wavelength[(wavelength > 5760) & (wavelength <= 7620)], flux[(wavelength > 5760) & (wavelength <= 7620)], color='green', alpha=0.5)
plt.plot(wavelength[wavelength > 7520], flux[wavelength > 7520], color='red', alpha=0.5)
plt.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
plt.xlim(1000,9900)
plt.show()

# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-plots-practice.pdf'
with PdfPages(pdf_filename) as pdf:
        fig, ax = plt.subplots(figsize=(20, 6))
        ax.plot(wavelength[wavelength <= 5800], flux[wavelength <= 5800], color='blue', alpha=0.5)
        ax.plot(wavelength[(wavelength > 5760) & (wavelength <= 7620)], flux[(wavelength > 5760) & (wavelength <= 7620)], color='green', alpha=0.5)
        ax.plot(wavelength[wavelength > 7520], flux[wavelength > 7520], color='red', alpha=0.5)
        ax.plot(SFG_stack['zbin=0']['wln'],convolve(SFG_stack['zbin=0']['flux'], Gaussian1DKernel(5)), color='black', alpha=1)
        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
        ax.set_xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
        ax.set_xlim(3500,9900)

     # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# All the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')


### it appears that the problem is with the second half of the rqagn then ?? 
## it is the specifc values and not the size of the range ???
# Out:
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# All plots saved in DESI-SFG-stacked-plots-practice.pdf

# %%
"""

The lack of simulated correction might be having an impact ?
Need to use different redshift bins - why does DESI have negative redshifts?
Why is there such a difference between the bins?

"""


plt.figure(figsize=(20,6))
plt.plot(SFG_stacks['zbin=0']['wln'],SFG_stacks['zbin=0']['flux'], label='0.0<z<0.5', color='yellow', alpha=0.5)
plt.plot(SFG_stacks['zbin=1']['wln'],SFG_stacks['zbin=1']['flux'], label='0.5<z<1.0', color='red', alpha=0.5)
plt.plot(SFG_stacks['zbin=2']['wln'],SFG_stacks['zbin=2']['flux'], label='1.0<z<4.0', color='green', alpha=0.5)
plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
plt.xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
plt.legend()


# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-zbin-plots-practice.pdf'
with PdfPages(pdf_filename) as pdf:
        fig, ax = plt.subplots(figsize=(12, 8))
        ax.plot(SFG_stacks['zbin=0']['wln'],SFG_stacks['zbin=0']['flux'], label='0.0<z<0.5', color='yellow', alpha=0.5)
        ax.plot(SFG_stacks['zbin=1']['wln'],SFG_stacks['zbin=1']['flux'], label='0.5<z<1.0', color='red', alpha=0.5)
        ax.plot(SFG_stacks['zbin=2']['wln'],SFG_stacks['zbin=2']['flux'], label='1.0<z<4.0', color='green', alpha=0.5)
        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
        ax.set_xlabel('Rest-frame wavelength, $\lambda$ [$\AA$]')
        ax.legend()
     # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# After the loop, all the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')
# Out:
# All plots saved in DESI-SFG-stacked-zbin-plots-practice.pdf
