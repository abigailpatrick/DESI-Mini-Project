# %% [markdown]
# # THIS CODE CONCATENATES WITH INVERSE VAR WEIGHTING

# %%
from astropy.table import Table, vstack, Column, MaskedColumn, pprint
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt
from astropy.convolution import convolve, Gaussian1DKernel

from astropy.io import fits
from matplotlib.backends.backend_pdf import PdfPages

import os
import requests
import sys
sys.path.append('/Users/s2537809/DESI/desispec/py')
sys.path.append('/Users/s2537809/DESI/desimodel/py')
sys.path.append('/Users/s2537809/DESI/desitarget/py')
sys.path.append('/Users/s2537809/DESI/desiutil/py')

#from desispec.io import read_spectra
# import DESI related modules - 
from desimodel.footprint import radec2pix      # For getting healpix values
import desispec.io                             # Input/Output functions related to DESI spectra
from desispec import coaddition                # Functions related to coadding the spectra


from scipy import interpolate
import astropy.units as u
path='/Users/s2537809/Documents/DESI-STACKING'#specify code directory
os.chdir(path)
import stack_code as sc
import importlib
import fnmatch
import extinction as ext
from scipy.optimize import curve_fit
from astropy.coordinates import SkyCoord
from astropy.modeling import models
from astropy.table import Table
from matplotlib import gridspec
import spectres
import time
import warnings

#pip install lmfit, extinction, sfdmap, spectres

import pandas as pd
crossmatch = Table.read('crossmatch_classifications.fits', format = 'fits' )
# Out:
# /Users/s2537809/DESI/desispec/py/desispec/qproc/qextract.py:19: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_extract(image_flux,image_var,x,hw=3) :
# /Users/s2537809/DESI/desispec/py/desispec/image_model.py:27: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_proj(image,x,sigma,flux) :
# /Users/s2537809/DESI/desispec/py/desispec/preproc.py:379: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def numba_mean(image_flux,image_ivar,x,hw=3) :

# %% [markdown]
# ## Cell below verifies if Spectra are downloaded and downloads if they aren't
#
# Only run if unsure if spectra are downloaded, to save time!

# %%
"""
Note: The lengths for indexing are:

HERG = 184

RQAGN = 814

LERG = 1293

SFG = 6294

"""


Overall_class = 'SFG'
my_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][1000:1200]
search_column_name = 'TARGETID'
search_values = np.array(my_table[f'{search_column_name}'])



def select_data(table, column_name, search_values):
    # Get the column data as a numpy array
    column_data = table[column_name]

    SURVEY = []
    PROGRAM = []
    HEALPIX = []
    n_values = []
    Z = []
    

    for search_value in search_values:
        # Find the indices where the condition is met (value == search_value)
        indices = np.where(column_data == search_value)[0]


        if len(indices) > 0:
            # Find the corresponding Survey, program, healpix, and Z values
            SURVEY.append(table['SURVEY'][indices[0]])
            PROGRAM.append(table['PROGRAM'][indices[0]])
            HEALPIX.append(table['HEALPIX'][indices[0]])
            Z.append(table['Z'][indices[0]])
            HEALPIX_str = str(table['HEALPIX'][indices[0]])
            n_str = HEALPIX_str[:3]
            n_values.append(int(n_str))
        else:
            # Handle the case where the search value was not found
            SURVEY.append(None)
            PROGRAM.append(None)
            HEALPIX.append(None)
            n_values.append(None)
            Z.append(None)
    

    return np.array(SURVEY), np.array(PROGRAM), np.array(HEALPIX), np.array(n_values), np.array(Z), 


SURVEY = select_data(my_table, search_column_name, search_values)[0]
PROGRAM = select_data(my_table, search_column_name, search_values)[1]
HEALPIX = select_data(my_table, search_column_name, search_values)[2]
n = select_data(my_table, search_column_name, search_values)[3]
Z = select_data(my_table, search_column_name, search_values)[4]
print (SURVEY,PROGRAM,HEALPIX, n, Z)

for n, survey, program, healpix, Z, search_value in zip(n, SURVEY, PROGRAM, HEALPIX, Z, search_values):
        #download the file from the given Target ID
        target_url = f"https://data.desi.lbl.gov/public/edr/spectro/redux/fuji/healpix/{survey}/{program}/{n}/{healpix}/coadd-{survey}-{program}-{healpix}.fits"
        
        # Define the folder name and file name
        folder_name = 'DESI_Downloads'
        file_name = f"coadd-{survey}-{program}-{healpix}.fits"
        print(search_value)


        # Check if the folder exists, and create it if it doesn't
        if not os.path.exists(folder_name):
            os.makedirs(folder_name)

        # Check if the file exists in the folder
        file_path = os.path.join(folder_name, file_name)
        if os.path.exists(file_path):
            print(f"{file_name} already exists in {folder_name}. No need to download.")
        else:
            # File doesn't exist, download it
            try:
                response = requests.get(target_url)
                if response.status_code == 200:
                    with open(file_path, 'wb') as file:
                        file.write(response.content)
                    print(f"{file_name} downloaded to {folder_name}.")
                else:
                    print(f"Failed to download {file_name}. Status code: {response.status_code}")
            except Exception as e:
                print(f"An error occurred while downloading {file_name}: {str(e)}")
# Out:
# ['sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1' 'sv1'
#  'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv1' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1'
#  'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv1' 'sv1' 'sv3'
#  'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv1' 'sv1' 'sv1' 'sv3'
#  'sv1' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3'
#  'sv1' 'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv1' 'sv1'
#  'sv1' 'sv3' 'sv3' 'sv3' 'sv3' 'sv1' 'sv1' 'sv3' 'sv3' 'sv1' 'sv3' 'sv3'
#  'sv3' 'sv3' 'sv3' 'sv1' 'sv3' 'sv1' 'sv3' 'sv3'] ['bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright'
#  'bright' 'other' 'bright' 'bright' 'dark' 'other' 'other' 'bright'
#  'bright' 'dark' 'other' 'other' 'bright' 'bright' 'other' 'other'
#  'bright' 'other' 'dark' 'bright' 'bright' 'dark' 'bright' 'other' 'other'
#  'bright' 'other' 'other' 'other' 'bright' 'bright' 'other' 'bright'
#  'bright' 'bright' 'bright' 'other' 'other' 'other' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright' 'bright'
#  'other' 'other' 'bright' 'dark' 'dark' 'bright' 'other' 'other' 'dark'
#  'other' 'bright' 'bright' 'bright' 'bright' 'bright' 'other' 'dark'
#  'dark' 'other' 'other' 'other' 'other' 'other' 'bright' 'other' 'bright'
#  'bright' 'other' 'dark' 'bright' 'bright' 'other' 'other' 'bright'
#  'other' 'other' 'bright' 'bright' 'other' 'dark' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'other' 'bright' 'bright' 'bright' 'bright'
#  'bright' 'other' 'bright' 'other' 'bright' 'bright' 'other' 'bright'
#  'bright' 'dark' 'bright' 'bright' 'bright' 'other' 'dark' 'other'
#  'bright' 'bright' 'bright' 'other' 'other' 'bright' 'other' 'other'
#  'bright' 'other' 'dark' 'bright' 'other' 'bright' 'dark' 'other' 'bright'
#  'other' 'other' 'other' 'bright' 'other' 'bright' 'other' 'bright' 'dark'
#  'bright' 'other' 'other' 'bright' 'bright' 'dark' 'bright' 'other'
#  'other' 'bright' 'bright' 'bright' 'dark' 'other' 'bright' 'bright'
#  'bright' 'bright' 'bright' 'other' 'other' 'dark' 'bright' 'bright'
#  'bright' 'dark' 'bright' 'other' 'other' 'other' 'other' 'other' 'bright'
#  'bright' 'bright' 'dark' 'other' 'other' 'dark' 'bright' 'other' 'bright'
#  'bright' 'bright' 'dark' 'dark' 'other' 'bright' 'other' 'backup'
#  'backup'] [10152 10154 10152 11521 10154 11521 10152 10154 10154 11521 10154 11521
#  10152 11521 11521 10154 10154 10154 10152 10152 10154 10154 10154 10154
#  11521 10152 11521 10152 10152 10154 11521 10154 10154 10155 10154 10154
#  10152 10154 10154 10154 10154 11521 10154 10154 10154 10154 10154 11521
#  10154 11521 10152 10154 10154 11521 10154 11521 10154 11521 11521 10154
#  10152 11521 11521 11521 11521 10154 10152 10154 10154 11521 10154 10154
#  11521 10154 11521 10154 10154 10152 11521 10154 10154 10155 11521 11521
#  10152 11521 10154 10154 11521 10152 10154 10154 11521 11521 11521 10155
#  11521 11521 11521 10155 10154 11521 10154 11521 10154 11521 10154 11521
#  11521 11521 10154 11521 10154 10154 10154 11521 10155 10154 10152 11521
#  11521 10154 10154 10154 11521 10154 10152 11521 10154 10154 10154 11521
#  10152 10154 10154 11521 11521 11521 10154 11521 11521 10154 10155 10154
#  10154 11521 10154 10152 10152 10154 11521 11521 11521 10155 11521 11521
#  10154 10152 10155 10155 11521 11521 10154 11521 10154 10152 10155 10155
#  11521 10152 10154 10154 10154 10152 11521 10155 10152 10152 10152 10152
#  11521 11521 10152 10154 10154 11521 10152 10154 10152 11521 10154 10152
#  11521 10154 11521 11521 10154 10154 11521 10152] [101 101 101 115 101 115 101 101 101 115 101 115 101 115 115 101 101 101
#  101 101 101 101 101 101 115 101 115 101 101 101 115 101 101 101 101 101
#  101 101 101 101 101 115 101 101 101 101 101 115 101 115 101 101 101 115
#  101 115 101 115 115 101 101 115 115 115 115 101 101 101 101 115 101 101
#  115 101 115 101 101 101 115 101 101 101 115 115 101 115 101 101 115 101
#  101 101 115 115 115 101 115 115 115 101 101 115 101 115 101 115 101 115
#  115 115 101 115 101 101 101 115 101 101 101 115 115 101 101 101 115 101
#  101 115 101 101 101 115 101 101 101 115 115 115 101 115 115 101 101 101
#  101 115 101 101 101 101 115 115 115 101 115 115 101 101 101 101 115 115
#  101 115 101 101 101 101 115 101 101 101 101 101 115 101 101 101 101 101
#  115 115 101 101 101 115 101 101 101 115 101 101 115 101 115 115 101 101
#  115 101] [ 3.35145291e-01  2.47546395e-01  3.51474847e-01  2.13741842e-01
#   2.60245790e-01  2.46776309e-01  3.26101244e-01  3.50294377e-01
#   2.48664978e-01  2.30915676e-01  2.67320575e-01  2.51255934e-01
#   1.32054771e+00  4.66177402e-01  8.94670238e-01  2.64692571e-01
#   2.06842153e-01  1.18354918e+00  6.16881356e-01  9.71320367e-01
#   5.00949636e-01  1.43829866e-01  4.76371842e-01  1.18181335e+00
#   1.13551269e-01  9.56587148e-01  1.14206160e+00  4.20989635e-01
#   2.23063008e-01  2.62026642e-01  4.06392886e-01 -1.99570145e-03
#   1.61394631e+00  4.77336916e-01  3.45942222e-01  4.37611319e-01
#   1.18263070e+00  2.94771704e-01  3.26752756e-01 -1.99570145e-03
#   3.22729213e-01  2.25642234e-01  4.70261812e-01  2.60548780e-01
#   1.00551746e+00  9.03125446e-01  2.62803606e-01  4.15334710e-01
#   4.78697777e-02  3.01728664e-01  2.47619772e-01  2.12142287e-01
#   2.60254741e-01  2.51951408e-01  3.27000936e-01  2.40847110e-01
#   1.47463133e-01  8.06549617e-01  8.15919143e-01  4.65331591e-01
#   9.57477660e-01  7.52400543e-01  2.98955876e-01  4.92391271e-01
#  -1.99570145e-03  2.36904500e+00  6.47611703e-01  2.62972521e-01
#   2.65348851e-01  2.49709585e-01  2.10873257e-01  2.70182415e-01
#   5.72395385e-01  6.76710731e-01  7.10427329e-01  4.72487169e-01
#   1.25386578e+00  5.74550204e-01 -1.99570145e-03  6.12581395e-01
#   3.38195228e-01 -1.99570145e-03  2.53992626e-01  3.98017042e-01
#   9.58143966e-01  3.37176488e-01  2.75735084e-01  2.63472260e-01
#   7.59646502e-01  1.70988878e-01  2.38028642e-01  2.45220551e-01
#   6.64954428e-01  2.48519854e-01  4.06864414e-01  7.59687869e-01
#   7.37262654e-01  2.06402577e-01  3.37734549e-01  2.66866943e-01
#   2.10601248e-01  4.41680646e-01  4.52201856e-01  4.98444339e-02
#  -1.99569129e-03  2.31138140e-01  2.58271269e-01  4.40589866e-01
#   3.16568144e-01  1.07066125e-01  6.36902678e-01  3.23551450e-01
#   2.07949892e-01  1.42424417e+00  1.83040205e-01  2.28335580e-01
#   1.26313829e+00  2.36690044e-01  2.22107843e-01  2.89424617e-01
#  -1.99570145e-03  6.13595807e-01  3.46999254e-01  3.92465185e-01
#   4.06637584e-01  2.62197770e-01  2.22658176e-01  3.87577344e-01
#   8.31122973e-02  9.41927038e-01  3.19716211e-01  2.14372227e-01
#   1.01801308e+00  1.11760550e+00  4.17545529e-01  4.93845663e-01
#   3.03088749e-01  1.25986723e+00  4.30977354e-01  2.51786180e-01
#   3.33530562e-01 -1.99570145e-03  4.95964185e-01  2.65083905e-01
#   3.14700478e-01  4.04847697e-01  4.30283532e-01  2.57139736e-01
#   1.11580458e+00  1.47590864e-01  4.71829153e-01  4.28236748e-01
#   4.05566016e-01  2.63668566e-01  8.03809807e-01  3.28498005e-01
#   1.18411999e+00  5.55423332e-01  1.88907020e-01  1.88025265e-01
#   1.36714944e-01  1.36668873e+00  1.18389185e+00  3.87780029e-01
#   2.12478393e-01  3.26275299e-01  3.92941940e-01  2.60161886e-01
#   2.09195372e-01 -1.99570145e-03  5.30797823e-01  3.37288903e-01
#   2.08938025e-01  6.45889139e-02  6.52192040e-01  2.34304472e-01
#   1.18289867e+00  7.32124331e-01  3.48583331e-01  3.87177342e-01
#  -1.99570145e-03  3.03327379e-02  2.47141434e-01  9.23367520e-02
#   1.06122598e+00  3.41469365e-01  9.04649766e-01  8.86065561e-01
#   6.48397814e-02 -1.99570145e-03  3.35562472e-01  4.10595427e-02
#   1.45934177e-01  1.17756972e+00  1.14986790e+00  7.38655253e-01
#   2.43709265e-01  6.38046178e-01  4.95573579e-02  6.57485407e-02]
# 39633304823008514
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982975969
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396555936
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932938903
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468443875
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015647
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008573
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308396555958
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468443898
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008188
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468443902
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015678
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008590
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932938945
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015720
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976058
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936751
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538058
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008682
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308396556073
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633311944936784
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936786
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976100
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556087
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015757
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008714
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633329376463774
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308396556090
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633304823008722
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633315476538100
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015773
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538118
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 213624597512203
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444049
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633311944936838
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936850
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008798
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982976184
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976186
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936860
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444078
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008327
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444091
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538211
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556220
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936891
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936898
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939121
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944936897
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196401992
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823008865
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633315476538259
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944936944
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376463927
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976313
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402018
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976328
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799015888
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939200
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976347
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308396556302
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402028
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376463948
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015908
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799015912
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944936993
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008926
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982976389
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976403
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376463988
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444230
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944937038
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939274
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976442
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008466
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976450
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 213624597512196
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304823008991
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633332799015965
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538416
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538437
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939336
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633329376464089
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008514
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304823009073
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633325932939360
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538476
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976557
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016060
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308396556500
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633311944937171
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538517
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016074
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016076
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402183
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444396
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633339577008598
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008627
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464206
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444490
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633315476538598
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402250
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976719
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464220
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976735
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633339577008650
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976749
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939529
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577008672
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464268
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311944937314
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464266
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976782
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311944937324
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538635
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016198
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444546
# coadd-sv3-dark-10155.fits already exists in DESI_Downloads. No need to download.
# 39633318982976791
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746553
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633329376464302
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016225
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982976840
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976847
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633322468444584
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464325
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538672
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746587
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402344
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538679
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976866
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982976871
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939622
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308400746634
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746638
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538705
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016261
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016285
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939655
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538738
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633329376464395
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016309
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127747
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939691
# coadd-sv1-other-10155.fits already exists in DESI_Downloads. No need to download.
# 39633318982976981
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311949127768
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633336196402452
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127790
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199794
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746719
# coadd-sv3-dark-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977050
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016358
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633329376464481
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402481
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939767
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633325932939775
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633336196402503
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476538869
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199873
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633322468444756
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633322468444768
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633339577008893
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633332799016400
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982977125
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016407
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949127878
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827199916
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633322468444809
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633322468444834
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633336196402570
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304827199972
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977255
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476538991
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633318982977261
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400746897
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577008995
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633322468444890
# coadd-sv3-bright-10155.fits already exists in DESI_Downloads. No need to download.
# 39633308400746911
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746926
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633308400746933
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633304827200045
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633336196402641
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633325932939926
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633304827200056
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977346
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633311949128018
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633325932939952
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633308400746994
# coadd-sv1-other-10152.fits already exists in DESI_Downloads. No need to download.
# 39633318982977418
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633308400747026
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577009097
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633318982977442
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633304827200127
# coadd-sv3-bright-10152.fits already exists in DESI_Downloads. No need to download.
# 39633339577009104
# coadd-sv3-bright-11521.fits already exists in DESI_Downloads. No need to download.
# 39633311949128097
# coadd-sv3-dark-10154.fits already exists in DESI_Downloads. No need to download.
# 39633332799016602
# coadd-sv3-dark-11521.fits already exists in DESI_Downloads. No need to download.
# 39633339577009120
# coadd-sv1-other-11521.fits already exists in DESI_Downloads. No need to download.
# 39633315476539133
# coadd-sv3-bright-10154.fits already exists in DESI_Downloads. No need to download.
# 39633315476539148
# coadd-sv1-other-10154.fits already exists in DESI_Downloads. No need to download.
# 2305843021293300240
# coadd-sv3-backup-11521.fits already exists in DESI_Downloads. No need to download.
# 2305843019858848671
# coadd-sv3-backup-10152.fits already exists in DESI_Downloads. No need to download.

# %% [markdown]
# # Wavelength Overlap Regions Weighted Average

# %%
def inv_var_weighted_average(flux1, ivar1, flux2, ivar2):
    """
    Finds the inverse varience weighted average of two flux spectra
    
    """
    weight1 = 1 / ivar1
    weight2 = 1 / ivar2
    total_weight = weight1 + weight2
    weighted_flux1 = flux1 * (weight1 / total_weight)
    weighted_flux2 = flux2 * (weight2 / total_weight)
    weighted_avg = weighted_flux1 + weighted_flux2
    return weighted_avg

def no_overlap_f(waveb,fluxb,waver,fluxr,wavez,fluxz):
    """
    Isolates the flux and wavelength arrays of each band to non-overlapping wavelength sections
    
    """
    new_b_length = np.where(waveb<waver[0])
    b_wave = waveb[new_b_length]
    b_flux = fluxb[new_b_length]
    new_r_length = np.where((waver>waveb[-1])&(waver<wavez[0]))
    r_wave = waver[new_r_length]
    r_flux = fluxr[new_r_length]
    new_z_length = np.where(wavez>waver[-1])
    z_wave = wavez[new_z_length]
    z_flux = fluxz[new_z_length]

    return b_wave,b_flux,r_wave,r_flux,z_wave,z_flux


def overlap_av(wave1,wave2,flux1,flux2,ivar1,ivar2):
    """
    Finds the overlap of two wavelength ranges.
    Computes the inverse var weighted average flux and wavelength for th eoverlapping range 
    
    """
    overlap_idx_1 = np.where(wave1 >= wave2[0]) 
    overlap_wave = wave1[overlap_idx_1]
    overlap_flux_1 = flux1[overlap_idx_1]
    overlap_ivar_1 = ivar1[overlap_idx_1]

    overlap_idx_2 = np.where(wave2 <= wave1[-1]) 
    overlap_flux_2 = flux2[overlap_idx_2]
    overlap_ivar_2 = ivar2[overlap_idx_2]
    
    overlap_av_flux = inv_var_weighted_average(overlap_flux_1,overlap_ivar_1,overlap_flux_2,overlap_ivar_2)

    return overlap_av_flux, overlap_wave

# %% [markdown]
# # Stacking Functions

# %%
#stacking functions

# Ignore warnings due to spec_var=0
warnings.filterwarnings("ignore", message="divide by zero encountered in true_divide")


def get_spectra(table, column_name, search_values): 
    print('Number of spectra =', len(table))
    # Get the Target IDs as a numpy array
    column_data = table[column_name]

    SURVEY, PROGRAM, HEALPIX, n_values = [], [], [], []
    Z, RA, DEC, Source_ID = [], [], [], []


    for search_value in search_values:
        # Find the indices where the condition is met (value == search_value)
        # This is only relevant if input is doen by search value and not selected table
        indices = np.where(column_data == search_value)[0]

        if len(indices) > 0:
            # Find the corresponding Survey, program, healpix, Z , RA and Dec values
            SURVEY.append(table['SURVEY'][indices[0]])
            PROGRAM.append(table['PROGRAM'][indices[0]])
            HEALPIX.append(table['HEALPIX'][indices[0]])
            Z.append(table['Z'][indices[0]])
            RA.append(table['TARGET_RA'][indices[0]]) 
            DEC.append(table['TARGET_DEC'][indices[0]])
            Source_ID.append(table['TARGETID'][indices[0]])
            HEALPIX_str = str(table['HEALPIX'][indices[0]])
            n_str = HEALPIX_str[:3]
            n_values.append(int(n_str))
        else:
            # Handle the case where the search value was not found
            SURVEY.append(None)
            PROGRAM.append(None)
            HEALPIX.append(None)
            n_values.append(None)
            Z.append(None)   
            RA.append(None)
            DEC.append(None)
            Source_ID.append(None)
            
    
    z = np.array(Z)
    RA = np.array(RA)
    DEC = np.array(DEC)
    id_spec = np.array(Source_ID)
    wave_spec, flux_spec, sigma_spec = [], [], []
    
    for index, (survey, program, healpix, search_value) in enumerate(zip(SURVEY, PROGRAM, HEALPIX, search_values)):
        
        folder_name = 'DESI_Downloads'
        file_name = f"coadd-{survey}-{program}-{healpix}.fits"
        coadd_obj = desispec.io.read_spectra(f'{folder_name}/{file_name}')
        coadd_tgts = coadd_obj.target_ids().data
        # Selecting the particular spectra of the targetid
        row = (coadd_tgts == search_value)
        coadd_spec = coadd_obj[row] 

        # Inverse Vartiance weighted average for overlap
        no_overlap = no_overlap_f(coadd_spec.wave['b'],coadd_spec.flux['b'][0],coadd_spec.wave['r'],coadd_spec.flux['r'][0],coadd_spec.wave['z'],coadd_spec.flux['z'][0])
        overlap_br= overlap_av(coadd_spec.wave['b'],coadd_spec.wave['r'],coadd_spec.flux['b'][0],coadd_spec.flux['r'][0],coadd_spec.ivar['b'][0],coadd_spec.ivar['r'][0])
        overlap_rz= overlap_av(coadd_spec.wave['r'],coadd_spec.wave['z'],coadd_spec.flux['r'][0],coadd_spec.flux['z'][0],coadd_spec.ivar['r'][0],coadd_spec.ivar['z'][0])
        
        
        # Concaternating Spectra
        flux_spectra = np.concatenate((no_overlap[1],overlap_br[0],no_overlap[3],overlap_rz[0],no_overlap[5]))
        wave_spectra = np.concatenate((no_overlap[0],overlap_br[1],no_overlap[2],overlap_rz[1],no_overlap[4]))

        # Using Desispec to get wavelengths, flux and sigma
        wave = wave_spectra
        wave = wave.flatten()
        #flux = coadd_spec.flux['r'][0]
        #flux = convolve(flux_spectra, Gaussian1DKernel(5))
        #pick if i want to convolve or not
        flux = flux_spectra
        flux = flux.flatten()
        sigma = (np.sqrt(1/coadd_spec.ivar['r']))
        sigma = sigma.flatten()
        if index % 2 == 0 and len(wave) > 0:
                wave = wave[:-1]
                flux = flux[:-1]
                sigma = sigma[:-1]
        sigma_spec.append(sigma)
        wave_spec.append(wave)
        flux_spec.append(flux)
        
    
    wave_spec = np.array(wave_spec,dtype=object)
    flux_spec = np.array(flux_spec,dtype=object)
    sigma_spec = np.array(sigma_spec,dtype=object)
    # alternatively tried wave_spec = wave_spec.tolist()

    
    
    return wave_spec, flux_spec, sigma_spec, z, RA, DEC, id_spec


def get_stack(spec, zbins=None):# can add redshift ranges i.e zbins = [[0.0,0.1],[0.1,0.2]]
    wave_spec, flux_spec, sigma_spec, z, RA, DEC, id_spec= spec
    stack = sc.stack_spectra(wave_spec,flux_spec,sigma_spec,
                               z, RA, DEC, zbins = zbins)
    return stack

# %% [markdown]
# ## Spectra Selection and Application of Stacking

# %%
# Bin the data by flux (proxy for SFR?) or mass 


var_bin = 'Mass_median'
crossmatch = crossmatch[np.array(np.argsort(crossmatch[f'{var_bin}']))]


Overall_class = 'SFG'
total_objects = 6294
bins = 6
table_size = total_objects // bins

# Create a list to store the tables
tables = []

# Loop to create each table
for i in range(bins):
    start_index = i * table_size
    end_index = (i + 1) * table_size if i < bins - 1 else total_objects
    
    # Create a table for the current segment
    current_table = crossmatch[crossmatch['Overall_class'] == f'{Overall_class}'][start_index:end_index]
    
    # Append the table to the list
    tables.append(current_table)

# There are tables 0 to 5
#print(tables[1])

# Create a list to store the stack outputs
stack_outputs = []

# Perform operations for each table
for i, table in enumerate(tables):
    search_column_name = 'TARGETID'
    search_values = np.array(table[f'{search_column_name}'])
    
    # Extract relevant spectra
    spec = get_spectra(table, search_column_name, search_values)
    
    # Stack spectra
    stack = get_stack(spec)

    # Append the stack output to the list
    stack_outputs.append(stack)
# Out:
# Number of spectra = 1049
# INFO:spectra.py:372:read_spectra: iotime 3.191 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:19:10.904676
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_69285/3482820004.py:79: RuntimeWarning: divide by zero encountered in divide
#   sigma = (np.sqrt(1/coadd_spec.ivar['r']))
# INFO:spectra.py:372:read_spectra: iotime 0.255 sec to read coadd-sv1-other-10157.fits at 2024-01-08T00:19:15.310878
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_69285/3924121423.py:6: RuntimeWarning: divide by zero encountered in divide
#   weight1 = 1 / ivar1
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_69285/3924121423.py:7: RuntimeWarning: divide by zero encountered in divide
#   weight2 = 1 / ivar2
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_69285/3924121423.py:9: RuntimeWarning: invalid value encountered in divide
#   weighted_flux1 = flux1 * (weight1 / total_weight)
# /var/folders/wq/x4d7t0dd705bwvpnmkf6s7s40000gn/T/ipykernel_69285/3924121423.py:10: RuntimeWarning: invalid value encountered in divide
#   weighted_flux2 = flux2 * (weight2 / total_weight)
# INFO:spectra.py:372:read_spectra: iotime 3.034 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:19:19.069704
# INFO:spectra.py:372:read_spectra: iotime 3.695 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:19:25.294370
# INFO:spectra.py:372:read_spectra: iotime 1.249 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:19:30.139918
# INFO:spectra.py:372:read_spectra: iotime 2.026 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:19:32.903466
# INFO:spectra.py:372:read_spectra: iotime 1.091 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:19:36.851142
# INFO:spectra.py:372:read_spectra: iotime 2.208 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:19:40.664010
# INFO:spectra.py:372:read_spectra: iotime 2.307 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:19:45.137174
# INFO:spectra.py:372:read_spectra: iotime 0.951 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:19:48.405551
# INFO:spectra.py:372:read_spectra: iotime 1.924 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:19:51.443761
# INFO:spectra.py:372:read_spectra: iotime 2.288 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:19:55.996808
# INFO:spectra.py:372:read_spectra: iotime 1.393 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:19:58.232108
# INFO:spectra.py:372:read_spectra: iotime 3.170 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:20:01.919028
# INFO:spectra.py:372:read_spectra: iotime 3.238 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:20:07.961475
# INFO:spectra.py:372:read_spectra: iotime 3.285 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:20:13.931528
# INFO:spectra.py:372:read_spectra: iotime 3.825 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:20:22.063886
# INFO:spectra.py:372:read_spectra: iotime 3.821 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:20:29.368279
# INFO:spectra.py:372:read_spectra: iotime 3.426 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:20:37.437364
# INFO:spectra.py:372:read_spectra: iotime 3.521 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:20:43.757914
# INFO:spectra.py:372:read_spectra: iotime 0.650 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:20:48.313423
# INFO:spectra.py:372:read_spectra: iotime 3.609 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:20:53.148964
# INFO:spectra.py:372:read_spectra: iotime 3.842 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T00:21:01.798809
# INFO:spectra.py:372:read_spectra: iotime 2.523 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:21:08.718119
# INFO:spectra.py:372:read_spectra: iotime 3.817 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:21:15.417756
# INFO:spectra.py:372:read_spectra: iotime 0.784 sec to read coadd-sv3-bright-10157.fits at 2024-01-08T00:21:17.964760
# INFO:spectra.py:372:read_spectra: iotime 2.639 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:21:21.146655
# INFO:spectra.py:372:read_spectra: iotime 2.048 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:21:25.826954
# INFO:spectra.py:372:read_spectra: iotime 2.726 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:21:30.863316
# INFO:spectra.py:372:read_spectra: iotime 2.350 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:21:37.976377
# INFO:spectra.py:372:read_spectra: iotime 2.743 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:21:42.293495
# INFO:spectra.py:372:read_spectra: iotime 0.626 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:21:44.744933
# INFO:spectra.py:372:read_spectra: iotime 2.947 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:21:48.377491
# INFO:spectra.py:372:read_spectra: iotime 0.875 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:21:52.436547
# INFO:spectra.py:372:read_spectra: iotime 0.684 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:21:54.770554
# INFO:spectra.py:372:read_spectra: iotime 3.778 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:21:58.938728
# INFO:spectra.py:372:read_spectra: iotime 1.003 sec to read coadd-sv3-backup-10153.fits at 2024-01-08T00:22:03.416263
# INFO:spectra.py:372:read_spectra: iotime 2.267 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:22:06.126865
# INFO:spectra.py:372:read_spectra: iotime 3.791 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:22:12.176795
# INFO:spectra.py:372:read_spectra: iotime 3.303 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:22:18.211600
# INFO:spectra.py:372:read_spectra: iotime 2.995 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:22:24.652983
# INFO:spectra.py:372:read_spectra: iotime 2.923 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:22:31.192499
# INFO:spectra.py:372:read_spectra: iotime 3.190 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:22:36.596241
# INFO:spectra.py:372:read_spectra: iotime 1.042 sec to read coadd-sv3-dark-10157.fits at 2024-01-08T00:22:40.853314
# INFO:spectra.py:372:read_spectra: iotime 2.684 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:22:44.126934
# INFO:spectra.py:372:read_spectra: iotime 2.875 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:22:49.461162
# INFO:spectra.py:372:read_spectra: iotime 2.909 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:22:54.941277
# INFO:spectra.py:372:read_spectra: iotime 1.188 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:23:00.241660
# INFO:spectra.py:372:read_spectra: iotime 0.963 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:23:02.510450
# INFO:spectra.py:372:read_spectra: iotime 2.192 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:23:05.791617
# INFO:spectra.py:372:read_spectra: iotime 0.914 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:23:07.568723
# INFO:spectra.py:372:read_spectra: iotime 0.964 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:23:08.789378
# INFO:spectra.py:372:read_spectra: iotime 1.313 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:23:10.768727
# INFO:spectra.py:372:read_spectra: iotime 3.476 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:23:14.803285
# INFO:spectra.py:372:read_spectra: iotime 2.522 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:23:18.737836
# INFO:spectra.py:372:read_spectra: iotime 0.349 sec to read coadd-sv3-bright-10151.fits at 2024-01-08T00:23:22.198357
# INFO:spectra.py:372:read_spectra: iotime 2.556 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:23:25.046816
# INFO:spectra.py:372:read_spectra: iotime 3.556 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:23:29.830662
# INFO:spectra.py:372:read_spectra: iotime 1.645 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:23:33.443550
# INFO:spectra.py:372:read_spectra: iotime 2.500 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:23:38.062980
# INFO:spectra.py:372:read_spectra: iotime 3.427 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:23:42.356503
# INFO:spectra.py:372:read_spectra: iotime 3.542 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:23:49.165369
# INFO:spectra.py:372:read_spectra: iotime 3.716 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:23:55.780728
# INFO:spectra.py:372:read_spectra: iotime 2.613 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T00:24:02.243779
# INFO:spectra.py:372:read_spectra: iotime 1.884 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:24:06.662017
# INFO:spectra.py:372:read_spectra: iotime 4.178 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:24:12.687379
# INFO:spectra.py:372:read_spectra: iotime 0.676 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:24:16.859818
# INFO:spectra.py:372:read_spectra: iotime 0.235 sec to read coadd-sv1-other-10157.fits at 2024-01-08T00:24:17.431077
# INFO:spectra.py:372:read_spectra: iotime 2.287 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:24:19.809303
# INFO:spectra.py:372:read_spectra: iotime 0.780 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:24:22.923223
# INFO:spectra.py:372:read_spectra: iotime 0.603 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:24:23.812896
# INFO:spectra.py:372:read_spectra: iotime 3.092 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:24:27.103440
# INFO:spectra.py:372:read_spectra: iotime 1.156 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:24:29.678338
# INFO:spectra.py:372:read_spectra: iotime 3.737 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:24:34.407641
# INFO:spectra.py:372:read_spectra: iotime 3.349 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:24:40.747756
# INFO:spectra.py:372:read_spectra: iotime 1.412 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:24:45.042570
# INFO:spectra.py:372:read_spectra: iotime 0.806 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:24:47.671092
# INFO:spectra.py:372:read_spectra: iotime 0.866 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:24:48.897163
# INFO:spectra.py:372:read_spectra: iotime 2.319 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:24:52.396276
# INFO:spectra.py:372:read_spectra: iotime 3.123 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:24:59.303196
# INFO:spectra.py:372:read_spectra: iotime 0.596 sec to read coadd-sv3-backup-10154.fits at 2024-01-08T00:25:03.664333
# INFO:spectra.py:372:read_spectra: iotime 3.009 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:25:07.989814
# INFO:spectra.py:372:read_spectra: iotime 3.310 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:25:14.355396
# INFO:spectra.py:372:read_spectra: iotime 1.089 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:25:18.736322
# INFO:spectra.py:372:read_spectra: iotime 3.087 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:25:23.387428
# INFO:spectra.py:372:read_spectra: iotime 0.753 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:25:27.552623
# INFO:spectra.py:372:read_spectra: iotime 3.150 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:25:31.768609
# INFO:spectra.py:372:read_spectra: iotime 3.271 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:25:38.662336
# INFO:spectra.py:372:read_spectra: iotime 0.917 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:25:43.639470
# INFO:spectra.py:372:read_spectra: iotime 0.871 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:25:45.094121
# INFO:spectra.py:372:read_spectra: iotime 0.810 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:25:46.133766
# INFO:spectra.py:372:read_spectra: iotime 0.707 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:25:47.041668
# INFO:spectra.py:372:read_spectra: iotime 2.324 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:25:49.692963
# INFO:spectra.py:372:read_spectra: iotime 2.943 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:25:55.465565
# INFO:spectra.py:372:read_spectra: iotime 0.677 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:25:58.802989
# INFO:spectra.py:372:read_spectra: iotime 3.358 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:26:02.477595
# INFO:spectra.py:372:read_spectra: iotime 1.270 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:26:06.967853
# INFO:spectra.py:372:read_spectra: iotime 3.745 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:26:12.271796
# INFO:spectra.py:372:read_spectra: iotime 1.345 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:26:15.333685
# INFO:spectra.py:372:read_spectra: iotime 3.485 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:26:19.888271
# INFO:spectra.py:372:read_spectra: iotime 0.669 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:26:23.635476
# INFO:spectra.py:372:read_spectra: iotime 0.516 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:26:25.309365
# INFO:spectra.py:372:read_spectra: iotime 3.698 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:26:29.158635
# INFO:spectra.py:372:read_spectra: iotime 3.246 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:26:34.691431
# INFO:spectra.py:372:read_spectra: iotime 3.303 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:26:42.057840
# INFO:spectra.py:372:read_spectra: iotime 2.715 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:26:47.367608
# INFO:spectra.py:372:read_spectra: iotime 3.591 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:26:54.714669
# INFO:spectra.py:372:read_spectra: iotime 4.203 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:27:03.058597
# INFO:spectra.py:372:read_spectra: iotime 0.875 sec to read coadd-sv3-backup-11520.fits at 2024-01-08T00:27:08.412789
# INFO:spectra.py:372:read_spectra: iotime 1.801 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:27:11.431701
# INFO:spectra.py:372:read_spectra: iotime 3.578 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:27:17.420514
# INFO:spectra.py:372:read_spectra: iotime 0.981 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:27:21.904103
# INFO:spectra.py:372:read_spectra: iotime 4.960 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T00:27:28.718072
# INFO:spectra.py:372:read_spectra: iotime 0.335 sec to read coadd-sv1-other-10158.fits at 2024-01-08T00:27:31.089415
# INFO:spectra.py:372:read_spectra: iotime 1.317 sec to read coadd-sv3-bright-10157.fits at 2024-01-08T00:27:33.148220
# INFO:spectra.py:372:read_spectra: iotime 3.702 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:27:37.664487
# INFO:spectra.py:372:read_spectra: iotime 3.498 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:27:45.244225
# INFO:spectra.py:372:read_spectra: iotime 3.621 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:27:52.988242
# INFO:spectra.py:372:read_spectra: iotime 3.410 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:28:00.763197
# INFO:spectra.py:372:read_spectra: iotime 2.828 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:28:06.784989
# INFO:spectra.py:372:read_spectra: iotime 0.157 sec to read coadd-sv1-other-11524.fits at 2024-01-08T00:28:09.586577
# INFO:spectra.py:372:read_spectra: iotime 0.671 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:28:10.851753
# INFO:spectra.py:372:read_spectra: iotime 4.129 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:28:15.136739
# INFO:spectra.py:372:read_spectra: iotime 2.803 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T00:28:21.436243
# INFO:spectra.py:372:read_spectra: iotime 1.269 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:28:26.909982
# INFO:spectra.py:372:read_spectra: iotime 1.609 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:28:29.247963
# INFO:spectra.py:372:read_spectra: iotime 1.026 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:28:30.772267
# INFO:spectra.py:372:read_spectra: iotime 1.955 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:28:34.242300
# INFO:spectra.py:372:read_spectra: iotime 2.107 sec to read coadd-sv3-dark-10152.fits at 2024-01-08T00:28:38.441511
# INFO:spectra.py:372:read_spectra: iotime 2.972 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:28:44.195524
# INFO:spectra.py:372:read_spectra: iotime 1.239 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:28:49.662690
# INFO:spectra.py:372:read_spectra: iotime 1.746 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T00:28:52.285717
# INFO:spectra.py:372:read_spectra: iotime 3.112 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:28:57.306264
# INFO:spectra.py:372:read_spectra: iotime 3.559 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:29:04.449504
# INFO:spectra.py:372:read_spectra: iotime 1.113 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:29:09.352124
# INFO:spectra.py:372:read_spectra: iotime 0.112 sec to read coadd-sv1-other-10146.fits at 2024-01-08T00:29:10.210163
# INFO:spectra.py:372:read_spectra: iotime 2.505 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:29:12.761452
# INFO:spectra.py:372:read_spectra: iotime 2.906 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:29:20.033242
# INFO:spectra.py:372:read_spectra: iotime 2.695 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:29:23.863883
# INFO:spectra.py:372:read_spectra: iotime 1.041 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:29:28.433577
# INFO:spectra.py:372:read_spectra: iotime 1.374 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:29:31.962720
# INFO:spectra.py:372:read_spectra: iotime 1.244 sec to read coadd-sv3-bright-10157.fits at 2024-01-08T00:29:33.893424
# INFO:spectra.py:372:read_spectra: iotime 0.676 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:29:34.902610
# INFO:spectra.py:372:read_spectra: iotime 3.316 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:29:38.404223
# INFO:spectra.py:372:read_spectra: iotime 3.174 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:29:44.845121
# INFO:spectra.py:372:read_spectra: iotime 4.113 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:29:52.826002
# INFO:spectra.py:372:read_spectra: iotime 0.973 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:29:59.133824
# INFO:spectra.py:372:read_spectra: iotime 0.837 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:30:01.730254
# INFO:spectra.py:372:read_spectra: iotime 3.428 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:30:05.501050
# INFO:spectra.py:372:read_spectra: iotime 4.301 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T00:30:12.329988
# INFO:spectra.py:372:read_spectra: iotime 3.402 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:30:19.166291
# INFO:spectra.py:372:read_spectra: iotime 0.862 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:30:24.353088
# INFO:spectra.py:372:read_spectra: iotime 1.370 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:30:26.100703
# INFO:spectra.py:372:read_spectra: iotime 0.973 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:30:27.392232
# INFO:spectra.py:372:read_spectra: iotime 0.695 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:30:29.336113
# INFO:spectra.py:372:read_spectra: iotime 0.449 sec to read coadd-sv1-other-10158.fits at 2024-01-08T00:30:30.373428
# INFO:spectra.py:372:read_spectra: iotime 0.173 sec to read coadd-sv1-other-11524.fits at 2024-01-08T00:30:30.763756
# INFO:spectra.py:372:read_spectra: iotime 2.865 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:30:33.710292
# INFO:spectra.py:372:read_spectra: iotime 4.833 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T00:30:41.846804
# INFO:spectra.py:372:read_spectra: iotime 3.914 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T00:30:49.842946
# INFO:spectra.py:372:read_spectra: iotime 1.077 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:30:54.684417
# INFO:spectra.py:372:read_spectra: iotime 2.740 sec to read coadd-sv3-dark-11520.fits at 2024-01-08T00:30:59.403563
# INFO:spectra.py:372:read_spectra: iotime 0.622 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:31:02.500997
# INFO:spectra.py:372:read_spectra: iotime 0.384 sec to read coadd-sv1-other-10158.fits at 2024-01-08T00:31:03.755512
# INFO:spectra.py:372:read_spectra: iotime 2.605 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:31:06.455994
# INFO:spectra.py:372:read_spectra: iotime 1.080 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:31:10.418056
# INFO:spectra.py:372:read_spectra: iotime 0.735 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:31:12.070665
# INFO:spectra.py:372:read_spectra: iotime 0.892 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:31:13.368150
# INFO:spectra.py:372:read_spectra: iotime 0.882 sec to read coadd-sv1-other-10147.fits at 2024-01-08T00:31:15.218885
# INFO:spectra.py:372:read_spectra: iotime 3.450 sec to read coadd-sv3-dark-11520.fits at 2024-01-08T00:31:18.988015
# INFO:spectra.py:372:read_spectra: iotime 3.439 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:31:25.277274
# INFO:spectra.py:372:read_spectra: iotime 0.918 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:31:29.665439
# INFO:spectra.py:372:read_spectra: iotime 0.731 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:31:30.866858
# INFO:spectra.py:372:read_spectra: iotime 0.887 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:31:31.955578
# INFO:spectra.py:372:read_spectra: iotime 3.686 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:31:35.845351
# INFO:spectra.py:372:read_spectra: iotime 1.647 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:31:41.345889
# INFO:spectra.py:372:read_spectra: iotime 0.780 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:31:44.076118
# INFO:spectra.py:372:read_spectra: iotime 0.146 sec to read coadd-sv1-other-11524.fits at 2024-01-08T00:31:44.495266
# INFO:spectra.py:372:read_spectra: iotime 0.891 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:31:45.474071
# INFO:spectra.py:372:read_spectra: iotime 3.644 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:31:49.341876
# INFO:spectra.py:372:read_spectra: iotime 1.582 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:31:54.169919
# INFO:spectra.py:372:read_spectra: iotime 1.124 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:31:55.893185
# INFO:spectra.py:372:read_spectra: iotime 2.985 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:32:00.280856
# INFO:spectra.py:372:read_spectra: iotime 0.855 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:32:03.439277
# INFO:spectra.py:372:read_spectra: iotime 2.791 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:32:06.547669
# INFO:spectra.py:372:read_spectra: iotime 3.555 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:32:12.022217
# INFO:spectra.py:372:read_spectra: iotime 0.161 sec to read coadd-sv3-bright-11522.fits at 2024-01-08T00:32:16.341435
# INFO:spectra.py:372:read_spectra: iotime 3.519 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:32:20.271033
# INFO:spectra.py:372:read_spectra: iotime 1.543 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:32:22.803045
# INFO:spectra.py:372:read_spectra: iotime 1.484 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:32:25.966890
# INFO:spectra.py:372:read_spectra: iotime 2.611 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:32:29.838171
# INFO:spectra.py:372:read_spectra: iotime 1.280 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:32:33.731471
# INFO:spectra.py:372:read_spectra: iotime 3.575 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:32:39.042804
# INFO:spectra.py:372:read_spectra: iotime 2.541 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:32:45.352523
# INFO:spectra.py:372:read_spectra: iotime 0.341 sec to read coadd-sv1-other-10158.fits at 2024-01-08T00:32:49.705230
# INFO:spectra.py:372:read_spectra: iotime 3.893 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:32:54.020376
# INFO:spectra.py:372:read_spectra: iotime 4.882 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:33:02.206873
# INFO:spectra.py:372:read_spectra: iotime 4.479 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:33:10.930419
# INFO:spectra.py:372:read_spectra: iotime 0.945 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:33:15.714730
# INFO:spectra.py:372:read_spectra: iotime 0.869 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:33:17.076990
# INFO:spectra.py:372:read_spectra: iotime 3.034 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:33:20.354636
# INFO:spectra.py:372:read_spectra: iotime 2.704 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:33:25.105695
# INFO:spectra.py:372:read_spectra: iotime 2.347 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:33:31.643721
# INFO:spectra.py:372:read_spectra: iotime 3.938 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:33:36.428596
# INFO:spectra.py:372:read_spectra: iotime 1.195 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:33:39.934999
# INFO:spectra.py:372:read_spectra: iotime 3.532 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:33:44.980986
# INFO:spectra.py:372:read_spectra: iotime 3.248 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:33:50.880127
# INFO:spectra.py:372:read_spectra: iotime 4.060 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:33:58.662033
# INFO:spectra.py:372:read_spectra: iotime 4.809 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:34:06.537311
# INFO:spectra.py:372:read_spectra: iotime 3.394 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:34:13.014942
# INFO:spectra.py:372:read_spectra: iotime 2.106 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:34:19.460390
# INFO:spectra.py:372:read_spectra: iotime 0.954 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:34:21.651623
# INFO:spectra.py:372:read_spectra: iotime 2.885 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:34:26.371649
# INFO:spectra.py:372:read_spectra: iotime 2.503 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:34:33.068603
# INFO:spectra.py:372:read_spectra: iotime 0.528 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:34:37.826986
# INFO:spectra.py:372:read_spectra: iotime 2.258 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:34:40.389360
# INFO:spectra.py:372:read_spectra: iotime 2.870 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:34:46.783167
# INFO:spectra.py:372:read_spectra: iotime 3.349 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:34:51.736972
# INFO:spectra.py:372:read_spectra: iotime 2.639 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:34:58.649431
# INFO:spectra.py:372:read_spectra: iotime 2.909 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:35:04.326337
# INFO:spectra.py:372:read_spectra: iotime 3.181 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:35:11.148383
# INFO:spectra.py:372:read_spectra: iotime 3.463 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:35:17.829135
# INFO:spectra.py:372:read_spectra: iotime 2.956 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:35:22.234744
# INFO:spectra.py:372:read_spectra: iotime 3.675 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:35:29.530694
# INFO:spectra.py:372:read_spectra: iotime 3.663 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:35:36.654477
# INFO:spectra.py:372:read_spectra: iotime 0.903 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:35:40.257163
# INFO:spectra.py:372:read_spectra: iotime 3.393 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:35:44.496161
# INFO:spectra.py:372:read_spectra: iotime 1.919 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:35:49.931925
# INFO:spectra.py:372:read_spectra: iotime 3.141 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:35:55.064192
# INFO:spectra.py:372:read_spectra: iotime 3.584 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:36:02.112178
# INFO:spectra.py:372:read_spectra: iotime 2.238 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:36:09.822579
# INFO:spectra.py:372:read_spectra: iotime 3.320 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:36:15.158274
# INFO:spectra.py:372:read_spectra: iotime 4.058 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:36:22.280803
# INFO:spectra.py:372:read_spectra: iotime 1.534 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T00:36:27.809566
# INFO:spectra.py:372:read_spectra: iotime 2.868 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:36:32.351265
# INFO:spectra.py:372:read_spectra: iotime 0.879 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:36:36.203696
# INFO:spectra.py:372:read_spectra: iotime 2.332 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:36:38.894698
# INFO:spectra.py:372:read_spectra: iotime 3.292 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:36:46.226557
# INFO:spectra.py:372:read_spectra: iotime 2.945 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:36:50.502295
# INFO:spectra.py:372:read_spectra: iotime 3.201 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:36:57.297602
# INFO:spectra.py:372:read_spectra: iotime 2.945 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:37:02.639550
# INFO:spectra.py:372:read_spectra: iotime 3.029 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:37:09.295669
# INFO:spectra.py:372:read_spectra: iotime 3.573 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:37:15.625968
# INFO:spectra.py:372:read_spectra: iotime 2.943 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:37:22.565397
# INFO:spectra.py:372:read_spectra: iotime 3.817 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:37:30.256188
# INFO:spectra.py:372:read_spectra: iotime 2.384 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:37:36.206207
# INFO:spectra.py:372:read_spectra: iotime 4.427 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:37:42.379362
# INFO:spectra.py:372:read_spectra: iotime 3.510 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:37:49.910984
# INFO:spectra.py:372:read_spectra: iotime 4.481 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:37:58.544557
# INFO:spectra.py:372:read_spectra: iotime 4.517 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:38:06.676455
# INFO:spectra.py:372:read_spectra: iotime 4.511 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:38:17.207640
# INFO:spectra.py:372:read_spectra: iotime 3.652 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:38:24.705816
# INFO:spectra.py:372:read_spectra: iotime 3.377 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:38:31.267874
# INFO:spectra.py:372:read_spectra: iotime 2.660 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:38:36.616262
# INFO:spectra.py:372:read_spectra: iotime 3.220 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:38:42.505230
# INFO:spectra.py:372:read_spectra: iotime 3.923 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:38:49.872926
# INFO:spectra.py:372:read_spectra: iotime 3.551 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:38:57.857054
# INFO:spectra.py:372:read_spectra: iotime 3.848 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:39:05.248382
# INFO:spectra.py:372:read_spectra: iotime 3.103 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:39:12.108886
# INFO:spectra.py:372:read_spectra: iotime 3.186 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:39:19.607851
# INFO:spectra.py:372:read_spectra: iotime 2.761 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:39:24.795979
# INFO:spectra.py:372:read_spectra: iotime 0.496 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:39:29.996562
# INFO:spectra.py:372:read_spectra: iotime 1.866 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:39:32.278573
# INFO:spectra.py:372:read_spectra: iotime 3.190 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:39:38.071827
# INFO:spectra.py:372:read_spectra: iotime 3.165 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:39:44.741232
# INFO:spectra.py:372:read_spectra: iotime 3.636 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:39:51.708960
# INFO:spectra.py:372:read_spectra: iotime 3.814 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:39:59.702625
# INFO:spectra.py:372:read_spectra: iotime 4.215 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:40:06.632107
# INFO:spectra.py:372:read_spectra: iotime 4.259 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:40:14.495714
# INFO:spectra.py:372:read_spectra: iotime 1.713 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:40:21.019807
# INFO:spectra.py:372:read_spectra: iotime 4.195 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:40:27.879344
# INFO:spectra.py:372:read_spectra: iotime 3.777 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:40:35.192279
# INFO:spectra.py:372:read_spectra: iotime 3.166 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:40:42.084929
# INFO:spectra.py:372:read_spectra: iotime 4.176 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:40:51.207052
# INFO:spectra.py:372:read_spectra: iotime 3.285 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:40:58.258600
# INFO:spectra.py:372:read_spectra: iotime 3.926 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:41:05.915048
# INFO:spectra.py:372:read_spectra: iotime 3.597 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:41:13.542191
# INFO:spectra.py:372:read_spectra: iotime 3.153 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:41:20.562148
# INFO:spectra.py:372:read_spectra: iotime 3.378 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:41:26.119712
# INFO:spectra.py:372:read_spectra: iotime 2.077 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:41:30.894330
# INFO:spectra.py:372:read_spectra: iotime 0.487 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:41:34.072398
# INFO:spectra.py:372:read_spectra: iotime 3.757 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:41:38.183133
# INFO:spectra.py:372:read_spectra: iotime 2.510 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:41:44.561132
# INFO:spectra.py:372:read_spectra: iotime 3.411 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:41:49.094828
# INFO:spectra.py:372:read_spectra: iotime 0.853 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:41:53.553990
# INFO:spectra.py:372:read_spectra: iotime 2.671 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:41:58.105335
# INFO:spectra.py:372:read_spectra: iotime 3.827 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:42:05.118289
# INFO:spectra.py:372:read_spectra: iotime 2.851 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:42:12.277532
# INFO:spectra.py:372:read_spectra: iotime 2.382 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:42:17.752957
# INFO:spectra.py:372:read_spectra: iotime 1.627 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:42:24.860509
# INFO:spectra.py:372:read_spectra: iotime 1.021 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:42:27.834244
# INFO:spectra.py:372:read_spectra: iotime 2.722 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:42:31.868487
# INFO:spectra.py:372:read_spectra: iotime 4.239 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:42:39.232445
# INFO:spectra.py:372:read_spectra: iotime 3.465 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:42:44.642449
# INFO:spectra.py:372:read_spectra: iotime 3.490 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:42:51.946433
# INFO:spectra.py:372:read_spectra: iotime 4.355 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:43:01.179738
# INFO:spectra.py:372:read_spectra: iotime 3.172 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:43:08.417983
# INFO:spectra.py:372:read_spectra: iotime 4.024 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:43:17.057179
# INFO:spectra.py:372:read_spectra: iotime 2.425 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:43:22.735579
# INFO:spectra.py:372:read_spectra: iotime 3.147 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:43:27.915281
# INFO:spectra.py:372:read_spectra: iotime 3.814 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T00:43:35.604883
# INFO:spectra.py:372:read_spectra: iotime 2.779 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:43:41.450123
# INFO:spectra.py:372:read_spectra: iotime 1.036 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:43:45.451494
# INFO:spectra.py:372:read_spectra: iotime 1.277 sec to read coadd-sv3-bright-10151.fits at 2024-01-08T00:43:48.106822
# INFO:spectra.py:372:read_spectra: iotime 2.548 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:43:51.143022
# INFO:spectra.py:372:read_spectra: iotime 3.686 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:43:57.681949
# INFO:spectra.py:372:read_spectra: iotime 3.448 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:44:04.524481
# INFO:spectra.py:372:read_spectra: iotime 2.538 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:44:10.533642
# INFO:spectra.py:372:read_spectra: iotime 0.612 sec to read coadd-sv1-other-10152.fits at 2024-01-08T00:44:14.194005
# INFO:spectra.py:372:read_spectra: iotime 2.458 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:44:16.892630
# INFO:spectra.py:372:read_spectra: iotime 3.814 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:44:21.412448
# INFO:spectra.py:372:read_spectra: iotime 1.613 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:44:27.504738
# INFO:spectra.py:372:read_spectra: iotime 1.280 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:44:29.343573
# INFO:spectra.py:372:read_spectra: iotime 2.911 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:44:33.693047
# INFO:spectra.py:372:read_spectra: iotime 3.152 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:44:39.510055
# INFO:spectra.py:372:read_spectra: iotime 0.634 sec to read coadd-sv3-backup-10153.fits at 2024-01-08T00:44:43.747455
# INFO:spectra.py:372:read_spectra: iotime 4.146 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:44:48.242116
# INFO:spectra.py:372:read_spectra: iotime 3.574 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:44:53.450424
# INFO:spectra.py:372:read_spectra: iotime 2.113 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:45:00.117268
# INFO:spectra.py:372:read_spectra: iotime 2.834 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:45:05.581065
# INFO:spectra.py:372:read_spectra: iotime 3.254 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:45:12.732955
# INFO:spectra.py:372:read_spectra: iotime 1.360 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:45:17.219299
# INFO:spectra.py:372:read_spectra: iotime 3.611 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:45:21.681583
# INFO:spectra.py:372:read_spectra: iotime 2.812 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:45:28.280232
# INFO:spectra.py:372:read_spectra: iotime 4.216 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:45:36.899137
# INFO:spectra.py:372:read_spectra: iotime 2.880 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:45:42.519427
# INFO:spectra.py:372:read_spectra: iotime 3.020 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:45:49.705978
# INFO:spectra.py:372:read_spectra: iotime 4.614 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:45:55.587562
# INFO:spectra.py:372:read_spectra: iotime 3.318 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:46:02.760807
# INFO:spectra.py:372:read_spectra: iotime 3.040 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:46:09.994875
# INFO:spectra.py:372:read_spectra: iotime 0.825 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:46:14.884580
# INFO:spectra.py:372:read_spectra: iotime 4.067 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:46:19.986071
# INFO:spectra.py:372:read_spectra: iotime 4.329 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:46:28.221856
# INFO:spectra.py:372:read_spectra: iotime 2.641 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:46:34.370800
# INFO:spectra.py:372:read_spectra: iotime 0.745 sec to read coadd-sv1-other-10155.fits at 2024-01-08T00:46:38.180977
# INFO:spectra.py:372:read_spectra: iotime 1.865 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:46:40.497104
# INFO:spectra.py:372:read_spectra: iotime 0.342 sec to read coadd-sv1-other-10158.fits at 2024-01-08T00:46:43.123000
# INFO:spectra.py:372:read_spectra: iotime 2.307 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:46:45.681602
# INFO:spectra.py:372:read_spectra: iotime 1.107 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:46:49.595913
# INFO:spectra.py:372:read_spectra: iotime 2.913 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:46:54.200623
# INFO:spectra.py:372:read_spectra: iotime 4.048 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:46:59.744793
# INFO:spectra.py:372:read_spectra: iotime 3.599 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:47:08.428649
# INFO:spectra.py:372:read_spectra: iotime 3.886 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:47:16.608017
# INFO:spectra.py:372:read_spectra: iotime 0.996 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:47:20.659510
# INFO:spectra.py:372:read_spectra: iotime 2.911 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:47:25.247232
# INFO:spectra.py:372:read_spectra: iotime 3.606 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:47:31.515722
# INFO:spectra.py:372:read_spectra: iotime 0.778 sec to read coadd-sv1-other-10154.fits at 2024-01-08T00:47:36.593857
# INFO:spectra.py:372:read_spectra: iotime 0.907 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:47:38.085205
# INFO:spectra.py:372:read_spectra: iotime 3.841 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:47:42.166780
# INFO:spectra.py:372:read_spectra: iotime 2.296 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:47:47.544238
# INFO:spectra.py:372:read_spectra: iotime 4.085 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:47:56.590563
# INFO:spectra.py:372:read_spectra: iotime 3.542 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:48:03.728368
# INFO:spectra.py:372:read_spectra: iotime 0.835 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:48:06.694195
# INFO:spectra.py:372:read_spectra: iotime 3.424 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:48:11.313616
# INFO:spectra.py:372:read_spectra: iotime 3.840 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:48:17.716522
# INFO:spectra.py:372:read_spectra: iotime 3.421 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:48:24.749753
# INFO:spectra.py:372:read_spectra: iotime 3.452 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:48:30.243432
# INFO:spectra.py:372:read_spectra: iotime 4.063 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:48:38.760000
# INFO:spectra.py:372:read_spectra: iotime 3.068 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:48:45.246618
# INFO:spectra.py:372:read_spectra: iotime 3.037 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:48:52.224046
# INFO:spectra.py:372:read_spectra: iotime 3.170 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:48:59.263044
# INFO:spectra.py:372:read_spectra: iotime 0.939 sec to read coadd-sv3-bright-10151.fits at 2024-01-08T00:49:01.378408
# INFO:spectra.py:372:read_spectra: iotime 3.818 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:49:05.393385
# INFO:spectra.py:372:read_spectra: iotime 2.675 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:49:11.598834
# INFO:spectra.py:372:read_spectra: iotime 3.805 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:49:19.135176
# INFO:spectra.py:372:read_spectra: iotime 3.202 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:49:25.862528
# INFO:spectra.py:372:read_spectra: iotime 3.355 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:49:33.217566
# INFO:spectra.py:372:read_spectra: iotime 2.394 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T00:49:39.405335
# INFO:spectra.py:372:read_spectra: iotime 2.083 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:49:43.676063
# INFO:spectra.py:372:read_spectra: iotime 0.687 sec to read coadd-sv1-other-11520.fits at 2024-01-08T00:49:46.558968
# INFO:spectra.py:372:read_spectra: iotime 3.733 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:49:50.683871
# INFO:spectra.py:372:read_spectra: iotime 3.401 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:49:58.247105
# INFO:spectra.py:372:read_spectra: iotime 3.680 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T00:50:06.648785
# INFO:spectra.py:372:read_spectra: iotime 3.284 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:50:13.991975
# INFO:spectra.py:372:read_spectra: iotime 4.724 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:50:24.776976
# INFO:spectra.py:372:read_spectra: iotime 1.455 sec to read coadd-sv1-other-11521.fits at 2024-01-08T00:50:29.760604
# INFO:spectra.py:372:read_spectra: iotime 1.560 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:50:32.137106
# INFO:spectra.py:372:read_spectra: iotime 1.323 sec to read coadd-sv1-other-10156.fits at 2024-01-08T00:50:34.284030
# INFO:spectra.py:372:read_spectra: iotime 2.552 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:50:38.074497
# INFO:spectra.py:372:read_spectra: iotime 3.168 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:50:44.950756
# INFO:spectra.py:372:read_spectra: iotime 0.840 sec to read coadd-sv1-other-10150.fits at 2024-01-08T00:50:50.503543
# INFO:spectra.py:372:read_spectra: iotime 3.066 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:50:54.190652
# INFO:spectra.py:372:read_spectra: iotime 1.780 sec to read coadd-sv1-other-10153.fits at 2024-01-08T00:50:59.545545
# INFO:spectra.py:372:read_spectra: iotime 3.683 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:51:05.033922
# INFO:spectra.py:372:read_spectra: iotime 3.713 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:51:11.814954
# INFO:spectra.py:372:read_spectra: iotime 3.135 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:51:19.586585
# INFO:spectra.py:372:read_spectra: iotime 4.047 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T00:51:27.616886
# INFO:spectra.py:372:read_spectra: iotime 2.716 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:51:34.807964
# INFO:spectra.py:372:read_spectra: iotime 2.475 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:51:39.646177
# INFO:spectra.py:372:read_spectra: iotime 3.833 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:51:47.193928
# INFO:spectra.py:372:read_spectra: iotime 3.519 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:51:54.950272
# INFO:spectra.py:372:read_spectra: iotime 3.305 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T00:52:03.112753
# INFO:spectra.py:372:read_spectra: iotime 2.070 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T00:52:07.913079
# INFO:spectra.py:372:read_spectra: iotime 3.576 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T00:52:13.494082
# INFO:spectra.py:372:read_spectra: iotime 1.303 sec to read coadd-sv3-bright-10157.fits at 2024-01-08T00:52:19.563081
# INFO:spectra.py:372:read_spectra: iotime 2.543 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:52:23.281859
# INFO:spectra.py:372:read_spectra: iotime 2.403 sec to read coadd-sv3-bright-11520.fits at 2024-01-08T00:52:29.009069
# INFO:spectra.py:372:read_spectra: iotime 2.430 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:52:35.356182
# INFO:spectra.py:372:read_spectra: iotime 2.636 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T00:52:39.921863
# INFO:spectra.py:372:read_spectra: iotime 4.326 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T00:52:47.882825
# INFO:spectra.py:372:read_spectra: iotime 4.254 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T00:52:55.798736
# INFO:spectra.py:372:read_spectra: iotime 2.710 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T00:53:02.771255
# INFO:spectra.py:372:read_spectra: iotime 3.647 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T00:53:10.225915
# ...
# INFO:spectra.py:372:read_spectra: iotime 0.451 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:37:52.357309
# INFO:spectra.py:372:read_spectra: iotime 2.387 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T04:37:54.837509
# INFO:spectra.py:372:read_spectra: iotime 2.688 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T04:37:58.071599
# INFO:spectra.py:372:read_spectra: iotime 2.203 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T04:38:01.791081
# INFO:spectra.py:372:read_spectra: iotime 2.298 sec to read coadd-sv3-dark-10150.fits at 2024-01-08T04:38:04.662722
# INFO:spectra.py:372:read_spectra: iotime 2.385 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T04:38:07.668839
# INFO:spectra.py:372:read_spectra: iotime 0.869 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T04:38:09.652480
# INFO:spectra.py:372:read_spectra: iotime 0.586 sec to read coadd-sv1-other-10147.fits at 2024-01-08T04:38:10.523975
# INFO:spectra.py:372:read_spectra: iotime 0.836 sec to read coadd-sv1-other-10153.fits at 2024-01-08T04:38:11.515939
# INFO:spectra.py:372:read_spectra: iotime 2.161 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T04:38:13.853102
# INFO:spectra.py:372:read_spectra: iotime 0.635 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:38:15.052362
# INFO:spectra.py:372:read_spectra: iotime 0.573 sec to read coadd-sv3-backup-10153.fits at 2024-01-08T04:38:15.805811
# INFO:spectra.py:372:read_spectra: iotime 2.219 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T04:38:18.166346
# INFO:spectra.py:372:read_spectra: iotime 2.293 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T04:38:21.021977
# INFO:spectra.py:372:read_spectra: iotime 2.052 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T04:38:24.534997
# INFO:spectra.py:372:read_spectra: iotime 1.968 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T04:38:27.115329
# INFO:spectra.py:372:read_spectra: iotime 2.206 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T04:38:29.821165
# INFO:spectra.py:372:read_spectra: iotime 0.458 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:38:30.860275
# INFO:spectra.py:372:read_spectra: iotime 0.631 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:38:31.697092
# INFO:spectra.py:372:read_spectra: iotime 2.326 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T04:38:34.216056
# INFO:spectra.py:372:read_spectra: iotime 2.881 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T04:38:37.634998
# INFO:spectra.py:372:read_spectra: iotime 0.685 sec to read coadd-sv1-other-10154.fits at 2024-01-08T04:38:40.147076
# INFO:spectra.py:372:read_spectra: iotime 2.124 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T04:38:42.515910
# INFO:spectra.py:372:read_spectra: iotime 1.647 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T04:38:44.655120
# INFO:spectra.py:372:read_spectra: iotime 1.457 sec to read coadd-sv3-dark-10152.fits at 2024-01-08T04:38:46.609657
# INFO:spectra.py:372:read_spectra: iotime 0.403 sec to read coadd-sv1-other-10158.fits at 2024-01-08T04:38:47.301695
# INFO:spectra.py:372:read_spectra: iotime 0.458 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:38:47.875119
# INFO:spectra.py:372:read_spectra: iotime 0.422 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:38:48.393621
# INFO:spectra.py:372:read_spectra: iotime 1.508 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T04:38:50.017678
# INFO:spectra.py:372:read_spectra: iotime 2.108 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T04:38:52.510752
# INFO:spectra.py:372:read_spectra: iotime 3.012 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T04:38:56.208345
# INFO:spectra.py:372:read_spectra: iotime 2.203 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T04:39:00.037619
# INFO:spectra.py:372:read_spectra: iotime 0.843 sec to read coadd-sv1-other-10156.fits at 2024-01-08T04:39:01.494200
# INFO:spectra.py:372:read_spectra: iotime 1.461 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T04:39:03.186502
# INFO:spectra.py:372:read_spectra: iotime 0.675 sec to read coadd-sv1-other-10154.fits at 2024-01-08T04:39:04.219932
# INFO:spectra.py:372:read_spectra: iotime 0.642 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:39:05.031811
# INFO:spectra.py:372:read_spectra: iotime 0.596 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:39:05.782284
# INFO:spectra.py:372:read_spectra: iotime 2.058 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T04:39:07.975911
# INFO:spectra.py:372:read_spectra: iotime 1.951 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T04:39:10.371580
# INFO:spectra.py:372:read_spectra: iotime 1.960 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T04:39:13.067097
# INFO:spectra.py:372:read_spectra: iotime 0.754 sec to read coadd-sv1-other-11521.fits at 2024-01-08T04:39:14.306599
# INFO:spectra.py:372:read_spectra: iotime 1.941 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T04:39:16.450197
# INFO:spectra.py:372:read_spectra: iotime 2.625 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T04:39:19.558467
# INFO:spectra.py:372:read_spectra: iotime 0.591 sec to read coadd-sv1-other-10147.fits at 2024-01-08T04:39:21.960490
# INFO:spectra.py:372:read_spectra: iotime 0.629 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:39:22.836086
# INFO:spectra.py:372:read_spectra: iotime 0.517 sec to read coadd-sv3-backup-10155.fits at 2024-01-08T04:39:23.492427
# INFO:spectra.py:372:read_spectra: iotime 2.003 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T04:39:25.612127
# INFO:spectra.py:372:read_spectra: iotime 0.590 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:39:26.604529
# INFO:spectra.py:372:read_spectra: iotime 0.597 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:39:27.390117
# INFO:spectra.py:372:read_spectra: iotime 1.862 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T04:39:29.382952
# INFO:spectra.py:372:read_spectra: iotime 1.626 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T04:39:31.483096
# INFO:spectra.py:372:read_spectra: iotime 1.512 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T04:39:33.541529
# INFO:spectra.py:372:read_spectra: iotime 0.749 sec to read coadd-sv1-other-10150.fits at 2024-01-08T04:39:34.668341
# INFO:spectra.py:372:read_spectra: iotime 1.478 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T04:39:36.356434
# INFO:spectra.py:372:read_spectra: iotime 0.450 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:39:37.129466
# INFO:spectra.py:372:read_spectra: iotime 2.216 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T04:39:39.473086
# INFO:spectra.py:372:read_spectra: iotime 2.104 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T04:39:42.098586
# INFO:spectra.py:372:read_spectra: iotime 0.833 sec to read coadd-sv1-other-10156.fits at 2024-01-08T04:39:44.445103
# INFO:spectra.py:372:read_spectra: iotime 1.806 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T04:39:46.502702
# INFO:spectra.py:372:read_spectra: iotime 1.690 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T04:39:48.576383
# INFO:spectra.py:372:read_spectra: iotime 1.680 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T04:39:50.873201
# INFO:spectra.py:372:read_spectra: iotime 1.477 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T04:39:52.758983
# INFO:spectra.py:372:read_spectra: iotime 0.847 sec to read coadd-sv3-bright-11524.fits at 2024-01-08T04:39:53.984297
# INFO:spectra.py:372:read_spectra: iotime 1.967 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T04:39:56.154100
# INFO:spectra.py:372:read_spectra: iotime 2.567 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T04:39:59.143099
# INFO:spectra.py:372:read_spectra: iotime 2.214 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T04:40:02.673025
# INFO:spectra.py:372:read_spectra: iotime 0.703 sec to read coadd-sv1-other-10154.fits at 2024-01-08T04:40:04.297229
# INFO:spectra.py:372:read_spectra: iotime 1.983 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T04:40:06.486494
# INFO:spectra.py:372:read_spectra: iotime 2.133 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T04:40:09.037538
# INFO:spectra.py:372:read_spectra: iotime 1.474 sec to read coadd-sv3-bright-10147.fits at 2024-01-08T04:40:11.215677
# INFO:spectra.py:372:read_spectra: iotime 1.971 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T04:40:13.574545
# INFO:spectra.py:372:read_spectra: iotime 1.174 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T04:40:15.244156
# INFO:spectra.py:372:read_spectra: iotime 0.846 sec to read coadd-sv1-other-10153.fits at 2024-01-08T04:40:16.391672
# INFO:spectra.py:372:read_spectra: iotime 2.336 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T04:40:18.921149
# INFO:spectra.py:372:read_spectra: iotime 2.085 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T04:40:21.671092
# INFO:spectra.py:372:read_spectra: iotime 2.120 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T04:40:25.221169
# INFO:spectra.py:372:read_spectra: iotime 1.997 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T04:40:27.767182
# INFO:spectra.py:372:read_spectra: iotime 0.701 sec to read coadd-sv1-other-10154.fits at 2024-01-08T04:40:29.033010
# INFO:spectra.py:372:read_spectra: iotime 0.630 sec to read coadd-sv1-other-10154.fits at 2024-01-08T04:40:29.858568
# INFO:spectra.py:372:read_spectra: iotime 1.966 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T04:40:31.968432
# INFO:spectra.py:372:read_spectra: iotime 1.634 sec to read coadd-sv3-dark-10147.fits at 2024-01-08T04:40:34.055400
# INFO:spectra.py:372:read_spectra: iotime 1.179 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T04:40:35.735957
# INFO:spectra.py:372:read_spectra: iotime 0.745 sec to read coadd-sv1-other-11521.fits at 2024-01-08T04:40:36.753404
# INFO:spectra.py:372:read_spectra: iotime 2.511 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T04:40:39.500354
# INFO:spectra.py:372:read_spectra: iotime 0.886 sec to read coadd-sv1-other-10156.fits at 2024-01-08T04:40:41.053039
# INFO:spectra.py:372:read_spectra: iotime 2.493 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T04:40:43.816213
# INFO:spectra.py:372:read_spectra: iotime 0.460 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:40:44.875460
# INFO:spectra.py:372:read_spectra: iotime 0.625 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:40:45.699710
# INFO:spectra.py:372:read_spectra: iotime 1.950 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T04:40:47.824718
# INFO:spectra.py:372:read_spectra: iotime 2.095 sec to read coadd-sv3-dark-10154.fits at 2024-01-08T04:40:50.356716
# INFO:spectra.py:372:read_spectra: iotime 1.193 sec to read coadd-sv3-bright-10152.fits at 2024-01-08T04:40:52.538503
# INFO:spectra.py:372:read_spectra: iotime 2.478 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T04:40:55.329763
# INFO:spectra.py:372:read_spectra: iotime 3.281 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T04:40:59.331391
# INFO:spectra.py:372:read_spectra: iotime 2.397 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T04:41:03.261287
# INFO:spectra.py:372:read_spectra: iotime 2.171 sec to read coadd-sv3-bright-11521.fits at 2024-01-08T04:41:06.229184
# INFO:spectra.py:372:read_spectra: iotime 2.116 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T04:41:08.996242
# INFO:spectra.py:372:read_spectra: iotime 2.388 sec to read coadd-sv3-dark-10155.fits at 2024-01-08T04:41:12.233970
# INFO:spectra.py:372:read_spectra: iotime 1.973 sec to read coadd-sv3-bright-10155.fits at 2024-01-08T04:41:15.711499
# INFO:spectra.py:372:read_spectra: iotime 2.021 sec to read coadd-sv3-bright-10153.fits at 2024-01-08T04:41:18.498575
# INFO:spectra.py:372:read_spectra: iotime 2.509 sec to read coadd-sv3-dark-11521.fits at 2024-01-08T04:41:21.566580
# INFO:spectra.py:372:read_spectra: iotime 0.455 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:41:23.464955
# INFO:spectra.py:372:read_spectra: iotime 0.753 sec to read coadd-sv1-other-11521.fits at 2024-01-08T04:41:24.445823
# INFO:spectra.py:372:read_spectra: iotime 2.476 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T04:41:27.075000
# INFO:spectra.py:372:read_spectra: iotime 2.565 sec to read coadd-sv3-bright-10156.fits at 2024-01-08T04:41:30.220669
# INFO:spectra.py:372:read_spectra: iotime 0.641 sec to read coadd-sv1-other-10155.fits at 2024-01-08T04:41:32.405242
# INFO:spectra.py:372:read_spectra: iotime 1.975 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T04:41:34.593727
# INFO:spectra.py:372:read_spectra: iotime 0.856 sec to read coadd-sv1-other-10153.fits at 2024-01-08T04:41:35.859925
# INFO:spectra.py:372:read_spectra: iotime 2.221 sec to read coadd-sv3-bright-10158.fits at 2024-01-08T04:41:38.293047
# INFO:spectra.py:372:read_spectra: iotime 0.321 sec to read coadd-sv1-other-10158.fits at 2024-01-08T04:41:39.139746
# INFO:spectra.py:372:read_spectra: iotime 2.420 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T04:41:41.689447
# INFO:spectra.py:372:read_spectra: iotime 0.580 sec to read coadd-sv1-other-10147.fits at 2024-01-08T04:41:42.789434
# INFO:spectra.py:372:read_spectra: iotime 1.853 sec to read coadd-sv3-bright-10150.fits at 2024-01-08T04:41:44.822608
# INFO:spectra.py:372:read_spectra: iotime 0.794 sec to read coadd-sv1-other-10153.fits at 2024-01-08T04:41:46.035123
# INFO:spectra.py:372:read_spectra: iotime 2.404 sec to read coadd-sv3-dark-10158.fits at 2024-01-08T04:41:48.639621
# INFO:spectra.py:372:read_spectra: iotime 0.780 sec to read coadd-sv1-other-10153.fits at 2024-01-08T04:41:49.953478
# INFO:spectra.py:372:read_spectra: iotime 0.674 sec to read coadd-sv1-other-10154.fits at 2024-01-08T04:41:50.845079
# INFO:spectra.py:372:read_spectra: iotime 0.450 sec to read coadd-sv1-other-10152.fits at 2024-01-08T04:41:51.439476
# INFO:spectra.py:372:read_spectra: iotime 0.815 sec to read coadd-sv1-other-10156.fits at 2024-01-08T04:41:52.377264
# INFO:spectra.py:372:read_spectra: iotime 2.501 sec to read coadd-sv3-dark-10156.fits at 2024-01-08T04:41:55.033278
# INFO:spectra.py:372:read_spectra: iotime 2.670 sec to read coadd-sv3-dark-10153.fits at 2024-01-08T04:41:58.308022
# INFO:spectra.py:372:read_spectra: iotime 1.784 sec to read coadd-sv3-bright-10154.fits at 2024-01-08T04:42:01.945868
# flux_spec: [array([-2.65707231, -1.42336321, -1.81039   , ...,  0.78288257,
#          0.79760027,  0.53306121])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.15486611,  1.72544515,  1.24560595, ..., -0.33046967,
#          0.30090314, -0.32754001])                               ...
#  array([ 4.66301012, -2.75615239, -5.00343657, ..., -0.36792514,
#          0.07685958,  0.43134034])
#  array([-4.17562914, -5.43778276,  6.92230225, ..., -0.20099348,
#          0.26685894,  0.15159832])
#  array([ 5.30654383,  9.61966896, -7.97664595, ...,  1.56433988,
#          1.63528335,  1.65541875])                              ]
# zbin: [(-0.0019957014509158224, 3.0936110394805554)]
# 1
# Number of spectra to stack =  1049
# -0.0019957014509158224 3.0936110394805554
# flux= [array([-2.65707231, -1.42336321, -1.81039   , ...,  0.78288257,
#          0.79760027,  0.53306121])
#  array([0., 0., 0., ..., 0., 0., 0.])
#  array([-0.15486611,  1.72544515,  1.24560595, ..., -0.33046967,
#          0.30090314, -0.32754001])                               ...
#  array([ 4.66301012, -2.75615239, -5.00343657, ..., -0.36792514,
#          0.07685958,  0.43134034])
#  array([-4.17562914, -5.43778276,  6.92230225, ..., -0.20099348,
#          0.26685894,  0.15159832])
#  array([ 5.30654383,  9.61966896, -7.97664595, ...,  1.56433988,
#          1.63528335,  1.65541875])                              ]
# Spectra corrected for foreground extinction.
# flux_new: [[nan nan nan ... nan nan nan]
#  [nan nan nan ...  0.  0.  0.]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Fnorm: [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Stack[0]: [nan nan nan ... nan nan nan]
# Stack[1]: [nan nan nan ... nan nan nan]
# Stack[2]: [ 1.  1.  1. ... 66. 66. 39.]

# %%
stack_outputs[2]
# Out:
# {'zbin=0': {'flux': array([nan, nan, nan, ..., nan, nan, nan]),
#   'flux_err': array([nan, nan, nan, ..., nan, nan, nan]),
#   'N': array([ 1.,  1.,  1., ..., 98., 98., 55.]),
#   'wln': array([ 557.5,  558.5,  559.5, ..., 9841.5, 9842.5, 9843.5]),
#   'norm_range': array([3050, 3051, 3052, 3053, 3054, 3055, 3056, 3057, 3058, 3059, 3060,
#          3061, 3062, 3063, 3064, 3065, 3066, 3067, 3068, 3069, 3070, 3071,
#          3072, 3073, 3074, 3075, 3076, 3077, 3078, 3079, 3080, 3081, 3082,
#          3083, 3084, 3085, 3086, 3087, 3088, 3089, 3090, 3091, 3092, 3093,
#          3094, 3095, 3096, 3097, 3098, 3099, 3100, 3101, 3102, 3103, 3104,
#          3105, 3106, 3107, 3108, 3109, 3110, 3111, 3112, 3113, 3114, 3115,
#          3116])}}

# %% [markdown]
# ## Plot Stacked Spectra

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(20, 36), sharey=True)

# Define the labels for the legend
labels = ['SFG Low Mass Bin 1', 'SFG Low Mass Bin 2', 'SFG Mid Mass Bin 1', 'SFG Mid Mass Bin 2', 'SFG High Mass Bin 1', 'SFG High Mass Bin 2']

# Loop over each stack output and plot in a separate subplot
for i, (stack_output, label) in enumerate(zip(stack_outputs, labels)):
    ax = axes[i]  # Select the current subplot
    
    # Plot the stacked spectra
    ax.plot(stack_output['zbin=0']['wln'], stack_output['zbin=0']['flux'], color='purple', alpha=0.5,
            label=f'DESI {label} Stacked Spectra')
    
    # Plot the convolved spectra
    ax.plot(stack_output['zbin=0']['wln'], convolve(stack_output['zbin=0']['flux'], Gaussian1DKernel(5)),
            color='black', alpha=1)
    
    ax.set_ylabel('$F_{\lambda}$ [$10^{-17} \, \mathrm{erg\ s^{-1}\ cm^{-2}\ \AA^{-1}}$]')
    ax.set_xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
    ax.set_ylim(-5, 10)
    ax.set_xlim(1000, 10000)
    ax.legend()

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]

# %%
from matplotlib.backends.backend_pdf import PdfPages

# Create a PDF file to save the plots
pdf_filename = f'DESI-{Overall_class}-stacked-plots-Mass.pdf'
with PdfPages(pdf_filename) as pdf:
    # Create a figure with three subplots
    fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(20, 36), sharey=True)

    # Define the labels for the legend
    labels = ['Low Mass Bin 1', 'Low Mass Bin 2', 'Mid Mass Bin 1', 'Mid Mass Bin 2', 'High Mass Bin 1', 'High Mass Bin 2']

    # Loop over each stack output and plot in a separate subplot
    for i, (stack_output, label) in enumerate(zip(stack_outputs, labels)):
        ax = axes[i]  # Select the current subplot

        # Plot the stacked spectra
        ax.plot(stack_output['zbin=0']['wln'], stack_output['zbin=0']['flux'], color='purple', alpha=0.5,
                label=f'DESI {label} Stacked Spectra Mass')

        # Plot the convolved spectra
        ax.plot(stack_output['zbin=0']['wln'], convolve(stack_output['zbin=0']['flux'], Gaussian1DKernel(5)),
                color='black', alpha=1)

        ax.set_ylabel('$F_{\lambda}$ [$10^{-17} \, \mathrm{erg\ s^{-1}\ cm^{-2}\ \AA^{-1}}$]')
        ax.set_xlabel('Rest-frame wavelength $\lambda$ [$\AA$]')
        ax.set_ylim(-5, 10)
        ax.set_xlim(1000, 10000)
        ax.legend()

        # Save the current plot to the PDF file
        pdf.savefig(fig)
        plt.close()

# All the plots will be saved in the PDF file
print(f'All plots saved in {pdf_filename}')
# Out:
# All plots saved in DESI-SFG-stacked-plots-Mass.pdf
